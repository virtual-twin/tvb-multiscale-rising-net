# %% [markdown]
# # TVB-NEST: Bridging multiscale activity by co-simulation
#
# ## Step-by-step learn how to perform a co-simulation embedding spiking neural networks into large-scale brain networks using TVB.

# %%
from IPython.display import Image, display
display(Image(filename='../pics/ConceptGraph1.png',  width=1000, unconfined=False))

# %%
display(Image(filename='../pics/ConceptGraph2.png',  width=1000, unconfined=False))

# %% [markdown]
# ## tvb-multiscale toolbox:
#
# ### https://github.com/the-virtual-brain/tvb-multiscale
#
# For questions use the git issue tracker, or write an e-mail to me: dionysios.perdikis@charite.de

# %% [markdown]
# # TVB - NEST co-simulation

# %% [markdown]
# ## Wilson - Cowan TVB mean field model
#
# For every region node $n\prime$ modelled as a mean-field node in TVB:
#
# Population activity dynamics (1 excitatory and 1 inhibitory population):
#
#  $\dot{E}_k = \dfrac{1}{\tau_e} (-E_k  + (k_e - r_e E_k) \mathcal{S}_e (\alpha_e \left( c_{ee} E_k - c_{ei} I_k  + P_k - \theta_e + \mathbf{\Gamma}(E_k, E_j, u_{kj}) + W_{\zeta}\cdot E_j + W_{\zeta}\cdot I_j\right) )) $
#
# $
#             \dot{I}_k = \dfrac{1}{\tau_i} (-I_k  + (k_i - r_i I_k) \mathcal{S}_i (\alpha_i \left( c_{ie} E_k - c_{ee} I_k  + Q_k - \theta_i + \mathbf{\Gamma}(E_k, E_j, u_{kj}) + W_{\zeta}\cdot E_j + W_{\zeta}\cdot I_j\right) ))$

# %% [markdown]
# ## Spiking network model in NEST
#
# using "iaf_cond_alpha" spiking neuronal model.

# %% [markdown]
# ## TVB to NEST coupling
# TVB couples to NEST via instantaneous spike rate $ w_{TVB->NEST} * E(t) $,
#
# Inhomogeneous spike generator NEST devices are used as TVB "proxy" nodes and generate independent Poisson-random spike trains
#
# $ \left[ \sum_k \delta(t-\tau_{n\prime n}-{t_j}^k) \right]_{j \in n\prime} $
#
# Alternatively, the spike trains are generated outside NEST using the Elephant software and inserted to NEST via spike generator devices.

# %% [markdown]
# ## NEST to TVB update
#
# A NEST spike detector device is used to count spike for each time step, and convert it to an instantaneous population mean rate that overrides
#
# $ {E_{_{n}}}(t) =  \frac{\sum_j\left[ \sum_k \delta(t-\tau_n-{t_j}^k) \right]_{j \in E_n}}{N_E * dt} $
#
# $ {I_{_{n}}}(t) =  \frac{\sum_j\left[ \sum_k \delta(t-\tau_n-{t_j}^k) \right]_{j \in I_n}}{N_I * dt} $
#
# in  spikes/sec.
#
# This update process concerns only the TVB region nodes that are simulated exclusively in NEST, as spiking networks. All the rest of TVB nodes will follow the equations of the mean field model described above.

# %% [markdown]
# ## Simulator loop
#
# ### Simulating several (i.e., minimally 2) NEST time steps for every 1 TVB time step for stable integration
#
# ### Synchronizaion every minimum delay time between the two simulators.

# %% [markdown]
# # WORKFLOW:

# %%
from tvb.basic.profile import TvbProfile
TvbProfile.set_profile(TvbProfile.LIBRARY_PROFILE)

from tvb_multiscale.tvb_nest.config import Config
from examples.parallel.wilson_cowan.config import configure

config = configure(config_class=Config)

# Select here which kind of test Co-Simulation to perform,
# - with Tsync = min_tvb_delay, or
# - with Tsync = min_tvb_delay / 2:
config.TVB_MIN_IDELAY_TO_SYNC_N_STEP_RATIO = 1
# config.INTERFACE_COUPLING_MODE = "spikeNet"

# For interactive plotting:
# %matplotlib notebook  

# Otherwise:
# %matplotlib inline
# Out:
# 2023-10-24 18:09:20,437 - INFO - tvb_multiscale.tvb_nest.config - Configuring NEST path...
# 2023-10-24 18:09:20,437 - INFO - tvb_multiscale.tvb_nest.config - Configuring NEST path...
# 2023-10-24 18:09:20,438 - INFO - tvb_multiscale.tvb_nest.config - NEST_INSTALL_DIR: /home/docker/build/nest
# 2023-10-24 18:09:20,438 - INFO - tvb_multiscale.tvb_nest.config - NEST_INSTALL_DIR: /home/docker/build/nest
# 2023-10-24 18:09:20,439 - INFO - tvb_multiscale.tvb_nest.config - NEST_DATA_DIR: /home/docker/build/nest/share/nest
# 2023-10-24 18:09:20,439 - INFO - tvb_multiscale.tvb_nest.config - NEST_DATA_DIR: /home/docker/build/nest/share/nest
# 2023-10-24 18:09:20,440 - INFO - tvb_multiscale.tvb_nest.config - NEST_DOC_DIR: /home/docker/build/nest/share/doc/nest
# 2023-10-24 18:09:20,440 - INFO - tvb_multiscale.tvb_nest.config - NEST_DOC_DIR: /home/docker/build/nest/share/doc/nest
# 2023-10-24 18:09:20,441 - INFO - tvb_multiscale.tvb_nest.config - NEST_MODULE_PATH: /home/docker/build/nest/lib/nest
# 2023-10-24 18:09:20,441 - INFO - tvb_multiscale.tvb_nest.config - NEST_MODULE_PATH: /home/docker/build/nest/lib/nest
# 2023-10-24 18:09:20,442 - INFO - tvb_multiscale.tvb_nest.config - PATH: /home/docker/build/nest/bin:/home/docker/build/nest/bin:/usr/bin:/home/docker/.local/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin;;
# 2023-10-24 18:09:20,442 - INFO - tvb_multiscale.tvb_nest.config - PATH: /home/docker/build/nest/bin:/home/docker/build/nest/bin:/usr/bin:/home/docker/.local/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin;;
# 2023-10-24 18:09:20,442 - INFO - tvb_multiscale.tvb_nest.config - LD_LIBRARY_PATH: /home/docker/build/nest/lib/nest::/home/docker/build/nest/lib/nest
# 2023-10-24 18:09:20,442 - INFO - tvb_multiscale.tvb_nest.config - LD_LIBRARY_PATH: /home/docker/build/nest/lib/nest::/home/docker/build/nest/lib/nest
# 2023-10-24 18:09:20,443 - INFO - tvb_multiscale.tvb_nest.config - SLI_PATH: /home/docker/build/nest/share/nest/sli
# 2023-10-24 18:09:20,443 - INFO - tvb_multiscale.tvb_nest.config - SLI_PATH: /home/docker/build/nest/share/nest/sli
# 2023-10-24 18:09:20,444 - INFO - tvb_multiscale.tvb_nest.config - NEST_PYTHON_PREFIX: /home/docker/build/nest/lib/python3.10/site-packages
# 2023-10-24 18:09:20,444 - INFO - tvb_multiscale.tvb_nest.config - NEST_PYTHON_PREFIX: /home/docker/build/nest/lib/python3.10/site-packages
# 2023-10-24 18:09:20,445 - INFO - tvb_multiscale.tvb_nest.config - system path: ['/home/docker/build/nest/lib/python3.10/site-packages', '/home/docker/packages/tvb-multiscale/examples/tvb_nest/notebooks/parallel', '/home/docker/packages/tvb-multiscale/examples/tvb_nest/notebooks/parallel', '/usr', '/home/docker/.local', '', '/home/docker/build/nest/lib/python3.10/site-packages', '/usr/lib/python310.zip', '/usr/lib/python3.10', '/usr/lib/python3.10/lib-dynload', '/home/docker/.local/lib/python3.10/site-packages', '/home/docker/.local/lib/python3.10/site-packages/NESTML-5.3.0.post0.dev0-py3.10.egg', '/home/docker/.local/lib/python3.10/site-packages/odetoolbox-2.5.3-py3.10.egg', '/home/docker/.local/lib/python3.10/site-packages/astropy-5.3.3-py3.10-linux-aarch64.egg', '/home/docker/.local/lib/python3.10/site-packages/antlr4_python3_runtime-4.10-py3.10.egg', '/home/docker/.local/lib/python3.10/site-packages/pyerfa-2.0.0.3-py3.10-linux-aarch64.egg', '/home/docker/.local/lib/python3.10/site-packages/PyYAML-6.0.1-py3.10-linux-aarch64.egg', '/home/docker/.local/lib/python3.10/site-packages/pyspike-0.8.0-py3.10-linux-aarch64.egg', '/home/docker/packages/tvb-root/tvb_framework', '/home/docker/.local/lib/python3.10/site-packages/tvb_storage-2.8.1-py3.10.egg', '/home/docker/.local/lib/python3.10/site-packages/tvb_gdist-2.2-py3.10-linux-aarch64.egg', '/home/docker/.local/lib/python3.10/site-packages/tvb_data-2.0-py3.10.egg', '/home/docker/.local/lib/python3.10/site-packages/tables-3.7.0-py3.10-linux-aarch64.egg', '/home/docker/.local/lib/python3.10/site-packages/simplejson-3.19.1-py3.10-linux-aarch64.egg', '/home/docker/.local/lib/python3.10/site-packages/siibra-0.4a35-py3.10.egg', '/home/docker/.local/lib/python3.10/site-packages/psutil-5.9.5-py3.10-linux-aarch64.egg', '/home/docker/.local/lib/python3.10/site-packages/nibabel-5.1.0-py3.10.egg', '/home/docker/.local/lib/python3.10/site-packages/pyAesCrypt-6.1.0-py3.10.egg', '/home/docker/.local/lib/python3.10/site-packages/kubernetes-28.1.0-py3.10.egg', '/home/docker/.local/lib/python3.10/site-packages/cryptography-41.0.4-py3.10-linux-aarch64.egg', '/home/docker/.local/lib/python3.10/site-packages/PyLEMS-0.6.4-py3.10.egg', '/home/docker/.local/lib/python3.10/site-packages/numexpr-2.8.6-py3.10-linux-aarch64.egg', '/home/docker/.local/lib/python3.10/site-packages/networkx-3.1-py3.10.egg', '/home/docker/.local/lib/python3.10/site-packages/ipywidgets-8.1.1-py3.10.egg', '/home/docker/.local/lib/python3.10/site-packages/autopep8-2.0.4-py3.10.egg', '/home/docker/.local/lib/python3.10/site-packages/Deprecated-1.2.14-py3.10.egg', '/home/docker/.local/lib/python3.10/site-packages/scikit_image-0.21.0-py3.10-linux-aarch64.egg', '/home/docker/.local/lib/python3.10/site-packages/nilearn-0.10.1-py3.10.egg', '/home/docker/.local/lib/python3.10/site-packages/neuroglancer_scripts-1.1.0-py3.10.egg', '/home/docker/.local/lib/python3.10/site-packages/anytree-2.9.0-py3.10.egg', '/home/docker/.local/lib/python3.10/site-packages/websocket_client-1.6.3-py3.10.egg', '/home/docker/.local/lib/python3.10/site-packages/cffi-1.15.1-py3.10-linux-aarch64.egg', '/home/docker/.local/lib/python3.10/site-packages/widgetsnbextension-4.0.9-py3.10.egg', '/home/docker/.local/lib/python3.10/site-packages/jupyterlab_widgets-3.0.9-py3.10.egg', '/home/docker/.local/lib/python3.10/site-packages/comm-0.1.4-py3.10.egg', '/home/docker/.local/lib/python3.10/site-packages/pycodestyle-2.11.0-py3.10.egg', '/home/docker/.local/lib/python3.10/site-packages/wrapt-1.15.0-py3.10-linux-aarch64.egg', '/home/docker/.local/lib/python3.10/site-packages/tifffile-2023.9.18-py3.10.egg', '/home/docker/.local/lib/python3.10/site-packages/lazy_loader-0.3-py3.10.egg', '/home/docker/.local/lib/python3.10/site-packages/imageio-2.31.3-py3.10.egg', '/home/docker/.local/lib/python3.10/site-packages/PyWavelets-1.4.1-py3.10-linux-aarch64.egg', '/home/docker/packages/tvb-root/tvb_library', '/home/docker/packages/tvb-root/tvb_contrib', '/home/docker/.local/lib/python3 ...
# 2023-10-24 18:09:20,445 - INFO - tvb_multiscale.tvb_nest.config - system path: ['/home/docker/build/nest/lib/python3.10/site-packages', '/home/docker/packages/tvb-multiscale/examples/tvb_nest/notebooks/parallel', '/home/docker/packages/tvb-multiscale/examples/tvb_nest/notebooks/parallel', '/usr', '/home/docker/.local', '', '/home/docker/build/nest/lib/python3.10/site-packages', '/usr/lib/python310.zip', '/usr/lib/python3.10', '/usr/lib/python3.10/lib-dynload', '/home/docker/.local/lib/python3.10/site-packages', '/home/docker/.local/lib/python3.10/site-packages/NESTML-5.3.0.post0.dev0-py3.10.egg', '/home/docker/.local/lib/python3.10/site-packages/odetoolbox-2.5.3-py3.10.egg', '/home/docker/.local/lib/python3.10/site-packages/astropy-5.3.3-py3.10-linux-aarch64.egg', '/home/docker/.local/lib/python3.10/site-packages/antlr4_python3_runtime-4.10-py3.10.egg', '/home/docker/.local/lib/python3.10/site-packages/pyerfa-2.0.0.3-py3.10-linux-aarch64.egg', '/home/docker/.local/lib/python3.10/site-packages/PyYAML-6.0.1-py3.10-linux-aarch64.egg', '/home/docker/.local/lib/python3.10/site-packages/pyspike-0.8.0-py3.10-linux-aarch64.egg', '/home/docker/packages/tvb-root/tvb_framework', '/home/docker/.local/lib/python3.10/site-packages/tvb_storage-2.8.1-py3.10.egg', '/home/docker/.local/lib/python3.10/site-packages/tvb_gdist-2.2-py3.10-linux-aarch64.egg', '/home/docker/.local/lib/python3.10/site-packages/tvb_data-2.0-py3.10.egg', '/home/docker/.local/lib/python3.10/site-packages/tables-3.7.0-py3.10-linux-aarch64.egg', '/home/docker/.local/lib/python3.10/site-packages/simplejson-3.19.1-py3.10-linux-aarch64.egg', '/home/docker/.local/lib/python3.10/site-packages/siibra-0.4a35-py3.10.egg', '/home/docker/.local/lib/python3.10/site-packages/psutil-5.9.5-py3.10-linux-aarch64.egg', '/home/docker/.local/lib/python3.10/site-packages/nibabel-5.1.0-py3.10.egg', '/home/docker/.local/lib/python3.10/site-packages/pyAesCrypt-6.1.0-py3.10.egg', '/home/docker/.local/lib/python3.10/site-packages/kubernetes-28.1.0-py3.10.egg', '/home/docker/.local/lib/python3.10/site-packages/cryptography-41.0.4-py3.10-linux-aarch64.egg', '/home/docker/.local/lib/python3.10/site-packages/PyLEMS-0.6.4-py3.10.egg', '/home/docker/.local/lib/python3.10/site-packages/numexpr-2.8.6-py3.10-linux-aarch64.egg', '/home/docker/.local/lib/python3.10/site-packages/networkx-3.1-py3.10.egg', '/home/docker/.local/lib/python3.10/site-packages/ipywidgets-8.1.1-py3.10.egg', '/home/docker/.local/lib/python3.10/site-packages/autopep8-2.0.4-py3.10.egg', '/home/docker/.local/lib/python3.10/site-packages/Deprecated-1.2.14-py3.10.egg', '/home/docker/.local/lib/python3.10/site-packages/scikit_image-0.21.0-py3.10-linux-aarch64.egg', '/home/docker/.local/lib/python3.10/site-packages/nilearn-0.10.1-py3.10.egg', '/home/docker/.local/lib/python3.10/site-packages/neuroglancer_scripts-1.1.0-py3.10.egg', '/home/docker/.local/lib/python3.10/site-packages/anytree-2.9.0-py3.10.egg', '/home/docker/.local/lib/python3.10/site-packages/websocket_client-1.6.3-py3.10.egg', '/home/docker/.local/lib/python3.10/site-packages/cffi-1.15.1-py3.10-linux-aarch64.egg', '/home/docker/.local/lib/python3.10/site-packages/widgetsnbextension-4.0.9-py3.10.egg', '/home/docker/.local/lib/python3.10/site-packages/jupyterlab_widgets-3.0.9-py3.10.egg', '/home/docker/.local/lib/python3.10/site-packages/comm-0.1.4-py3.10.egg', '/home/docker/.local/lib/python3.10/site-packages/pycodestyle-2.11.0-py3.10.egg', '/home/docker/.local/lib/python3.10/site-packages/wrapt-1.15.0-py3.10-linux-aarch64.egg', '/home/docker/.local/lib/python3.10/site-packages/tifffile-2023.9.18-py3.10.egg', '/home/docker/.local/lib/python3.10/site-packages/lazy_loader-0.3-py3.10.egg', '/home/docker/.local/lib/python3.10/site-packages/imageio-2.31.3-py3.10.egg', '/home/docker/.local/lib/python3.10/site-packages/PyWavelets-1.4.1-py3.10-linux-aarch64.egg', '/home/docker/packages/tvb-root/tvb_library', '/home/docker/packages/tvb-root/tvb_contrib', '/home/docker/.local/lib/python3 ...
# Config (
#   title ........................................................................................... 'Config gid: 4ded1367-0cb5-4966-ab91-2a1be13d05c6'
#   Type ............................................................................................ 'Config'
#   gid ............................................................................................. UUID('4ded1367-0cb5-4966-ab91-2a1be13d05c6')
#   config.gid ...................................................................................... UUID('4ded1367-0cb5-4966-ab91-2a1be13d05c6')
#   config.title .................................................................................... 'Config gid: 4ded1367-0cb5-4966-ab91-2a1be13d05c6'
#   config.log ...................................................................................... <Logger tvb_multiscale.tvb_nest.config (DEBUG)>
#   config.BASEPATH ................................................................................. '/home/docker/packages/tvb-multiscale/examples/tvb_nest/notebooks/parallel/examples_data/WilsonCowanNoSpikeNetBuilders'
#   config.VERBOSITY ................................................................................ 1
#   config.out ...................................................................................... OutputConfig
#   config.figures .................................................................................. FiguresConfig
#   config.calcul ................................................................................... CalculusConfig
#   config.RAY_PARALLEL ............................................................................. True
#   config.DEFAULT_SUBJECT[connectivity] ............................................................ Connectivity gid: 86207e0a-eb32-4f40-bf3a-8735ff463844
#   config.DEFAULT_SUBJECT[cortex] .................................................................. Cortex gid: d58c5a54-9515-415d-b67d-0669d9dd4953
#   config.DEFAULT_SUBJECT_PATH ..................................................................... '/home/docker/packages/tvb-multiscale/examples/data/tvb_data/berlinSubjects/QL_20120814'
#   config.TVB_DATA_PATH ............................................................................ '/home/docker/packages/tvb-multiscale/examples/data/tvb_data'
#   config.DEFAULT_CONNECTIVITY_ZIP ................................................................. '/home/docker/packages/tvb-multiscale/examples/data/tvb_data/berlinSubjects/QL_20120814/QL_20120814_Connectivity.zip'
#   config.DEFAULT_DT ............................................................................... 0.1
#   config.TVB_TO_SPIKING_DT_RATIO .................................................................. 2
#   config.MIN_SPIKING_DT ........................................................................... 0.001
#   config.MIN_DELAY_RATIO .......................................................................... 1
#   config.DEFAULT_SPIKING_MIN_DELAY ................................................................ 1.0
#   config.DEFAULT_TVB_MODEL ........................................................................ <class 'tvb.simulator.models.wilson_cowan.WilsonCowan'>
#   config.DEFAULT_TVB_COUPLING_MODEL ............................................................... <class 'tvb.simulator.coupling.Linear'>
#   config.DEFAULT_DETERMINISTIC_INTEGRATOR ......................................................... <class 'tvb.simulator.integrators.HeunDeterministic'>
#   config.DEFAULT_STOCHASTIC_INTEGRATOR ............................................................ <class 'tvb.simulator.integrators.HeunStochastic'>
#   config.DEFAULT_INTEGRATOR ....................................................................... <class 'tvb.simulator.integrators.HeunStochastic'>
#   config.DEFAULT_TRANSFORMER_INTEGRATOR_MODEL ..................................................... <class 'tvb.simulator.integrators.EulerDeterministic'>
#   config.DEFAULT_NOISE ............................................................................ <class 'tvb.simulator.noise.Additive'>
#   config.DEFAULT_NSIG ............................................................................. 0.001
#   config.DEFAULT_TVB_NOISE_SEED ................................................................... 42
#   config.DEFAULT_MONITOR .......................................................................... <class 'tvb.simulator.monitors.Raw'>
#   config._NEST_PATH ............................................................................... '/home/docker/build/nest'
#   config.PYTHON ................................................................................... '/home/docker/build/nest/lib/python3.10/site-packages'
#   config.DATA_DIR ................................................................................. '/home/docker/build/nest/share/nest'
#   config.SLI_PATH ................................................................................. '/home/docker/build/nest/share/nest/sli'
#   config.DOC_DIR .................................................................................. '/home/docker/build/nest/share/doc/nest'
#   config.MODULE_PATH .............................................................................. '/home/docker/build/nest/lib/nest'
#   config.TVB_NEST_DIR ............................................................................. '/home/docker/packages/tvb-multiscale/tvb_multiscale/tvb_nest'
#   config.WORKING_DIR .............................................................................. '/home/docker/packages/tvb-multiscale/examples/tvb_nest/notebooks/parallel'
#   config.MYMODULES_DIR ............................................................................ '/home/docker/packages/tvb-multiscale/tvb_multiscale/tvb_nest/nest/modules'
#   config.MYMODULES_BLD_DIR ........................................................................ '/home/docker/build/nest_modules_builds'
#   config.RECORDINGS_DIR ........................................................................... '/home/docker/packages/tvb-multiscale/examples/tvb_nest/notebooks/parallel/examples_data/WilsonCowanNoSpikeNetBuilders/res/nest_recordings'
#   config.NEST_MASTER_SEED ......................................................................... 143202461
#   config.NEST_VERBOCITY ........................................................................... 40
#   config.DEFAULT_NUM_PROCS ........................................................................ 1
#   config.DEFAULT_LOCAL_NUM_THREADS ................................................................ 4
#   config.DEFAULT_SPIKING_MODEL .................................................................... 'iaf_cond_alpha'
#   config.DEFAULT_SYNAPSE .......................................................................... 'static_synapse'
#   config.LOCK_MIN_DELAY ........................................................................... False
#   config.DEFAULT_TVB_TO_NEST_INTERFACE ............................................................ 'inhomogeneous_poisson_generator'
#   config.DEFAULT_NEST_TO_TVB_INTERFACE ............................................................ 'spike_recorder'
#   config.DEFAULT_DEVICE_RECORD_TO ................................................................. 'memory'
#   config.NEST_INPUT_DEVICES_PARAMS_DEF[spike_generator][allow_offgrid_times] ...................... True
#   config.NEST_INPUT_DEVICES_PARAMS_DEF[mip_generator][p_copy] ..................................... 0.5
#   config.NEST_INPUT_DEVICES_PARAMS_DEF[mip_generator][mother_seed] ................................ 0
#   config.NEST_INPUT_DEVICES_PARAMS_DEF[inhomogeneous_poisson_generator][allow_offgrid_times] ...... True
#   config.NEST_INPUT_DEVICES_PARAMS_DEF[parrot_spike_generator][allow_offgrid_times] ............... True
#   config.NEST_INPUT_DEVICES_PARAMS_DEF[parrot_mip_generator][p_copy] .............................. 0.5
#   config.NEST_INPUT_DEVICES_PARAMS_DEF[parrot_mip_generator][mother_seed] ......................... 0
#   config.NEST_INPUT_DEVICES_PARAMS_DEF[parrot_inhomogeneous_poisson_generator][allow_offgrid_times]  True
#   config.N_REGIONS ................................................................................ None
#   config.SPIKENET_MODEL_BUILDERS .................................................................. None
#   config.SPIKING_NODES_INDS ....................................................................... --------------------
#   config.SPIKING_NODES_INDS: shape ................................................................ (2,)
#   config.SPIKING_NODES_INDS: dtype ................................................................ int64
#   config.SPIKING_NODES_INDS: values ............................................................... [[0, 1]]
#   config.N_NEURONS ................................................................................ 100
#   config.INTERFACE_MODEL .......................................................................... 'RATE'
#   config.TVB_TO_SPIKENET_PROXY_MODEL .............................................................. 'RATE'
#   config.INTERFACE_COUPLING_MODE .................................................................. 'TVB'
#   config.EXCLUSIVE_NODES .......................................................................... True
#   config.W_TVB_TO_SPIKENET ........................................................................ 2500.0
#   config.TVB_MIN_IDELAY_TO_SYNC_N_STEP_RATIO ...................................................... 2
#   config.SIMULATION_LENGTH ........................................................................ 1100.0
#   config.TRANSIENT ................................................................................ 100.0
# )

# %% [markdown]
# ## BACKEND: 1. Load structural data <br> (minimally a TVB connectivity)  <br> & prepare TVB simulator  <br> (region mean field model, integrator, monitors etc)

# %%
# This would run on TVB only before creating any multiscale cosimulation interface connections.
from examples.parallel.tvb_nest.wilson_cowan.tvb_config import build_tvb_simulator

simulator = build_tvb_simulator(config=config, config_class=Config)
# Out:
# 2023-10-24 18:09:21,033 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_parallel - There are no existing connections (i.e., with nonzero weights)!
# Setting minimum delay to 1 integrator time step = 0.1!.
# 2023-10-24 18:09:21,038 - ERROR - tvb_multiscale.core.tvb.cosimulator.cosimulator_parallel - Bad Simulator.integrator.noise.nsig shape: (2, 1, 1)
# 2023-10-24 18:09:21,051 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_parallel - There are no existing connections (i.e., with nonzero weights)!
# Setting minimum delay to 1 integrator time step = 0.1!.
# CoSimulatorParallel (
#   title ............................... 'CoSimulatorParallel gid: 08550923-54a9-4d21-a134-fdbe51cb4680'
#   Type ................................ 'CoSimulatorParallel'
#   model ............................... WilsonCowan gid: 01a972ad-3550-456b-948a-ce27e8e2dc6d
#   output_interfaces ................... None
#   input_interfaces .................... None
#   out_proxy_inds ...................... --------------------
#   shape ............................... (0,)
#   dtype ............................... int64
#   is empty ............................ True
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... False
#   voi ................................. --------------------
#   proxy_inds .......................... --------------------
#   synchronization_time ................ 0.0
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: 3024ce3a-c222-4268-8174-17ba70523f61
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: 7da6f0f8-7d24-444e-84f7-e467e7224251
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: 02f1a14c-06d9-405c-8023-a9562e276a46
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 2, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   monitors[0] ......................... Raw gid: d9477d86-a187-4ec1-bffb-94ae02ea5539
#   simulation_length ................... 1100.0
#   gid ................................. UUID('08550923-54a9-4d21-a134-fdbe51cb4680')
# )

# %% [markdown]
# ## BACKEND: 2. Build and connect the NEST network model <br> (networks of spiking neural populations for fine-scale <br>regions, stimulation devices, spike detectors etc)

# %%
# This would run on NEST only before creating any multiscale cosimulation interface connections.
# Here it is assumed that the TVB simulator is already created and we can get some of its attributes, 
# either by directly accessing it, or via serialization.

from examples.parallel.tvb_nest.wilson_cowan.nest_config import build_nest_network


# nest_network = build_nest_network(config=config, config_class=Config)

# %% [markdown]
# ## FRONTEND: 3. Build the TVB-NEST interface

# %%
# options for a nonopinionated builder:
from tvb_multiscale.core.interfaces.transformers.models.models import Transformers
from tvb_multiscale.core.interfaces.transformers.builders import \
        DefaultTVBtoSpikeNetTransformers, DefaultSpikeNetToTVBTransformers, \
        TVBtoSpikeNetTransformers, SpikeNetToTVBTransformers
from tvb_multiscale.tvb_nest.interfaces.builders import \
        TVBtoNESTModels, NESTInputProxyModels, DefaultTVBtoNESTModels, \
        NESTtoTVBModels, NESTOutputProxyModels, DefaultNESTtoTVBModels

    
def print_enum_like(enum_like):
    print("\n", enum_like.__name__)
    for name, value in enum_like.__dict__.items():
        if name[0] != "_":
            print(name,"= ", value)
    
def print_enum(enum):
    print("\n", enum)
    for name, member in enum.__members__.items():
        print(name,"= ", member.value)
    
    
print("Available input (NEST->TVB update) / output (TVB->NEST coupling) interface models:")
print_enum(TVBtoNESTModels)
print_enum(NESTtoTVBModels)
    
    
print("\n\nAvailable input (spikeNet->TVB update) / output (TVB->spikeNet coupling) transformer models:")

print_enum(TVBtoSpikeNetTransformers)
print_enum_like(DefaultTVBtoSpikeNetTransformers)
    
print_enum(SpikeNetToTVBTransformers)
print_enum_like(DefaultSpikeNetToTVBTransformers)    
    
    
print("\n\nAvailable input (NEST->TVB update) / output (TVB->NEST coupling) proxy models:")

print_enum_like(DefaultTVBtoNESTModels)
print_enum(NESTInputProxyModels)
    
print_enum(NESTOutputProxyModels)
print_enum_like(DefaultNESTtoTVBModels)
    
print("\n\nAll basic transformer models:")
print_enum(Transformers)
# Out:
#               -- N E S T --
#   Copyright (C) 2004 The NEST Initiative
#
#  Version: 3.5
#  Built: Sep 22 2023 09:19:05
#
#  This program is provided AS IS and comes with
#  NO WARRANTY. See the file LICENSE for details.
#
#  Problems or suggestions?
#    Visit https://www.nest-simulator.org
#
#  Type 'nest.help()' to find out more about NEST.
#
# 2023-10-24 18:09:21,526 - WARNING - tvb_multiscale.core.neotraits - Field seems mutable and has a default value. Consider using a lambda as a value factory
#    attribute tvb_multiscale.tvb_nest.nest_models.node._NESTNodeCollection._nodes = Attr(field_type=(<class 'nest.lib.hl_api_types.NodeCollection'>, <class 'tvb_multiscale.tvb_nest.nest_models.server_client.node_collection.NodeCollection'>), default=NodeCollection(<empty>), required=False)
# 2023-10-24 18:09:21,526 - WARNING - tvb_multiscale.core.neotraits - Field seems mutable and has a default value. Consider using a lambda as a value factory
#    attribute tvb_multiscale.tvb_nest.nest_models.node._NESTNodeCollection._nodes = Attr(field_type=(<class 'nest.lib.hl_api_types.NodeCollection'>, <class 'tvb_multiscale.tvb_nest.nest_models.server_client.node_collection.NodeCollection'>), default=NodeCollection(<empty>), required=False)
# Available input (NEST->TVB update) / output (TVB->NEST coupling) interface models:
#
#  <enum 'TVBtoSpikeNetModels'>
# RATE =  0
# SPIKES =  1
# CURRENT =  2
#
#  <enum 'SpikeNetToTVBModels'>
# SPIKES =  0
# VOLTAGE =  1
#
#
# Available input (spikeNet->TVB update) / output (TVB->spikeNet coupling) transformer models:
#
#  <enum 'TVBtoSpikeNetTransformers'>
# RATE =  <class 'tvb_multiscale.core.interfaces.transformers.models.base.LinearRate'>
# SPIKES =  <class 'tvb_multiscale.core.interfaces.transformers.models.elephant.RatesToSpikesElephantPoisson'>
# SPIKES_SINGLE_INTERACTION =  <class 'tvb_multiscale.core.interfaces.transformers.models.elephant.RatesToSpikesElephantPoissonSingleInteraction'>
# SPIKES_MULTIPLE_INTERACTION =  <class 'tvb_multiscale.core.interfaces.transformers.models.elephant.RatesToSpikesElephantPoissonMultipleInteraction'>
# CURRENT =  <class 'tvb_multiscale.core.interfaces.transformers.models.base.LinearCurrent'>
#
#  DefaultTVBtoSpikeNetTransformers
# RATE =  RATE
# SPIKES =  SPIKES
# CURRENT =  CURRENT
#
#  <enum 'SpikeNetToTVBTransformers'>
# SPIKES =  <class 'tvb_multiscale.core.interfaces.transformers.models.elephant.ElephantSpikesHistogramRate'>
# SPIKES_TO_RATE =  <class 'tvb_multiscale.core.interfaces.transformers.models.elephant.ElephantSpikesRate'>
# SPIKES_TO_HIST =  <class 'tvb_multiscale.core.interfaces.transformers.models.elephant.ElephantSpikesHistogram'>
# SPIKES_TO_HIST_RATE =  <class 'tvb_multiscale.core.interfaces.transformers.models.elephant.ElephantSpikesHistogramRate'>
# POTENTIAL =  <class 'tvb_multiscale.core.interfaces.transformers.models.base.LinearPotential'>
#
#  DefaultSpikeNetToTVBTransformers
# SPIKES =  SPIKES
# POTENTIAL =  POTENTIAL
#
#
# Available input (NEST->TVB update) / output (TVB->NEST coupling) proxy models:
#
#  DefaultTVBtoNESTModels
# RATE =  RATE
# SPIKES =  SPIKES
# CURRENT =  CURRENT
#
#  <enum 'NESTInputProxyModels'>
# RATE =  <class 'tvb_multiscale.tvb_nest.interfaces.io.NESTInhomogeneousPoissonGeneratorSet'>
# RATE_TO_SPIKES =  <class 'tvb_multiscale.tvb_nest.interfaces.io.NESTParrotInhomogeneousPoissonGeneratorSet'>
# SPIKES =  <class 'tvb_multiscale.tvb_nest.interfaces.io.NESTSpikeGeneratorSet'>
# PARROT_SPIKES =  <class 'tvb_multiscale.tvb_nest.interfaces.io.NESTParrotSpikeGeneratorSet'>
# CURRENT =  <class 'tvb_multiscale.tvb_nest.interfaces.io.NESTStepCurrentGeneratorSet'>
#
#  <enum 'NESTOutputProxyModels'>
# SPIKES =  <class 'tvb_multiscale.tvb_nest.interfaces.io.NESTSpikeRecorderSet'>
# SPIKES_MEAN =  <class 'tvb_multiscale.tvb_nest.interfaces.io.NESTSpikeRecorderTotalSet'>
# POTENTIAL =  <class 'tvb_multiscale.tvb_nest.interfaces.io.NESTVoltmeterSet'>
# POTENTIAL_MEAN =  <class 'tvb_multiscale.tvb_nest.interfaces.io.NESTVoltmeterMeanSet'>
# POTENTIAL_TOTAL =  <class 'tvb_multiscale.tvb_nest.interfaces.io.NESTVoltmeterTotalSet'>
#
#  DefaultNESTtoTVBModels
# SPIKES =  SPIKES_MEAN
# POTENTIAL =  POTENTIAL_MEAN
#
#
# All basic transformer models:
#
#  <enum 'Transformers'>
# ELEMENTARY =  <class 'tvb_multiscale.core.interfaces.transformers.models.base.Elementary'>
# LINEAR =  <class 'tvb_multiscale.core.interfaces.transformers.models.base.Linear'>
# ELEPHANT_POISSON =  <class 'tvb_multiscale.core.interfaces.transformers.models.elephant.RatesToSpikesElephantPoisson'>
# ELEPHANT_POISSON_SINGLE_INTERACTION =  <class 'tvb_multiscale.core.interfaces.transformers.models.elephant.RatesToSpikesElephantPoissonSingleInteraction'>
# ELEPHANT_POISSON_MULTIPLE_INTERACTION =  <class 'tvb_multiscale.core.interfaces.transformers.models.elephant.RatesToSpikesElephantPoissonMultipleInteraction'>
# ELEPHANT_HISTOGRAM =  <class 'tvb_multiscale.core.interfaces.transformers.models.elephant.ElephantSpikesHistogram'>
# ELEPHANT_HISTOGRAM_RATE =  <class 'tvb_multiscale.core.interfaces.transformers.models.elephant.ElephantSpikesHistogramRate'>
# ELEPHANT_RATE =  <class 'tvb_multiscale.core.interfaces.transformers.models.elephant.ElephantSpikesRate'>
# LINEAR_RATE =  <class 'tvb_multiscale.core.interfaces.transformers.models.base.LinearRate'>
# LINEAR_CURRENT =  <class 'tvb_multiscale.core.interfaces.transformers.models.base.LinearCurrent'>
# LINEAR_POTENTIAL =  <class 'tvb_multiscale.core.interfaces.transformers.models.base.LinearPotential'>
# LINEAR_INTEGRATION_RATE =  <class 'tvb_multiscale.core.interfaces.transformers.models.integration.LinearIntegrationRate'>
# LINEAR_INTEGRATION_CURRENT =  <class 'tvb_multiscale.core.interfaces.transformers.models.integration.LinearIntegrationCurrent'>
# LINEAR_INTEGRATION_POTENTIAL =  <class 'tvb_multiscale.core.interfaces.transformers.models.integration.LinearIntegrationPotential'>
# ELEPHANT_SPIKES_HISTOGRAM_LINEAR_INTEGRATION =  <class 'tvb_multiscale.core.interfaces.transformers.models.integration.ElephantSpikesHistogramLinearIntegration'>
# ELEPHANT_SPIKES_HISTOGRAM_RATE_LINEAR_INTEGRATION =  <class 'tvb_multiscale.core.interfaces.transformers.models.integration.ElephantSpikesHistogramRateLinearIntegration'>
# ELEPHANT_SPIKES_RATE_LINEAR_INTEGRATION =  <class 'tvb_multiscale.core.interfaces.transformers.models.integration.ElephantSpikesRateLinearIntegration'>

# %%
from examples.parallel.tvb_nest.wilson_cowan.tvb_interface_config import configure_TVB_interfaces
from examples.parallel.tvb_nest.wilson_cowan.nest_interface_config import configure_NEST_interfaces
from examples.parallel.tvb_nest.wilson_cowan.transformers_config import \
    configure_TVBtoNEST_transformer_interfaces, configure_NESTtoTVB_transformer_interfaces

tvb_interface_builder = configure_TVB_interfaces(simulator=simulator, config=config, config_class=Config)

nest_interface_builder = configure_NEST_interfaces(config=config, config_class=Config)

tvb_to_nest_interface_builder = configure_TVBtoNEST_transformer_interfaces(config=config, config_class=Config)

nest_to_tvb_interface_builder = configure_NESTtoTVB_transformer_interfaces(config=config, config_class=Config)
# Out:
# output (TVB-> coupling) interfaces' configurations:
#
# [{'voi': array(['E'], dtype='<U1'), 'coupling_mode': 'TVB', 'proxy_inds': array([0, 1])}]
#
# input (TVB<- update) interfaces' configurations:
#
# [{'voi': array(['E'], dtype='<U1'), 'proxy_inds': array([0, 1])}, {'voi': array(['I'], dtype='<U1'), 'proxy_inds': array([0, 1])}]
#
# input (spikeNet <- coupling) interfaces' configurations:
#
# [{'populations': array(['E'], dtype='<U1'), 'coupling_mode': 'TVB', 'proxy_inds': array([0, 1]), 'proxy_model': 'RATE', 'spiking_proxy_inds': array([0, 1])}]
#
# output (spikeNet -> update) interfaces' configurations:
#
# [{'populations': array(['E'], dtype='<U1'), 'proxy_inds': array([0, 1]), 'proxy_model': 'SPIKES_MEAN'}, {'populations': array(['I'], dtype='<U1'), 'proxy_inds': array([0, 1]), 'proxy_model': 'SPIKES_MEAN'}]
#
# output (->Transformer-> coupling) interfaces' configurations:
#
# [{'transformer_model': 'RATE', 'transformer_params': {'scale_factor': array([250000.])}}]
#
# input (TVB<-...-Transformer<-...-spikeNet update) interfaces' configurations:
#
# [{'transformer_model': 'SPIKES_TO_HIST_RATE', 'transformer_params': {'scale_factor': array([1.e-06])}}, {'transformer_model': 'SPIKES_TO_HIST_RATE', 'transformer_params': {'scale_factor': array([1.e-06])}}]

# %% [markdown]
# ## BACKEND:
# ### - Build TVB and Spiking Network models and simulators
# ### - Build interfaces
# ### - Configure co-simulation

# %%
from tvb_multiscale.core.nrp.init.tvb import tvb_init


tvb_app = tvb_init(config, tvb_cosimulator_builder=build_tvb_simulator)
# Out:
# Starting App NRPTVBApp...
#
# Setting TVB LIBRARY_PROFILE...
# 2023-10-24 18:09:21,591 - INFO - tvb_multiscale.core.orchestrators.base -
# Building with App NRPTVBApp...
# 2023-10-24 18:09:21,591 - INFO - tvb_multiscale.core.orchestrators.base -
# Building with App NRPTVBApp...
#
# Building with App NRPTVBApp...
# 2023-10-24 18:09:21,592 - INFO - tvb_multiscale.core.orchestrators.base -
# Building interfaces' with builder TVBInterfaceBuilder of App NRPTVBApp...
# 2023-10-24 18:09:21,592 - INFO - tvb_multiscale.core.orchestrators.base -
# Building interfaces' with builder TVBInterfaceBuilder of App NRPTVBApp...
#
# Building interfaces' with builder TVBInterfaceBuilder of App NRPTVBApp...
# 2023-10-24 18:09:21,593 - INFO - tvb_multiscale.core.orchestrators.base -
# Building TVB CoSimulator with builder script build_tvb_simulator of App NRPTVBApp...
# 2023-10-24 18:09:21,593 - INFO - tvb_multiscale.core.orchestrators.base -
# Building TVB CoSimulator with builder script build_tvb_simulator of App NRPTVBApp...
#
# Building TVB CoSimulator with builder script build_tvb_simulator of App NRPTVBApp...
# 2023-10-24 18:09:21,610 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_parallel - There are no existing connections (i.e., with nonzero weights)!
# Setting minimum delay to 1 integrator time step = 0.1!.
# 2023-10-24 18:09:21,615 - ERROR - tvb_multiscale.core.tvb.cosimulator.cosimulator_parallel - Bad Simulator.integrator.noise.nsig shape: (2, 1, 1)
# 2023-10-24 18:09:21,627 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_parallel - There are no existing connections (i.e., with nonzero weights)!
# Setting minimum delay to 1 integrator time step = 0.1!.
# CoSimulatorParallel (
#   title ............................... 'CoSimulatorParallel gid: 0c34ffe1-6006-4bf8-85e1-fe16cf0ae7f0'
#   Type ................................ 'CoSimulatorParallel'
#   model ............................... WilsonCowan gid: dc1dcaf6-fbd5-480e-aca2-0eafc59c55ec
#   output_interfaces ................... None
#   input_interfaces .................... None
#   out_proxy_inds ...................... --------------------
#   shape ............................... (0,)
#   dtype ............................... int64
#   is empty ............................ True
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... False
#   voi ................................. --------------------
#   proxy_inds .......................... --------------------
#   synchronization_time ................ 0.0
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: bcf9f500-fc69-477f-8892-a19a8ee08f61
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: 712065c1-7e05-402b-a935-583050aca028
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: ccec411c-2e97-4ba0-9182-a340beaab91f
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 2, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   monitors[0] ......................... Raw gid: 2e5c2ca5-16f5-4999-94f9-0f062e48da8c
#   simulation_length ................... 1100.0
#   gid ................................. UUID('0c34ffe1-6006-4bf8-85e1-fe16cf0ae7f0')
# )
# Failed to summarize:
# monitors
# tuple
# 'NoneType' object has no attribute 'tolist'
# 2023-10-24 18:09:21,633 - INFO - tvb_multiscale.core.orchestrators.base -
# CoSimulatorParallel (
#   title ............................... 'CoSimulatorParallel gid: 0c34ffe1-6006-4bf8-85e1-fe16cf0ae7f0'
#   Type ................................ 'CoSimulatorParallel'
#   model ............................... WilsonCowan gid: dc1dcaf6-fbd5-480e-aca2-0eafc59c55ec
#   output_interfaces ................... None
#   input_interfaces .................... None
#   out_proxy_inds ...................... --------------------
#   shape ............................... (0,)
#   dtype ............................... float64
#   is empty ............................ True
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... False
#   voi ................................. --------------------
#   proxy_inds .......................... --------------------
#   cosim_monitors ...................... --------------------
#   synchronization_time ................ 0.0
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: bcf9f500-fc69-477f-8892-a19a8ee08f61
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: 712065c1-7e05-402b-a935-583050aca028
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: ccec411c-2e97-4ba0-9182-a340beaab91f
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 2, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 1100.0
#   gid ................................. UUID('0c34ffe1-6006-4bf8-85e1-fe16cf0ae7f0')
# )
# 2023-10-24 18:09:21,633 - INFO - tvb_multiscale.core.orchestrators.base -
# CoSimulatorParallel (
#   title ............................... 'CoSimulatorParallel gid: 0c34ffe1-6006-4bf8-85e1-fe16cf0ae7f0'
#   Type ................................ 'CoSimulatorParallel'
#   model ............................... WilsonCowan gid: dc1dcaf6-fbd5-480e-aca2-0eafc59c55ec
#   output_interfaces ................... None
#   input_interfaces .................... None
#   out_proxy_inds ...................... --------------------
#   shape ............................... (0,)
#   dtype ............................... float64
#   is empty ............................ True
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... False
#   voi ................................. --------------------
#   proxy_inds .......................... --------------------
#   cosim_monitors ...................... --------------------
#   synchronization_time ................ 0.0
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: bcf9f500-fc69-477f-8892-a19a8ee08f61
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: 712065c1-7e05-402b-a935-583050aca028
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: ccec411c-2e97-4ba0-9182-a340beaab91f
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 2, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 1100.0
#   gid ................................. UUID('0c34ffe1-6006-4bf8-85e1-fe16cf0ae7f0')
# )
#
# CoSimulatorParallel (
#   title ............................... 'CoSimulatorParallel gid: 0c34ffe1-6006-4bf8-85e1-fe16cf0ae7f0'
#   Type ................................ 'CoSimulatorParallel'
#   model ............................... WilsonCowan gid: dc1dcaf6-fbd5-480e-aca2-0eafc59c55ec
#   output_interfaces ................... None
#   input_interfaces .................... None
#   out_proxy_inds ...................... --------------------
#   shape ............................... (0,)
#   dtype ............................... float64
#   is empty ............................ True
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... False
#   voi ................................. --------------------
#   proxy_inds .......................... --------------------
#   cosim_monitors ...................... --------------------
#   synchronization_time ................ 0.0
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: bcf9f500-fc69-477f-8892-a19a8ee08f61
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: 712065c1-7e05-402b-a935-583050aca028
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: ccec411c-2e97-4ba0-9182-a340beaab91f
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 2, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 1100.0
#   gid ................................. UUID('0c34ffe1-6006-4bf8-85e1-fe16cf0ae7f0')
# )
# 2023-10-24 18:09:21,635 - ERROR - tvb_multiscale.core.tvb.cosimulator.cosimulator_parallel - Bad Simulator.integrator.noise.nsig shape: (2, 1, 1)
# 2023-10-24 18:09:21,647 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_parallel - There are no existing connections (i.e., with nonzero weights)!
# Setting minimum delay to 1 integrator time step = 0.1!.
# 2023-10-24 18:09:21,651 - INFO - tvb_multiscale.core.orchestrators.base -
# Instantiating interfaces' builder TVBInterfaceBuilder of App NRPTVBApp...
# 2023-10-24 18:09:21,651 - INFO - tvb_multiscale.core.orchestrators.base -
# Instantiating interfaces' builder TVBInterfaceBuilder of App NRPTVBApp...
#
# Instantiating interfaces' builder TVBInterfaceBuilder of App NRPTVBApp...
# 2023-10-24 18:09:21,652 - INFO - tvb_multiscale.core.orchestrators.base -
# Configuring interfaces' builder TVBInterfaceBuilder of App NRPTVBApp...
# 2023-10-24 18:09:21,652 - INFO - tvb_multiscale.core.orchestrators.base -
# Configuring interfaces' builder TVBInterfaceBuilder of App NRPTVBApp...
#
# Configuring interfaces' builder TVBInterfaceBuilder of App NRPTVBApp...
# 2023-10-24 18:09:21,654 - INFO - tvb_multiscale.core.orchestrators.base -
# Reading interfaces' configurations from files...
# 2023-10-24 18:09:21,654 - INFO - tvb_multiscale.core.orchestrators.base -
# Reading interfaces' configurations from files...
#
# Reading interfaces' configurations from files...
# loading all interfaces
# 2023-10-24 18:09:21,658 - ERROR - tvb_multiscale.core.tvb.cosimulator.cosimulator_parallel - Bad Simulator.integrator.noise.nsig shape: (2, 1, 1)
# 2023-10-24 18:09:21,670 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_parallel - There are no existing connections (i.e., with nonzero weights)!
# Setting minimum delay to 1 integrator time step = 0.1!.
# 2023-10-24 18:09:21,674 - INFO - tvb_multiscale.core.orchestrators.base -
# TVBOutputInterfaces (
#   title ............................. 'TVBOutputInterfaces gid: 8e73ad5e-8e76-4b6a-ab24-4c842a342ca4'
#   Type .............................. 'TVBOutputInterfaces'
#   interfaces[0] ..................... '--------------------'
#   interfaces[0].title ............... 'TVBOutputInterface gid: 24cd0316-4266-42dd-82b3-2d13a51e6099'
#   interfaces[0].Type ................ 'TVBOutputInterface'
#   interfaces[0].monitor_ind ......... 0
#   interfaces[0].cvoi ................ --------------------
#   interfaces[0].cvoi: shape ......... (1,)
#   interfaces[0].cvoi: dtype ......... int64
#   interfaces[0].cvoi: values ........ 0
#   interfaces[0].coupling_mode ....... 'TVB'
#   interfaces[0].proxy_inds .......... --------------------
#   interfaces[0].proxy_inds: shape ... (2,)
#   interfaces[0].proxy_inds: dtype ... int64
#   interfaces[0].proxy_inds: values .. [[0, 1]]
#   interfaces[0].voi ................. --------------------
#   interfaces[0].voi: shape .......... (1,)
#   interfaces[0].voi: dtype .......... int64
#   interfaces[0].voi: values ......... 0
#   interfaces[0].voi_labels .......... --------------------
#   interfaces[0].voi_labels: shape ... (1,)
#   interfaces[0].voi_labels: dtype ... <U128
#   interfaces[0].voi_labels: values .. E
#   interfaces[0].model ............... ''
#   interfaces[0].gid ................. UUID('24cd0316-4266-42dd-82b3-2d13a51e6099')
#   interfaces[0].n_voi ............... 1
#   interfaces[0].number_of_proxy_nodes  2
#   dt ................................ 0.1
#   min_idelay ........................ 36
#   synchronization_time .............. 3.6
#   synchronization_n_step ............ 36
#   gid ............................... UUID('8e73ad5e-8e76-4b6a-ab24-4c842a342ca4')
#   n_vois ............................ 1
#   voi ............................... --------------------
#   voi: shape ........................ (1,)
#   voi: dtype ........................ int64
#   voi: values ....................... 0
#   voi_labels ........................ --------------------
#   voi_labels: shape ................. (1,)
#   voi_labels: dtype ................. <U1
#   voi_labels: values ................ E
#   number_of_proxy_nodes ............. 2
#   number_of_interfaces .............. 1
# )
# 2023-10-24 18:09:21,674 - INFO - tvb_multiscale.core.orchestrators.base -
# TVBOutputInterfaces (
#   title ............................. 'TVBOutputInterfaces gid: 8e73ad5e-8e76-4b6a-ab24-4c842a342ca4'
#   Type .............................. 'TVBOutputInterfaces'
#   interfaces[0] ..................... '--------------------'
#   interfaces[0].title ............... 'TVBOutputInterface gid: 24cd0316-4266-42dd-82b3-2d13a51e6099'
#   interfaces[0].Type ................ 'TVBOutputInterface'
#   interfaces[0].monitor_ind ......... 0
#   interfaces[0].cvoi ................ --------------------
#   interfaces[0].cvoi: shape ......... (1,)
#   interfaces[0].cvoi: dtype ......... int64
#   interfaces[0].cvoi: values ........ 0
#   interfaces[0].coupling_mode ....... 'TVB'
#   interfaces[0].proxy_inds .......... --------------------
#   interfaces[0].proxy_inds: shape ... (2,)
#   interfaces[0].proxy_inds: dtype ... int64
#   interfaces[0].proxy_inds: values .. [[0, 1]]
#   interfaces[0].voi ................. --------------------
#   interfaces[0].voi: shape .......... (1,)
#   interfaces[0].voi: dtype .......... int64
#   interfaces[0].voi: values ......... 0
#   interfaces[0].voi_labels .......... --------------------
#   interfaces[0].voi_labels: shape ... (1,)
#   interfaces[0].voi_labels: dtype ... <U128
#   interfaces[0].voi_labels: values .. E
#   interfaces[0].model ............... ''
#   interfaces[0].gid ................. UUID('24cd0316-4266-42dd-82b3-2d13a51e6099')
#   interfaces[0].n_voi ............... 1
#   interfaces[0].number_of_proxy_nodes  2
#   dt ................................ 0.1
#   min_idelay ........................ 36
#   synchronization_time .............. 3.6
#   synchronization_n_step ............ 36
#   gid ............................... UUID('8e73ad5e-8e76-4b6a-ab24-4c842a342ca4')
#   n_vois ............................ 1
#   voi ............................... --------------------
#   voi: shape ........................ (1,)
#   voi: dtype ........................ int64
#   voi: values ....................... 0
#   voi_labels ........................ --------------------
#   voi_labels: shape ................. (1,)
#   voi_labels: dtype ................. <U1
#   voi_labels: values ................ E
#   number_of_proxy_nodes ............. 2
#   number_of_interfaces .............. 1
# )
#
# TVBOutputInterfaces (
#   title ............................. 'TVBOutputInterfaces gid: 8e73ad5e-8e76-4b6a-ab24-4c842a342ca4'
#   Type .............................. 'TVBOutputInterfaces'
#   interfaces[0] ..................... '--------------------'
#   interfaces[0].title ............... 'TVBOutputInterface gid: 24cd0316-4266-42dd-82b3-2d13a51e6099'
#   interfaces[0].Type ................ 'TVBOutputInterface'
#   interfaces[0].monitor_ind ......... 0
#   interfaces[0].cvoi ................ --------------------
#   interfaces[0].cvoi: shape ......... (1,)
#   interfaces[0].cvoi: dtype ......... int64
#   interfaces[0].cvoi: values ........ 0
#   interfaces[0].coupling_mode ....... 'TVB'
#   interfaces[0].proxy_inds .......... --------------------
#   interfaces[0].proxy_inds: shape ... (2,)
#   interfaces[0].proxy_inds: dtype ... int64
#   interfaces[0].proxy_inds: values .. [[0, 1]]
#   interfaces[0].voi ................. --------------------
#   interfaces[0].voi: shape .......... (1,)
#   interfaces[0].voi: dtype .......... int64
#   interfaces[0].voi: values ......... 0
#   interfaces[0].voi_labels .......... --------------------
#   interfaces[0].voi_labels: shape ... (1,)
#   interfaces[0].voi_labels: dtype ... <U128
#   interfaces[0].voi_labels: values .. E
#   interfaces[0].model ............... ''
#   interfaces[0].gid ................. UUID('24cd0316-4266-42dd-82b3-2d13a51e6099')
#   interfaces[0].n_voi ............... 1
#   interfaces[0].number_of_proxy_nodes  2
#   dt ................................ 0.1
#   min_idelay ........................ 36
#   synchronization_time .............. 3.6
#   synchronization_n_step ............ 36
#   gid ............................... UUID('8e73ad5e-8e76-4b6a-ab24-4c842a342ca4')
#   n_vois ............................ 1
#   voi ............................... --------------------
#   voi: shape ........................ (1,)
#   voi: dtype ........................ int64
#   voi: values ....................... 0
#   voi_labels ........................ --------------------
#   voi_labels: shape ................. (1,)
#   voi_labels: dtype ................. <U1
#   voi_labels: values ................ E
#   number_of_proxy_nodes ............. 2
#   number_of_interfaces .............. 1
# )
# 2023-10-24 18:09:21,676 - INFO - tvb_multiscale.core.orchestrators.base -
# TVBInputInterfaces (
#   title ............................. 'TVBInputInterfaces gid: c900d7ac-532f-4a77-9c68-4985640009b8'
#   Type .............................. 'TVBInputInterfaces'
#   interfaces[0] ..................... '--------------------'
#   interfaces[0].title ............... 'TVBInputInterface gid: c54313ba-1eeb-4682-80b9-6ed7f9089ec9'
#   interfaces[0].Type ................ 'TVBInputInterface'
#   interfaces[0].proxy_inds .......... --------------------
#   interfaces[0].proxy_inds: shape ... (2,)
#   interfaces[0].proxy_inds: dtype ... int64
#   interfaces[0].proxy_inds: values .. [[0, 1]]
#   interfaces[0].voi ................. --------------------
#   interfaces[0].voi: shape .......... (1,)
#   interfaces[0].voi: dtype .......... int64
#   interfaces[0].voi: values ......... 0
#   interfaces[0].voi_labels .......... --------------------
#   interfaces[0].voi_labels: shape ... (1,)
#   interfaces[0].voi_labels: dtype ... <U128
#   interfaces[0].voi_labels: values .. E
#   interfaces[0].model ............... ''
#   interfaces[0].gid ................. UUID('c54313ba-1eeb-4682-80b9-6ed7f9089ec9')
#   interfaces[0].n_voi ............... 1
#   interfaces[0].number_of_proxy_nodes  2
#   interfaces[1] ..................... '--------------------'
#   interfaces[1].title ............... 'TVBInputInterface gid: c160409a-18d6-4e17-b27e-545fba6d830e'
#   interfaces[1].Type ................ 'TVBInputInterface'
#   interfaces[1].proxy_inds .......... --------------------
#   interfaces[1].proxy_inds: shape ... (2,)
#   interfaces[1].proxy_inds: dtype ... int64
#   interfaces[1].proxy_inds: values .. [[0, 1]]
#   interfaces[1].voi ................. --------------------
#   interfaces[1].voi: shape .......... (1,)
#   interfaces[1].voi: dtype .......... int64
#   interfaces[1].voi: values ......... 1
#   interfaces[1].voi_labels .......... --------------------
#   interfaces[1].voi_labels: shape ... (1,)
#   interfaces[1].voi_labels: dtype ... <U128
#   interfaces[1].voi_labels: values .. I
#   interfaces[1].model ............... ''
#   interfaces[1].gid ................. UUID('c160409a-18d6-4e17-b27e-545fba6d830e')
#   interfaces[1].n_voi ............... 1
#   interfaces[1].number_of_proxy_nodes  2
#   synchronization_time .............. 3.6
#   synchronization_n_step ............ 36
#   gid ............................... UUID('c900d7ac-532f-4a77-9c68-4985640009b8')
#   n_vois ............................ 2
#   voi ............................... --------------------
#   voi: shape ........................ (2,)
#   voi: dtype ........................ int64
#   voi: values ....................... [[0, 1]]
#   voi_labels ........................ --------------------
#   voi_labels: shape ................. (2,)
#   voi_labels: dtype ................. <U1
#   voi_labels: values ................ ['E' 'I']
#   number_of_proxy_nodes ............. 2
#   number_of_interfaces .............. 2
# )
# 2023-10-24 18:09:21,676 - INFO - tvb_multiscale.core.orchestrators.base -
# TVBInputInterfaces (
#   title ............................. 'TVBInputInterfaces gid: c900d7ac-532f-4a77-9c68-4985640009b8'
#   Type .............................. 'TVBInputInterfaces'
#   interfaces[0] ..................... '--------------------'
#   interfaces[0].title ............... 'TVBInputInterface gid: c54313ba-1eeb-4682-80b9-6ed7f9089ec9'
#   interfaces[0].Type ................ 'TVBInputInterface'
#   interfaces[0].proxy_inds .......... --------------------
#   interfaces[0].proxy_inds: shape ... (2,)
#   interfaces[0].proxy_inds: dtype ... int64
#   interfaces[0].proxy_inds: values .. [[0, 1]]
#   interfaces[0].voi ................. --------------------
#   interfaces[0].voi: shape .......... (1,)
#   interfaces[0].voi: dtype .......... int64
#   interfaces[0].voi: values ......... 0
#   interfaces[0].voi_labels .......... --------------------
#   interfaces[0].voi_labels: shape ... (1,)
#   interfaces[0].voi_labels: dtype ... <U128
#   interfaces[0].voi_labels: values .. E
#   interfaces[0].model ............... ''
#   interfaces[0].gid ................. UUID('c54313ba-1eeb-4682-80b9-6ed7f9089ec9')
#   interfaces[0].n_voi ............... 1
#   interfaces[0].number_of_proxy_nodes  2
#   interfaces[1] ..................... '--------------------'
#   interfaces[1].title ............... 'TVBInputInterface gid: c160409a-18d6-4e17-b27e-545fba6d830e'
#   interfaces[1].Type ................ 'TVBInputInterface'
#   interfaces[1].proxy_inds .......... --------------------
#   interfaces[1].proxy_inds: shape ... (2,)
#   interfaces[1].proxy_inds: dtype ... int64
#   interfaces[1].proxy_inds: values .. [[0, 1]]
#   interfaces[1].voi ................. --------------------
#   interfaces[1].voi: shape .......... (1,)
#   interfaces[1].voi: dtype .......... int64
#   interfaces[1].voi: values ......... 1
#   interfaces[1].voi_labels .......... --------------------
#   interfaces[1].voi_labels: shape ... (1,)
#   interfaces[1].voi_labels: dtype ... <U128
#   interfaces[1].voi_labels: values .. I
#   interfaces[1].model ............... ''
#   interfaces[1].gid ................. UUID('c160409a-18d6-4e17-b27e-545fba6d830e')
#   interfaces[1].n_voi ............... 1
#   interfaces[1].number_of_proxy_nodes  2
#   synchronization_time .............. 3.6
#   synchronization_n_step ............ 36
#   gid ............................... UUID('c900d7ac-532f-4a77-9c68-4985640009b8')
#   n_vois ............................ 2
#   voi ............................... --------------------
#   voi: shape ........................ (2,)
#   voi: dtype ........................ int64
#   voi: values ....................... [[0, 1]]
#   voi_labels ........................ --------------------
#   voi_labels: shape ................. (2,)
#   voi_labels: dtype ................. <U1
#   voi_labels: values ................ ['E' 'I']
#   number_of_proxy_nodes ............. 2
#   number_of_interfaces .............. 2
# )
#
# TVBInputInterfaces (
#   title ............................. 'TVBInputInterfaces gid: c900d7ac-532f-4a77-9c68-4985640009b8'
#   Type .............................. 'TVBInputInterfaces'
#   interfaces[0] ..................... '--------------------'
#   interfaces[0].title ............... 'TVBInputInterface gid: c54313ba-1eeb-4682-80b9-6ed7f9089ec9'
#   interfaces[0].Type ................ 'TVBInputInterface'
#   interfaces[0].proxy_inds .......... --------------------
#   interfaces[0].proxy_inds: shape ... (2,)
#   interfaces[0].proxy_inds: dtype ... int64
#   interfaces[0].proxy_inds: values .. [[0, 1]]
#   interfaces[0].voi ................. --------------------
#   interfaces[0].voi: shape .......... (1,)
#   interfaces[0].voi: dtype .......... int64
#   interfaces[0].voi: values ......... 0
#   interfaces[0].voi_labels .......... --------------------
#   interfaces[0].voi_labels: shape ... (1,)
#   interfaces[0].voi_labels: dtype ... <U128
#   interfaces[0].voi_labels: values .. E
#   interfaces[0].model ............... ''
#   interfaces[0].gid ................. UUID('c54313ba-1eeb-4682-80b9-6ed7f9089ec9')
#   interfaces[0].n_voi ............... 1
#   interfaces[0].number_of_proxy_nodes  2
#   interfaces[1] ..................... '--------------------'
#   interfaces[1].title ............... 'TVBInputInterface gid: c160409a-18d6-4e17-b27e-545fba6d830e'
#   interfaces[1].Type ................ 'TVBInputInterface'
#   interfaces[1].proxy_inds .......... --------------------
#   interfaces[1].proxy_inds: shape ... (2,)
#   interfaces[1].proxy_inds: dtype ... int64
#   interfaces[1].proxy_inds: values .. [[0, 1]]
#   interfaces[1].voi ................. --------------------
#   interfaces[1].voi: shape .......... (1,)
#   interfaces[1].voi: dtype .......... int64
#   interfaces[1].voi: values ......... 1
#   interfaces[1].voi_labels .......... --------------------
#   interfaces[1].voi_labels: shape ... (1,)
#   interfaces[1].voi_labels: dtype ... <U128
#   interfaces[1].voi_labels: values .. I
#   interfaces[1].model ............... ''
#   interfaces[1].gid ................. UUID('c160409a-18d6-4e17-b27e-545fba6d830e')
#   interfaces[1].n_voi ............... 1
#   interfaces[1].number_of_proxy_nodes  2
#   synchronization_time .............. 3.6
#   synchronization_n_step ............ 36
#   gid ............................... UUID('c900d7ac-532f-4a77-9c68-4985640009b8')
#   n_vois ............................ 2
#   voi ............................... --------------------
#   voi: shape ........................ (2,)
#   voi: dtype ........................ int64
#   voi: values ....................... [[0, 1]]
#   voi_labels ........................ --------------------
#   voi_labels: shape ................. (2,)
#   voi_labels: dtype ................. <U1
#   voi_labels: values ................ ['E' 'I']
#   number_of_proxy_nodes ............. 2
#   number_of_interfaces .............. 2
# )
# 2023-10-24 18:09:21,677 - INFO - tvb_multiscale.core.orchestrators.base -
# Configuring simulation with App NRPTVBApp...
# 2023-10-24 18:09:21,677 - INFO - tvb_multiscale.core.orchestrators.base -
# Configuring simulation with App NRPTVBApp...
#
# Configuring simulation with App NRPTVBApp...
# 2023-10-24 18:09:21,679 - ERROR - tvb_multiscale.core.tvb.cosimulator.cosimulator_parallel - Bad Simulator.integrator.noise.nsig shape: (2, 1, 1)
# 2023-10-24 18:09:21,690 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_parallel - There are no existing connections (i.e., with nonzero weights)!
# Setting minimum delay to 1 integrator time step = 0.1!.
# Failed to summarize:
# monitors
# tuple
# 'NoneType' object has no attribute 'tolist'
# 2023-10-24 18:09:21,698 - INFO - tvb_multiscale.core.orchestrators.base -
# CoSimulatorParallel (
#   title ............................... 'CoSimulatorParallel gid: 0c34ffe1-6006-4bf8-85e1-fe16cf0ae7f0'
#   Type ................................ 'CoSimulatorParallel'
#   model ............................... WilsonCowan gid: dc1dcaf6-fbd5-480e-aca2-0eafc59c55ec
#   output_interfaces ................... TVBOutputInterfaces gid: 8e73ad5e-8e76-4b6a-ab24-4c842a342ca4
#   input_interfaces .................... TVBInputInterfaces gid: c900d7ac-532f-4a77-9c68-4985640009b8
#   out_proxy_inds ...................... --------------------
#   out_proxy_inds: shape ............... (2,)
#   out_proxy_inds: dtype ............... int64
#   out_proxy_inds: values .............. [[0, 1]]
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... True
#   voi ................................. --------------------
#   voi: shape .......................... (2,)
#   voi: dtype .......................... int64
#   voi: values ......................... [[0, 1]]
#   proxy_inds .......................... --------------------
#   proxy_inds: shape ................... (2,)
#   proxy_inds: dtype ................... int64
#   proxy_inds: values .................. [[0, 1]]
#   cosim_monitors ...................... --------------------
#   cosim_monitors: shape ............... (1,)
#   cosim_monitors: dtype ............... object
#   cosim_monitors: values .............. CosimCoupling(period=0.100000, voi=[0])
#   synchronization_time ................ 3.6
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: bcf9f500-fc69-477f-8892-a19a8ee08f61
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: 712065c1-7e05-402b-a935-583050aca028
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: ccec411c-2e97-4ba0-9182-a340beaab91f
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 2, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 1101.6000000000001
#   gid ................................. UUID('0c34ffe1-6006-4bf8-85e1-fe16cf0ae7f0')
# )
# 2023-10-24 18:09:21,698 - INFO - tvb_multiscale.core.orchestrators.base -
# CoSimulatorParallel (
#   title ............................... 'CoSimulatorParallel gid: 0c34ffe1-6006-4bf8-85e1-fe16cf0ae7f0'
#   Type ................................ 'CoSimulatorParallel'
#   model ............................... WilsonCowan gid: dc1dcaf6-fbd5-480e-aca2-0eafc59c55ec
#   output_interfaces ................... TVBOutputInterfaces gid: 8e73ad5e-8e76-4b6a-ab24-4c842a342ca4
#   input_interfaces .................... TVBInputInterfaces gid: c900d7ac-532f-4a77-9c68-4985640009b8
#   out_proxy_inds ...................... --------------------
#   out_proxy_inds: shape ............... (2,)
#   out_proxy_inds: dtype ............... int64
#   out_proxy_inds: values .............. [[0, 1]]
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... True
#   voi ................................. --------------------
#   voi: shape .......................... (2,)
#   voi: dtype .......................... int64
#   voi: values ......................... [[0, 1]]
#   proxy_inds .......................... --------------------
#   proxy_inds: shape ................... (2,)
#   proxy_inds: dtype ................... int64
#   proxy_inds: values .................. [[0, 1]]
#   cosim_monitors ...................... --------------------
#   cosim_monitors: shape ............... (1,)
#   cosim_monitors: dtype ............... object
#   cosim_monitors: values .............. CosimCoupling(period=0.100000, voi=[0])
#   synchronization_time ................ 3.6
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: bcf9f500-fc69-477f-8892-a19a8ee08f61
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: 712065c1-7e05-402b-a935-583050aca028
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: ccec411c-2e97-4ba0-9182-a340beaab91f
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 2, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 1101.6000000000001
#   gid ................................. UUID('0c34ffe1-6006-4bf8-85e1-fe16cf0ae7f0')
# )
#
# CoSimulatorParallel (
#   title ............................... 'CoSimulatorParallel gid: 0c34ffe1-6006-4bf8-85e1-fe16cf0ae7f0'
#   Type ................................ 'CoSimulatorParallel'
#   model ............................... WilsonCowan gid: dc1dcaf6-fbd5-480e-aca2-0eafc59c55ec
#   output_interfaces ................... TVBOutputInterfaces gid: 8e73ad5e-8e76-4b6a-ab24-4c842a342ca4
#   input_interfaces .................... TVBInputInterfaces gid: c900d7ac-532f-4a77-9c68-4985640009b8
#   out_proxy_inds ...................... --------------------
#   out_proxy_inds: shape ............... (2,)
#   out_proxy_inds: dtype ............... int64
#   out_proxy_inds: values .............. [[0, 1]]
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... True
#   voi ................................. --------------------
#   voi: shape .......................... (2,)
#   voi: dtype .......................... int64
#   voi: values ......................... [[0, 1]]
#   proxy_inds .......................... --------------------
#   proxy_inds: shape ................... (2,)
#   proxy_inds: dtype ................... int64
#   proxy_inds: values .................. [[0, 1]]
#   cosim_monitors ...................... --------------------
#   cosim_monitors: shape ............... (1,)
#   cosim_monitors: dtype ............... object
#   cosim_monitors: values .............. CosimCoupling(period=0.100000, voi=[0])
#   synchronization_time ................ 3.6
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: bcf9f500-fc69-477f-8892-a19a8ee08f61
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: 712065c1-7e05-402b-a935-583050aca028
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: ccec411c-2e97-4ba0-9182-a340beaab91f
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 2, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 1101.6000000000001
#   gid ................................. UUID('0c34ffe1-6006-4bf8-85e1-fe16cf0ae7f0')
# )

# %%
from tvb_multiscale.core.nrp.init.spikeNet import nest_init

spikeNet_app = nest_init(config, spiking_network_builder=build_nest_network)
# Out:
# Starting App NESTNRPApp...
# 2023-10-24 18:09:21,712 - INFO - tvb_multiscale.core.orchestrators.base -
# Building with App NESTNRPApp...
# 2023-10-24 18:09:21,712 - INFO - tvb_multiscale.core.orchestrators.base -
# Building with App NESTNRPApp...
# 2023-10-24 18:09:21,712 - INFO - tvb_multiscale.core.orchestrators.base -
# Building with App NESTNRPApp...
#
# Building with App NESTNRPApp...
# 2023-10-24 18:09:21,714 - INFO - tvb_multiscale.core.orchestrators.base -
# Building Spiking Network with builder script build_nest_network of App NESTNRPApp...
# 2023-10-24 18:09:21,714 - INFO - tvb_multiscale.core.orchestrators.base -
# Building Spiking Network with builder script build_nest_network of App NESTNRPApp...
# 2023-10-24 18:09:21,714 - INFO - tvb_multiscale.core.orchestrators.base -
# Building Spiking Network with builder script build_nest_network of App NESTNRPApp...
#
# Building Spiking Network with builder script build_nest_network of App NESTNRPApp...
# Building NESTNetwork...
# 2023-10-24 18:09:21,719 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_nest.nest_models.network.NESTNetwork'> created!
# 2023-10-24 18:09:21,719 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_nest.nest_models.network.NESTNetwork'> created!
# 2023-10-24 18:09:21,719 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_nest.nest_models.network.NESTNetwork'> created!
# 2023-10-24 18:09:21,719 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_nest.nest_models.network.NESTNetwork'> created!
# 2023-10-24 18:09:21,719 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_nest.nest_models.network.NESTNetwork'> created!
# 2023-10-24 18:09:21,719 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_nest.nest_models.network.NESTNetwork'> created!
# 2023-10-24 18:09:21,719 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_nest.nest_models.network.NESTNetwork'> created!
# 2023-10-24 18:09:21,719 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_nest.nest_models.network.NESTNetwork'> created!
# 2023-10-24 18:09:21,719 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_nest.nest_models.network.NESTNetwork'> created!
# 2023-10-24 18:09:21,719 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_nest.nest_models.network.NESTNetwork'> created!
#
# ...created: OrderedDict([('title', "'NESTPopulation gid: 30361177-86b9-4a00-ab5a-1b69135703cc'"), ('Type', "'NESTPopulation'"), ('_nodes', 'NodeCollection(metadata=None, model=iaf_cond_alpha, size=100, first=1, last=100)'), ('label', "'E'"), ('model', "'NESTPopulation'"), ('brain_region', "'bankssts_L'"), ('gid', "UUID('30361177-86b9-4a00-ab5a-1b69135703cc')"), ('number_of_nodes', '100'), ('nodes', 'NodeCollection(metadata=None, model=iaf_cond_alpha, size=100, first=1, last=100)')])...
#
# ...created: OrderedDict([('title', "'NESTPopulation gid: 469c452c-307a-4430-b5c4-ff55ac7ffea5'"), ('Type', "'NESTPopulation'"), ('_nodes', 'NodeCollection(metadata=None, model=iaf_cond_alpha, size=100, first=101, last=200)'), ('label', "'I'"), ('model', "'NESTPopulation'"), ('brain_region', "'bankssts_L'"), ('gid', "UUID('469c452c-307a-4430-b5c4-ff55ac7ffea5')"), ('number_of_nodes', '100'), ('nodes', 'NodeCollection(metadata=None, model=iaf_cond_alpha, size=100, first=101, last=200)')])...
#
# ...created: OrderedDict([('title', "'NESTPopulation gid: 41b2ac83-9f9e-4917-8321-b95b3633590e'"), ('Type', "'NESTPopulation'"), ('_nodes', 'NodeCollection(metadata=None, model=iaf_cond_alpha, size=100, first=201, last=300)'), ('label', "'E'"), ('model', "'NESTPopulation'"), ('brain_region', "'bankssts_R'"), ('gid', "UUID('41b2ac83-9f9e-4917-8321-b95b3633590e')"), ('number_of_nodes', '100'), ('nodes', 'NodeCollection(metadata=None, model=iaf_cond_alpha, size=100, first=201, last=300)')])...
#
# ...created: OrderedDict([('title', "'NESTPopulation gid: 31202f13-8fa3-4881-948e-2899bc7289c2'"), ('Type', "'NESTPopulation'"), ('_nodes', 'NodeCollection(metadata=None, model=iaf_cond_alpha, size=100, first=301, last=400)'), ('label', "'I'"), ('model', "'NESTPopulation'"), ('brain_region', "'bankssts_R'"), ('gid', "UUID('31202f13-8fa3-4881-948e-2899bc7289c2')"), ('number_of_nodes', '100'), ('nodes', 'NodeCollection(metadata=None, model=iaf_cond_alpha, size=100, first=301, last=400)')])...
#
# ...connected populations E -> E in brain region bankssts_L...
#
# ...connected populations E -> I in brain region bankssts_L...
#
# ...connected populations I -> E in brain region bankssts_L...
#
# ...connected populations I -> I in brain region bankssts_L...
#
# ...connected populations E - bankssts_L -> [E, I] - bankssts_R...
#
# ...connected populations E - bankssts_R -> [E, I] - bankssts_L...
#
# ...connected populations E -> E in brain region bankssts_R...
#
# ...connected populations E -> I in brain region bankssts_R...
#
# ...connected populations I -> E in brain region bankssts_R...
#
# ...connected populations I -> I in brain region bankssts_R...
# 2023-10-24 18:09:21,740 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model spike_recorder for E created!
# 2023-10-24 18:09:21,740 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model spike_recorder for E created!
# 2023-10-24 18:09:21,742 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model multimeter for Excitatory created!
# 2023-10-24 18:09:21,742 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model multimeter for Excitatory created!
#
# ...created spike_recorder device for population E in brain region bankssts_L...
#
# ...created multimeter device for population E in brain region bankssts_L...
#
# ...created spike_recorder device for population E in brain region bankssts_R...
#
# ...created multimeter device for population E in brain region bankssts_R...
# 2023-10-24 18:09:21,749 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model spike_recorder for I created!
# 2023-10-24 18:09:21,749 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model spike_recorder for I created!
# 2023-10-24 18:09:21,751 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model multimeter for Inhibitory created!
# 2023-10-24 18:09:21,751 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model multimeter for Inhibitory created!
#
# ...created spike_recorder device for population I in brain region bankssts_L...
#
# ...created multimeter device for population I in brain region bankssts_L...
#
# ...created spike_recorder device for population I in brain region bankssts_R...
#
# ...created multimeter device for population I in brain region bankssts_R...
# 2023-10-24 18:09:21,757 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model poisson_generator for Stimulus created!
# 2023-10-24 18:09:21,757 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model poisson_generator for Stimulus created!
#
# ...created poisson_generator device for population E in brain region bankssts_L...
#
# ...created poisson_generator device for population E in brain region bankssts_R...
# NESTNetwork (
#   title .......................................................................... 'NESTNetwork gid: bebeac52-45f0-4ec3-88ff-9e6192aa0860'
#   Type ........................................................................... 'NESTNetwork'
#   config ......................................................................... '--------------------'
#   config.title ................................................................... 'Config gid: fdeaeb31-f174-4422-a90f-4f455f0b0822'
#   config.Type .................................................................... 'Config'
#   config.gid ..................................................................... UUID('fdeaeb31-f174-4422-a90f-4f455f0b0822')
#   brain_regions .................................................................. '--------------------'
#   brain_regions.title ............................................................ 'NESTBrain gid: 8754e1de-cb4a-4fda-9eba-dbb950036889'
#   brain_regions.Type ............................................................. 'NESTBrain'
#   brain_regions.gid .............................................................. UUID('8754e1de-cb4a-4fda-9eba-dbb950036889')
#   brain_regions.label ............................................................ ''
#   brain_regions.size ............................................................. 2
#   brain_regions.Regions .......................................................... --------------------
#   brain_regions.Regions: shape ................................................... (2,)
#   brain_regions.Regions: dtype ................................................... <U10
#   brain_regions.Regions: values .................................................. ['bankssts_L' 'bankssts_R']
#   brain_regions.bankssts_L ....................................................... '--------------------'
#   brain_regions[bankssts_L].title ................................................ 'NESTRegionNode gid: a77cb4c3-48f1-4d57-9293-2a10d98667fa'
#   brain_regions[bankssts_L].Type ................................................. 'NESTRegionNode'
#   brain_regions[bankssts_L].gid .................................................. UUID('a77cb4c3-48f1-4d57-9293-2a10d98667fa')
#   brain_regions[bankssts_L].label ................................................ 'bankssts_L'
#   brain_regions[bankssts_L].size ................................................. 2
#   brain_regions[bankssts_L].Populations .......................................... --------------------
#   brain_regions[bankssts_L].Populations: shape ................................... (2,)
#   brain_regions[bankssts_L].Populations: dtype ................................... <U1
#   brain_regions[bankssts_L].Populations: values .................................. ['E' 'I']
#   brain_regions[bankssts_L].E .................................................... '--------------------'
#   brain_regions[bankssts_L][E].title ............................................. 'NESTPopulation gid: 30361177-86b9-4a00-ab5a-1b69135703cc'
#   brain_regions[bankssts_L][E].Type .............................................. 'NESTPopulation'
#   brain_regions[bankssts_L][E]._nodes ............................................ NodeCollection(metadata=None, model=iaf_cond_alpha, size=100, first=1, last=100)
#   brain_regions[bankssts_L][E].label ............................................. 'E'
#   brain_regions[bankssts_L][E].model ............................................. 'NESTPopulation'
#   brain_regions[bankssts_L][E].brain_region ...................................... 'bankssts_L'
#   brain_regions[bankssts_L][E].gid ............................................... UUID('30361177-86b9-4a00-ab5a-1b69135703cc')
#   brain_regions[bankssts_L][E].number_of_nodes ................................... 100
#   brain_regions[bankssts_L][E].nodes ............................................. NodeCollection(metadata=None, model=iaf_cond_alpha, size=100, first=1, last=100)
#   brain_regions[bankssts_L][E].gids .............................................. --------------------
#   brain_regions[bankssts_L][E].gids: shape ....................................... (100,)
#   brain_regions[bankssts_L][E].gids: dtype ....................................... int64
#   brain_regions[bankssts_L][E].gids: unique_values ............................... [[1, 100]]
#   brain_regions[bankssts_L][E].parameters[archiver_length] ....................... --------------------
#   brain_regions[bankssts_L][E].parameters[archiver_length]: shape ................ (100,)
#   brain_regions[bankssts_L][E].parameters[archiver_length]: dtype ................ int64
#   brain_regions[bankssts_L][E].parameters[archiver_length]: unique_values ........ 0
#   brain_regions[bankssts_L][E].parameters[beta_Ca] ............................... --------------------
#   brain_regions[bankssts_L][E].parameters[beta_Ca]: shape ........................ (100,)
#   brain_regions[bankssts_L][E].parameters[beta_Ca]: dtype ........................ float64
#   brain_regions[bankssts_L][E].parameters[beta_Ca]: unique_values ................ 0.001
#   brain_regions[bankssts_L][E].parameters[C_m] ................................... --------------------
#   brain_regions[bankssts_L][E].parameters[C_m]: shape ............................ (100,)
#   brain_regions[bankssts_L][E].parameters[C_m]: dtype ............................ float64
#   brain_regions[bankssts_L][E].parameters[C_m]: unique_values .................... 250
#   brain_regions[bankssts_L][E].parameters[Ca] .................................... --------------------
#   brain_regions[bankssts_L][E].parameters[Ca]: shape ............................. (100,)
#   brain_regions[bankssts_L][E].parameters[Ca]: dtype ............................. float64
#   brain_regions[bankssts_L][E].parameters[Ca]: unique_values ..................... 0
#   brain_regions[bankssts_L][E].parameters[dg_ex] ................................. --------------------
#   brain_regions[bankssts_L][E].parameters[dg_ex]: shape .......................... (100,)
#   brain_regions[bankssts_L][E].parameters[dg_ex]: dtype .......................... float64
#   brain_regions[bankssts_L][E].parameters[dg_ex]: unique_values .................. 0
#   brain_regions[bankssts_L][E].parameters[dg_in] ................................. --------------------
#   brain_regions[bankssts_L][E].parameters[dg_in]: shape .......................... (100,)
#   brain_regions[bankssts_L][E].parameters[dg_in]: dtype .......................... float64
#   brain_regions[bankssts_L][E].parameters[dg_in]: unique_values .................. 0
#   brain_regions[bankssts_L][E].parameters[E_L] ................................... --------------------
#   brain_regions[bankssts_L][E].parameters[E_L]: shape ............................ (100,)
#   brain_regions[bankssts_L][E].parameters[E_L]: dtype ............................ float64
#   brain_regions[bankssts_L][E].parameters[E_L]: unique_values .................... -70
#   brain_regions[bankssts_L][E].parameters[E_ex] .................................. --------------------
#   brain_regions[bankssts_L][E].parameters[E_ex]: shape ........................... (100,)
#   brain_regions[bankssts_L][E].parameters[E_ex]: dtype ........................... float64
#   brain_regions[bankssts_L][E].parameters[E_ex]: unique_values ................... 0
#   brain_regions[bankssts_L][E].parameters[E_in] .................................. --------------------
#   brain_regions[bankssts_L][E].parameters[E_in]: shape ........................... (100,)
#   brain_regions[bankssts_L][E].parameters[E_in]: dtype ........................... float64
#   brain_regions[bankssts_L][E].parameters[E_in]: unique_values ................... -85
#   brain_regions[bankssts_L][E].parameters[element_type] .......................... --------------------
#   brain_regions[bankssts_L][E].parameters[element_type]: shape ................... (100,)
#   brain_regions[bankssts_L][E].parameters[element_type]: dtype ................... <U6
#   brain_regions[bankssts_L][E].parameters[element_type]: unique_values ........... neuron
#   brain_regions[bankssts_L][E].parameters[frozen] ................................ --------------------
#   brain_regions[bankssts_L][E].parameters[frozen]: shape ......................... (100,)
#   brain_regions[bankssts_L][E].parameters[frozen]: dtype ......................... bool
#   brain_regions[bankssts_L][E].parameters[frozen]: unique_values ................. 0
#   brain_regions[bankssts_L][E].parameters[g_L] ................................... --------------------
#   brain_regions[bankssts_L][E].parameters[g_L]: shape ............................ (100,)
#   brain_regions[bankssts_L][E].parameters[g_L]: dtype ............................ float64
#   brain_regions[bankssts_L][E].parameters[g_L]: unique_values .................... 16.6667
#   brain_regions[bankssts_L][E].parameters[g_ex] .................................. --------------------
#   brain_regions[bankssts_L][E].parameters[g_ex]: shape ........................... (100,)
#   brain_regions[bankssts_L][E].parameters[g_ex]: dtype ........................... float64
#   brain_regions[bankssts_L][E].parameters[g_ex]: unique_values ................... 0
#   brain_regions[bankssts_L][E].parameters[g_in] .................................. --------------------
#   brain_regions[bankssts_L][E].parameters[g_in]: shape ........................... (100,)
#   brain_regions[bankssts_L][E].parameters[g_in]: dtype ........................... float64
#   brain_regions[bankssts_L][E].parameters[g_in]: unique_values ................... 0
#   brain_regions[bankssts_L][E].parameters[global_id] ............................. --------------------
#   brain_regions[bankssts_L][E].parameters[global_id]: shape ...................... (100,)
#   brain_regions[bankssts_L][E].parameters[global_id]: dtype ...................... int64
#   brain_regions[bankssts_L][E].parameters[global_id]: unique_values .............. [[1, 100]]
#   brain_regions[bankssts_L][E].parameters[I_e] ................................... --------------------
#   brain_regions[bankssts_L][E].parameters[I_e]: shape ............................ (100,)
#   brain_regions[bankssts_L][E].parameters[I_e]: dtype ............................ float64
#   brain_regions[bankssts_L][E].parameters[I_e]: unique_values .................... 0
#   brain_regions[bankssts_L][E].parameters[local] ................................. --------------------
#   brain_regions[bankssts_L][E].parameters[local]: shape .......................... (100,)
#   brain_regions[bankssts_L][E].parameters[local]: dtype .......................... bool
#   brain_regions[bankssts_L][E].parameters[local]: unique_values .................. 1
#   brain_regions[bankssts_L][E].parameters[model] ................................. --------------------
#   brain_regions[bankssts_L][E].parameters[model]: shape .......................... (100,)
#   brain_regions[bankssts_L][E].parameters[model]: dtype .......................... <U14
#   brain_regions[bankssts_L][E].parameters[model]: unique_values .................. iaf_cond_alpha
#   brain_regions[bankssts_L][E].parameters[model_id] .............................. --------------------
#   brain_regions[bankssts_L][E].parameters[model_id]: shape ....................... (100,)
#   brain_regions[bankssts_L][E].parameters[model_id]: dtype ....................... int64
#   brain_regions[bankssts_L][E].parameters[model_id]: unique_values ............... 65
#   brain_regions[bankssts_L][E].parameters[node_uses_wfr] ......................... --------------------
#   brain_regions[bankssts_L][E].parameters[node_uses_wfr]: shape .................. (100,)
#   brain_regions[bankssts_L][E].parameters[node_uses_wfr]: dtype .................. bool
#   brain_regions[bankssts_L][E].parameters[node_uses_wfr]: unique_values .......... 0
#   brain_regions[bankssts_L][E].parameters[post_trace] ............................ --------------------
#   brain_regions[bankssts_L][E].parameters[post_trace]: shape ..................... (100,)
#   brain_regions[bankssts_L][E].parameters[post_trace]: dtype ..................... float64
#   brain_regions[bankssts_L][E].parameters[post_trace]: unique_values ............. 0
#   brain_regions[bankssts_L][E].parameters[recordables] ........................... --------------------
#   brain_regions[bankssts_L][E].parameters[recordables]: shape .................... (100, 4)
#   brain_regions[bankssts_L][E].parameters[recordables]: dtype .................... <U15
#   brain_regions[bankssts_L][E].parameters[recordables]: unique_values ............ ['V_m' 'g_ex' 'g_in' 't_ref_remaining']
#   brain_regions[bankssts_L][E].parameters[synaptic_elements] ..................... --------------------
#   brain_regions[bankssts_L][E].parameters[synaptic_elements]: shape .............. (100,)
#   brain_regions[bankssts_L][E].parameters[synaptic_elements]: dtype .............. object
#   brain_regions[bankssts_L][E].parameters[synaptic_elements]: values ............. [{} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {}
#  {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {}
#  {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {}
#  {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {}
#  {} {} {} {}]
#   brain_regions[bankssts_L][E].parameters[t_ref] ................................. --------------------
#   brain_regions[bankssts_L][E].parameters[t_ref]: shape .......................... (100,)
#   brain_regions[bankssts_L][E].parameters[t_ref]: dtype .......................... float64
#   brain_regions[bankssts_L][E].parameters[t_ref]: unique_values .................. 2
#   brain_regions[bankssts_L][E].parameters[t_spike] ............................... --------------------
#   brain_regions[bankssts_L][E].parameters[t_spike]: shape ........................ (100,)
#   brain_regions[bankssts_L][E].parameters[t_spike]: dtype ........................ float64
#   brain_regions[bankssts_L][E].parameters[t_spike]: unique_values ................ -1
#   brain_regions[bankssts_L][E].parameters[tau_Ca] ................................ --------------------
#   brain_regions[bankssts_L][E].parameters[tau_Ca]: shape ......................... (100,)
#   brain_regions[bankssts_L][E].parameters[tau_Ca]: dtype ......................... float64
#   brain_regions[bankssts_L][E].parameters[tau_Ca]: unique_values ................. 10000
#   brain_regions[bankssts_L][E].parameters[tau_minus] ............................. --------------------
#   brain_regions[bankssts_L][E].parameters[tau_minus]: shape ...................... (100,)
#   brain_regions[bankssts_L][E].parameters[tau_minus]: dtype ...................... float64
#   brain_regions[bankssts_L][E].parameters[tau_minus]: unique_values .............. 20
#   brain_regions[bankssts_L][E].parameters[tau_minus_triplet] ..................... --------------------
#   brain_regions[bankssts_L][E].parameters[tau_minus_triplet]: shape .............. (100,)
#   brain_regions[bankssts_L][E].parameters[tau_minus_triplet]: dtype .............. float64
#   brain_regions[bankssts_L][E].parameters[tau_minus_triplet]: unique_values ...... 110
#   brain_regions[bankssts_L][E].parameters[tau_syn_ex] ............................ --------------------
#   brain_regions[bankssts_L][E].parameters[tau_syn_ex]: shape ..................... (100,)
#   brain_regions[bankssts_L][E].parameters[tau_syn_ex]: dtype ..................... float64
#   brain_regions[bankssts_L][E].parameters[tau_syn_ex]: unique_values ............. 0.2
#   brain_regions[bankssts_L][E].parameters[tau_syn_in] ............................ --------------------
#   brain_regions[bankssts_L][E].parameters[tau_syn_in]: shape ..................... (100,)
#   brain_regions[bankssts_L][E].parameters[tau_syn_in]: dtype ..................... float64
#   brain_regions[bankssts_L][E].parameters[tau_syn_in]: unique_values ............. 2
#   brain_regions[bankssts_L][E].parameters[thread] ................................ --------------------
#   brain_regions[bankssts_L][E].parameters[thread]: shape ......................... (100,)
#   brain_regions[bankssts_L][E].parameters[thread]: dtype ......................... int64
#   brain_regions[bankssts_L][E].parameters[thread]: =1 ............................ 25 total instances
#   brain_regions[bankssts_L][E].parameters[thread]: =2 ............................ 25 total instances
#   brain_regions[bankssts_L][E].parameters[thread]: =3 ............................ 25 total instances
#   brain_regions[bankssts_L][E].parameters[thread]: =0 ............................ 25 total instances
#   brain_regions[bankssts_L][E].parameters[thread_local_id] ....................... --------------------
#   brain_regions[bankssts_L][E].parameters[thread_local_id]: shape ................ (100,)
#   brain_regions[bankssts_L][E].parameters[thread_local_id]: dtype ................ int64
#   brain_regions[bankssts_L][E].parameters[thread_local_id]: unique_values ........ -1
#   brain_regions[bankssts_L][E].parameters[V_m] ................................... --------------------
#   brain_regions[bankssts_L][E].parameters[V_m]: shape ............................ (100,)
#   brain_regions[bankssts_L][E].parameters[V_m]: dtype ............................ float64
#   brain_regions[bankssts_L][E].parameters[V_m]: unique_values .................... -70
#   brain_regions[bankssts_L][E].parameters[V_reset] ............................... --------------------
#   brain_regions[bankssts_L][E].parameters[V_reset]: shape ........................ (100,)
#   brain_regions[bankssts_L][E].parameters[V_reset]: dtype ........................ float64
#   brain_regions[bankssts_L][E].parameters[V_reset]: unique_values ................ -60
#   brain_regions[bankssts_L][E].parameters[V_th] .................................. --------------------
#   brain_regions[bankssts_L][E].parameters[V_th]: shape ........................... (100,)
#   brain_regions[bankssts_L][E].parameters[V_th]: dtype ........................... float64
#   brain_regions[bankssts_L][E].parameters[V_th]: unique_values ................... -55
#   brain_regions[bankssts_L][E].parameters[vp] .................................... --------------------
#   brain_regions[bankssts_L][E].parameters[vp]: shape ............................. (100,)
#   brain_regions[bankssts_L][E].parameters[vp]: dtype ............................. int64
#   brain_regions[bankssts_L][E].parameters[vp]: =1 ................................ 25 total instances
#   brain_regions[bankssts_L][E].parameters[vp]: =2 ................................ 25 total instances
#   brain_regions[bankssts_L][E].parameters[vp]: =3 ................................ 25 total instances
#   brain_regions[bankssts_L][E].parameters[vp]: =0 ................................ 25 total instances
#   brain_regions[bankssts_L][E].connectivity[target_out] .......................... --------------------
#   brain_regions[bankssts_L][E].connectivity[target_out]: shape ................... (40100,)
#   brain_regions[bankssts_L][E].connectivity[target_out]: dtype ................... int64
#   brain_regions[bankssts_L][E].connectivity[target_out]: unique_values ........... [[1, 401]]
#   brain_regions[bankssts_L][E].connectivity[weight_out] .......................... --------------------
#   brain_regions[bankssts_L][E].connectivity[weight_out]: shape ................... (40100,)
#   brain_regions[bankssts_L][E].connectivity[weight_out]: dtype ................... float64
#   brain_regions[bankssts_L][E].connectivity[weight_out]: =10.0 ................... 10000 total instances
#   brain_regions[bankssts_L][E].connectivity[weight_out]: =6.0 .................... 10000 total instances
#   brain_regions[bankssts_L][E].connectivity[weight_out]: =2.4967185335356043e-07 . 20000 total instances
#   brain_regions[bankssts_L][E].connectivity[weight_out]: =1.0 .................... 100 total instances
#   brain_regions[bankssts_L][E].connectivity[delay_out] ........................... --------------------
#   brain_regions[bankssts_L][E].connectivity[delay_out]: shape .................... (40100,)
#   brain_regions[bankssts_L][E].connectivity[delay_out]: dtype .................... float64
#   brain_regions[bankssts_L][E].connectivity[delay_out]: =1.0 ..................... 20100 total instances
#   brain_regions[bankssts_L][E].connectivity[delay_out]: =40.0 .................... 20000 total instances
#   brain_regions[bankssts_L][E].connectivity[receptor_out] ........................ --------------------
#   brain_regions[bankssts_L][E].connectivity[receptor_out]: shape ................. (40100,)
#   brain_regions[bankssts_L][E].connectivity[receptor_out]: dtype ................. int64
#   brain_regions[bankssts_L][E].connectivity[receptor_out]: unique_values ......... 0
#   brain_regions[bankssts_L][E].connectivity[source_in] ........................... --------------------
#   brain_regions[bankssts_L][E].connectivity[source_in]: shape .................... (30200,)
#   brain_regions[bankssts_L][E].connectivity[source_in]: dtype .................... int64
#   brain_regions[bankssts_L][E].connectivity[source_in]: unique_values ............ [[1, 300], [402], [409]]
#   brain_regions[bankssts_L][E].connectivity[weight_in] ........................... --------------------
#   brain_regions[bankssts_L][E].connectivity[weight_in]: shape .................... (30200,)
#   brain_regions[bankssts_L][E].connectivity[weight_in]: dtype .................... float64
#   brain_regions[bankssts_L][E].connectivity[weight_in]: =10.0 .................... 10000 total instances
#   brain_regions[bankssts_L][E].connectivity[weight_in]: =-10.0 ................... 10000 total instances
#   brain_regions[bankssts_L][E].connectivity[weight_in]: =3.4653900070709257e-07 .. 10000 total instances
#   brain_regions[bankssts_L][E].connectivity[weight_in]: =1.0 ..................... 200 total instances
#   brain_regions[bankssts_L][E].connectivity[delay_in] ............................ --------------------
#   brain_regions[bankssts_L][E].connectivity[delay_in]: shape ..................... (30200,)
#   brain_regions[bankssts_L][E].connectivity[delay_in]: dtype ..................... float64
#   brain_regions[bankssts_L][E].connectivity[delay_in]: =1.0 ...................... 20200 total instances
#   brain_regions[bankssts_L][E].connectivity[delay_in]: =40.0 ..................... 10000 total instances
#   brain_regions[bankssts_L][E].connectivity[receptor_in] ......................... --------------------
#   brain_regions[bankssts_L][E].connectivity[receptor_in]: shape .................. (30200,)
#   brain_regions[bankssts_L][E].connectivity[receptor_in]: dtype .................. int64
#   brain_regions[bankssts_L][E].connectivity[receptor_in]: =0 ..................... 30100 total instances
#   brain_regions[bankssts_L][E].connectivity[receptor_in]: =1 ..................... 100 total instances
#   brain_regions[bankssts_L].I .................................................... '--------------------'
#   brain_regions[bankssts_L][I].title ............................................. 'NESTPopulation gid: 469c452c-307a-4430-b5c4-ff55ac7ffea5'
#   brain_regions[bankssts_L][I].Type .............................................. 'NESTPopulation'
#   brain_regions[bankssts_L][I]._nodes ............................................ NodeCollection(metadata=None, model=iaf_cond_alpha, size=100, first=101, last=200)
#   brain_regions[bankssts_L][I].label ............................................. 'I'
#   brain_regions[bankssts_L][I].model ............................................. 'NESTPopulation'
#   brain_regions[bankssts_L][I].brain_region ...................................... 'bankssts_L'
#   brain_regions[bankssts_L][I].gid ............................................... UUID('469c452c-307a-4430-b5c4-ff55ac7ffea5')
#   brain_regions[bankssts_L][I].number_of_nodes ................................... 100
#   brain_regions[bankssts_L][I].nodes ............................................. NodeCollection(metadata=None, model=iaf_cond_alpha, size=100, first=101, last=200)
#   brain_regions[bankssts_L][I].gids .............................................. --------------------
#   brain_regions[bankssts_L][I].gids: shape ....................................... (100,)
#   brain_regions[bankssts_L][I].gids: dtype ....................................... int64
#   brain_regions[bankssts_L][I].gids: unique_values ............................... [[101, 200]]
#   brain_regions[bankssts_L][I].parameters[archiver_length] ....................... --------------------
#   brain_regions[bankssts_L][I].parameters[archiver_length]: shape ................ (100,)
#   brain_regions[bankssts_L][I].parameters[archiver_length]: dtype ................ int64
#   brain_regions[bankssts_L][I].parameters[archiver_length]: unique_values ........ 0
#   brain_regions[bankssts_L][I].parameters[beta_Ca] ............................... --------------------
#   brain_regions[bankssts_L][I].parameters[beta_Ca]: shape ........................ (100,)
#   brain_regions[bankssts_L][I].parameters[beta_Ca]: dtype ........................ float64
#   brain_regions[bankssts_L][I].parameters[beta_Ca]: unique_values ................ 0.001
#   brain_regions[bankssts_L][I].parameters[C_m] ................................... --------------------
#   brain_regions[bankssts_L][I].parameters[C_m]: shape ............................ (100,)
#   brain_regions[bankssts_L][I].parameters[C_m]: dtype ............................ float64
#   brain_regions[bankssts_L][I].parameters[C_m]: unique_values .................... 250
#   brain_regions[bankssts_L][I].parameters[Ca] .................................... --------------------
#   brain_regions[bankssts_L][I].parameters[Ca]: shape ............................. (100,)
#   brain_regions[bankssts_L][I].parameters[Ca]: dtype ............................. float64
#   brain_regions[bankssts_L][I].parameters[Ca]: unique_values ..................... 0
#   brain_regions[bankssts_L][I].parameters[dg_ex] ................................. --------------------
#   brain_regions[bankssts_L][I].parameters[dg_ex]: shape .......................... (100,)
#   brain_regions[bankssts_L][I].parameters[dg_ex]: dtype .......................... float64
#   brain_regions[bankssts_L][I].parameters[dg_ex]: unique_values .................. 0
#   brain_regions[bankssts_L][I].parameters[dg_in] ................................. --------------------
#   brain_regions[bankssts_L][I].parameters[dg_in]: shape .......................... (100,)
#   brain_regions[bankssts_L][I].parameters[dg_in]: dtype .......................... float64
#   brain_regions[bankssts_L][I].parameters[dg_in]: unique_values .................. 0
#   brain_regions[bankssts_L][I].parameters[E_L] ................................... --------------------
#   brain_regions[bankssts_L][I].parameters[E_L]: shape ............................ (100,)
#   brain_regions[bankssts_L][I].parameters[E_L]: dtype ............................ float64
#   brain_regions[bankssts_L][I].parameters[E_L]: unique_values .................... -70
#   brain_regions[bankssts_L][I].parameters[E_ex] .................................. --------------------
#   brain_regions[bankssts_L][I].parameters[E_ex]: shape ........................... (100,)
#   brain_regions[bankssts_L][I].parameters[E_ex]: dtype ........................... float64
#   brain_regions[bankssts_L][I].parameters[E_ex]: unique_values ................... 0
#   brain_regions[bankssts_L][I].parameters[E_in] .................................. --------------------
#   brain_regions[bankssts_L][I].parameters[E_in]: shape ........................... (100,)
#   brain_regions[bankssts_L][I].parameters[E_in]: dtype ........................... float64
#   brain_regions[bankssts_L][I].parameters[E_in]: unique_values ................... -85
#   brain_regions[bankssts_L][I].parameters[element_type] .......................... --------------------
#   brain_regions[bankssts_L][I].parameters[element_type]: shape ................... (100,)
#   brain_regions[bankssts_L][I].parameters[element_type]: dtype ................... <U6
#   brain_regions[bankssts_L][I].parameters[element_type]: unique_values ........... neuron
#   brain_regions[bankssts_L][I].parameters[frozen] ................................ --------------------
#   brain_regions[bankssts_L][I].parameters[frozen]: shape ......................... (100,)
#   brain_regions[bankssts_L][I].parameters[frozen]: dtype ......................... bool
#   brain_regions[bankssts_L][I].parameters[frozen]: unique_values ................. 0
#   brain_regions[bankssts_L][I].parameters[g_L] ................................... --------------------
#   brain_regions[bankssts_L][I].parameters[g_L]: shape ............................ (100,)
#   brain_regions[bankssts_L][I].parameters[g_L]: dtype ............................ float64
#   brain_regions[bankssts_L][I].parameters[g_L]: unique_values .................... 16.6667
#   brain_regions[bankssts_L][I].parameters[g_ex] .................................. --------------------
#   brain_regions[bankssts_L][I].parameters[g_ex]: shape ........................... (100,)
#   brain_regions[bankssts_L][I].parameters[g_ex]: dtype ........................... float64
#   brain_regions[bankssts_L][I].parameters[g_ex]: unique_values ................... 0
#   brain_regions[bankssts_L][I].parameters[g_in] .................................. --------------------
#   brain_regions[bankssts_L][I].parameters[g_in]: shape ........................... (100,)
#   brain_regions[bankssts_L][I].parameters[g_in]: dtype ........................... float64
#   brain_regions[bankssts_L][I].parameters[g_in]: unique_values ................... 0
#   brain_regions[bankssts_L][I].parameters[global_id] ............................. --------------------
#   brain_regions[bankssts_L][I].parameters[global_id]: shape ...................... (100,)
#   brain_regions[bankssts_L][I].parameters[global_id]: dtype ...................... int64
#   brain_regions[bankssts_L][I].parameters[global_id]: unique_values .............. [[101, 200]]
#   brain_regions[bankssts_L][I].parameters[I_e] ................................... --------------------
#   brain_regions[bankssts_L][I].parameters[I_e]: shape ............................ (100,)
#   brain_regions[bankssts_L][I].parameters[I_e]: dtype ............................ float64
#   brain_regions[bankssts_L][I].parameters[I_e]: unique_values .................... 0
#   brain_regions[bankssts_L][I].parameters[local] ................................. --------------------
#   brain_regions[bankssts_L][I].parameters[local]: shape .......................... (100,)
#   brain_regions[bankssts_L][I].parameters[local]: dtype .......................... bool
#   brain_regions[bankssts_L][I].parameters[local]: unique_values .................. 1
#   brain_regions[bankssts_L][I].parameters[model] ................................. --------------------
#   brain_regions[bankssts_L][I].parameters[model]: shape .......................... (100,)
#   brain_regions[bankssts_L][I].parameters[model]: dtype .......................... <U14
#   brain_regions[bankssts_L][I].parameters[model]: unique_values .................. iaf_cond_alpha
#   brain_regions[bankssts_L][I].parameters[model_id] .............................. --------------------
#   brain_regions[bankssts_L][I].parameters[model_id]: shape ....................... (100,)
#   brain_regions[bankssts_L][I].parameters[model_id]: dtype ....................... int64
#   brain_regions[bankssts_L][I].parameters[model_id]: unique_values ............... 65
#   brain_regions[bankssts_L][I].parameters[node_uses_wfr] ......................... --------------------
#   brain_regions[bankssts_L][I].parameters[node_uses_wfr]: shape .................. (100,)
#   brain_regions[bankssts_L][I].parameters[node_uses_wfr]: dtype .................. bool
#   brain_regions[bankssts_L][I].parameters[node_uses_wfr]: unique_values .......... 0
#   brain_regions[bankssts_L][I].parameters[post_trace] ............................ --------------------
#   brain_regions[bankssts_L][I].parameters[post_trace]: shape ..................... (100,)
#   brain_regions[bankssts_L][I].parameters[post_trace]: dtype ..................... float64
#   brain_regions[bankssts_L][I].parameters[post_trace]: unique_values ............. 0
#   brain_regions[bankssts_L][I].parameters[recordables] ........................... --------------------
#   brain_regions[bankssts_L][I].parameters[recordables]: shape .................... (100, 4)
#   brain_regions[bankssts_L][I].parameters[recordables]: dtype .................... <U15
#   brain_regions[bankssts_L][I].parameters[recordables]: unique_values ............ ['V_m' 'g_ex' 'g_in' 't_ref_remaining']
#   brain_regions[bankssts_L][I].parameters[synaptic_elements] ..................... --------------------
#   brain_regions[bankssts_L][I].parameters[synaptic_elements]: shape .............. (100,)
#   brain_regions[bankssts_L][I].parameters[synaptic_elements]: dtype .............. object
#   brain_regions[bankssts_L][I].parameters[synaptic_elements]: values ............. [{} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {}
#  {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {}
#  {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {}
#  {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {}
#  {} {} {} {}]
#   brain_regions[bankssts_L][I].parameters[t_ref] ................................. --------------------
#   brain_regions[bankssts_L][I].parameters[t_ref]: shape .......................... (100,)
#   brain_regions[bankssts_L][I].parameters[t_ref]: dtype .......................... float64
#   brain_regions[bankssts_L][I].parameters[t_ref]: unique_values .................. 2
#   brain_regions[bankssts_L][I].parameters[t_spike] ............................... --------------------
#   brain_regions[bankssts_L][I].parameters[t_spike]: shape ........................ (100,)
#   brain_regions[bankssts_L][I].parameters[t_spike]: dtype ........................ float64
#   brain_regions[bankssts_L][I].parameters[t_spike]: unique_values ................ -1
#   brain_regions[bankssts_L][I].parameters[tau_Ca] ................................ --------------------
#   brain_regions[bankssts_L][I].parameters[tau_Ca]: shape ......................... (100,)
#   brain_regions[bankssts_L][I].parameters[tau_Ca]: dtype ......................... float64
#   brain_regions[bankssts_L][I].parameters[tau_Ca]: unique_values ................. 10000
#   brain_regions[bankssts_L][I].parameters[tau_minus] ............................. --------------------
#   brain_regions[bankssts_L][I].parameters[tau_minus]: shape ...................... (100,)
#   brain_regions[bankssts_L][I].parameters[tau_minus]: dtype ...................... float64
#   brain_regions[bankssts_L][I].parameters[tau_minus]: unique_values .............. 20
#   brain_regions[bankssts_L][I].parameters[tau_minus_triplet] ..................... --------------------
#   brain_regions[bankssts_L][I].parameters[tau_minus_triplet]: shape .............. (100,)
#   brain_regions[bankssts_L][I].parameters[tau_minus_triplet]: dtype .............. float64
#   brain_regions[bankssts_L][I].parameters[tau_minus_triplet]: unique_values ...... 110
#   brain_regions[bankssts_L][I].parameters[tau_syn_ex] ............................ --------------------
#   brain_regions[bankssts_L][I].parameters[tau_syn_ex]: shape ..................... (100,)
#   brain_regions[bankssts_L][I].parameters[tau_syn_ex]: dtype ..................... float64
#   brain_regions[bankssts_L][I].parameters[tau_syn_ex]: unique_values ............. 0.2
#   brain_regions[bankssts_L][I].parameters[tau_syn_in] ............................ --------------------
#   brain_regions[bankssts_L][I].parameters[tau_syn_in]: shape ..................... (100,)
#   brain_regions[bankssts_L][I].parameters[tau_syn_in]: dtype ..................... float64
#   brain_regions[bankssts_L][I].parameters[tau_syn_in]: unique_values ............. 2
#   brain_regions[bankssts_L][I].parameters[thread] ................................ --------------------
#   brain_regions[bankssts_L][I].parameters[thread]: shape ......................... (100,)
#   brain_regions[bankssts_L][I].parameters[thread]: dtype ......................... int64
#   brain_regions[bankssts_L][I].parameters[thread]: =1 ............................ 25 total instances
#   brain_regions[bankssts_L][I].parameters[thread]: =2 ............................ 25 total instances
#   brain_regions[bankssts_L][I].parameters[thread]: =3 ............................ 25 total instances
#   brain_regions[bankssts_L][I].parameters[thread]: =0 ............................ 25 total instances
#   brain_regions[bankssts_L][I].parameters[thread_local_id] ....................... --------------------
#   brain_regions[bankssts_L][I].parameters[thread_local_id]: shape ................ (100,)
#   brain_regions[bankssts_L][I].parameters[thread_local_id]: dtype ................ int64
#   brain_regions[bankssts_L][I].parameters[thread_local_id]: unique_values ........ -1
#   brain_regions[bankssts_L][I].parameters[V_m] ................................... --------------------
#   brain_regions[bankssts_L][I].parameters[V_m]: shape ............................ (100,)
#   brain_regions[bankssts_L][I].parameters[V_m]: dtype ............................ float64
#   brain_regions[bankssts_L][I].parameters[V_m]: unique_values .................... -70
#   brain_regions[bankssts_L][I].parameters[V_reset] ............................... --------------------
#   brain_regions[bankssts_L][I].parameters[V_reset]: shape ........................ (100,)
#   brain_regions[bankssts_L][I].parameters[V_reset]: dtype ........................ float64
#   brain_regions[bankssts_L][I].parameters[V_reset]: unique_values ................ -60
#   brain_regions[bankssts_L][I].parameters[V_th] .................................. --------------------
#   brain_regions[bankssts_L][I].parameters[V_th]: shape ........................... (100,)
#   brain_regions[bankssts_L][I].parameters[V_th]: dtype ........................... float64
#   brain_regions[bankssts_L][I].parameters[V_th]: unique_values ................... -55
#   brain_regions[bankssts_L][I].parameters[vp] .................................... --------------------
#   brain_regions[bankssts_L][I].parameters[vp]: shape ............................. (100,)
#   brain_regions[bankssts_L][I].parameters[vp]: dtype ............................. int64
#   brain_regions[bankssts_L][I].parameters[vp]: =1 ................................ 25 total instances
#   brain_regions[bankssts_L][I].parameters[vp]: =2 ................................ 25 total instances
#   brain_regions[bankssts_L][I].parameters[vp]: =3 ................................ 25 total instances
#   brain_regions[bankssts_L][I].parameters[vp]: =0 ................................ 25 total instances
#   brain_regions[bankssts_L][I].connectivity[target_out] .......................... --------------------
#   brain_regions[bankssts_L][I].connectivity[target_out]: shape ................... (20100,)
#   brain_regions[bankssts_L][I].connectivity[target_out]: dtype ................... int64
#   brain_regions[bankssts_L][I].connectivity[target_out]: unique_values ........... [[1, 200], [405]]
#   brain_regions[bankssts_L][I].connectivity[weight_out] .......................... --------------------
#   brain_regions[bankssts_L][I].connectivity[weight_out]: shape ................... (20100,)
#   brain_regions[bankssts_L][I].connectivity[weight_out]: dtype ................... float64
#   brain_regions[bankssts_L][I].connectivity[weight_out]: =-10.0 .................. 10000 total instances
#   brain_regions[bankssts_L][I].connectivity[weight_out]: =-1.0 ................... 10000 total instances
#   brain_regions[bankssts_L][I].connectivity[weight_out]: =1.0 .................... 100 total instances
#   brain_regions[bankssts_L][I].connectivity[delay_out] ........................... --------------------
#   brain_regions[bankssts_L][I].connectivity[delay_out]: shape .................... (20100,)
#   brain_regions[bankssts_L][I].connectivity[delay_out]: dtype .................... float64
#   brain_regions[bankssts_L][I].connectivity[delay_out]: unique_values ............ 1
#   brain_regions[bankssts_L][I].connectivity[receptor_out] ........................ --------------------
#   brain_regions[bankssts_L][I].connectivity[receptor_out]: shape ................. (20100,)
#   brain_regions[bankssts_L][I].connectivity[receptor_out]: dtype ................. int64
#   brain_regions[bankssts_L][I].connectivity[receptor_out]: unique_values ......... 0
#   brain_regions[bankssts_L][I].connectivity[source_in] ........................... --------------------
#   brain_regions[bankssts_L][I].connectivity[source_in]: shape .................... (30100,)
# ...
#   interfaces[1].spiking_proxy_inds: values  [[0, 1]]
#   interfaces[1].populations .............. --------------------
#   interfaces[1].populations: shape ....... (1,)
#   interfaces[1].populations: dtype ....... <U128
#   interfaces[1].populations: values ...... I
#   interfaces[1].model .................... ''
#   interfaces[1].gid ...................... UUID('d123b74b-1c84-456d-82c6-fe947aae1a22')
#   interfaces[1].number_of_proxy_nodes .... 2
#   interfaces[1].number_of_proxy_gids ..... 2
#   interfaces[1].proxy_gids ............... --------------------
#   interfaces[1].proxy_gids: shape ........ (2,)
#   interfaces[1].proxy_gids: dtype ........ int64
#   interfaces[1].proxy_gids: values ....... [[413, 414]]
#   synchronization_time ................... 3.6
#   synchronization_n_step ................. 36
#   gid .................................... UUID('0b8edcbf-4a21-404a-b770-a66d35338d0d')
#   number_of_interfaces ................... 2
#   number_of_populations .................. 2
#   populations_unique ..................... --------------------
#   populations_unique: shape .............. (2,)
#   populations_unique: dtype .............. <U1
#   populations_unique: values ............. ['E' 'I']
#   spiking_proxy_inds ..................... --------------------
#   spiking_proxy_inds: shape .............. (4,)
#   spiking_proxy_inds: dtype .............. int64
#   spiking_proxy_inds: =0 ................. {0, 2}
#   spiking_proxy_inds: =1 ................. {1, 3}
# )
# 2023-10-24 18:09:24,542 - INFO - tvb_multiscale.core.orchestrators.base -
# NESTOutputInterfaces (
#   title .................................. 'NESTOutputInterfaces gid: 0b8edcbf-4a21-404a-b770-a66d35338d0d'
#   Type ................................... 'NESTOutputInterfaces'
#   interfaces[0] .......................... '--------------------'
#   interfaces[0].title .................... 'NESTOutputInterface gid: f772693d-8b4b-41c2-8a5b-a781a6d7b271'
#   interfaces[0].Type ..................... 'NESTOutputInterface'
#   interfaces[0].proxy .................... NESTSpikeRecorderTotalSet gid: b6bd65ba-c9ce-4339-b2a8-2eb7a6d97a32
#   interfaces[0].spiking_network .......... NESTNetwork gid: bebeac52-45f0-4ec3-88ff-9e6192aa0860
#   interfaces[0].dt ....................... 0.1
#   interfaces[0].times .................... --------------------
#   interfaces[0].times: shape ............. (2,)
#   interfaces[0].times: dtype ............. int64
#   interfaces[0].times: values ............ [[0, 1]]
#   interfaces[0].spiking_proxy_inds ....... --------------------
#   interfaces[0].spiking_proxy_inds: shape  (2,)
#   interfaces[0].spiking_proxy_inds: dtype  int64
#   interfaces[0].spiking_proxy_inds: values  [[0, 1]]
#   interfaces[0].populations .............. --------------------
#   interfaces[0].populations: shape ....... (1,)
#   interfaces[0].populations: dtype ....... <U128
#   interfaces[0].populations: values ...... E
#   interfaces[0].model .................... ''
#   interfaces[0].gid ...................... UUID('f772693d-8b4b-41c2-8a5b-a781a6d7b271')
#   interfaces[0].number_of_proxy_nodes .... 2
#   interfaces[0].number_of_proxy_gids ..... 2
#   interfaces[0].proxy_gids ............... --------------------
#   interfaces[0].proxy_gids: shape ........ (2,)
#   interfaces[0].proxy_gids: dtype ........ int64
#   interfaces[0].proxy_gids: values ....... [[411, 412]]
#   interfaces[1] .......................... '--------------------'
#   interfaces[1].title .................... 'NESTOutputInterface gid: d123b74b-1c84-456d-82c6-fe947aae1a22'
#   interfaces[1].Type ..................... 'NESTOutputInterface'
#   interfaces[1].proxy .................... NESTSpikeRecorderTotalSet gid: 1ffe08db-b4ea-4502-a46c-b22d70302bc5
#   interfaces[1].spiking_network .......... NESTNetwork gid: bebeac52-45f0-4ec3-88ff-9e6192aa0860
#   interfaces[1].dt ....................... 0.1
#   interfaces[1].times .................... --------------------
#   interfaces[1].times: shape ............. (2,)
#   interfaces[1].times: dtype ............. int64
#   interfaces[1].times: values ............ [[0, 1]]
#   interfaces[1].spiking_proxy_inds ....... --------------------
#   interfaces[1].spiking_proxy_inds: shape  (2,)
#   interfaces[1].spiking_proxy_inds: dtype  int64
#   interfaces[1].spiking_proxy_inds: values  [[0, 1]]
#   interfaces[1].populations .............. --------------------
#   interfaces[1].populations: shape ....... (1,)
#   interfaces[1].populations: dtype ....... <U128
#   interfaces[1].populations: values ...... I
#   interfaces[1].model .................... ''
#   interfaces[1].gid ...................... UUID('d123b74b-1c84-456d-82c6-fe947aae1a22')
#   interfaces[1].number_of_proxy_nodes .... 2
#   interfaces[1].number_of_proxy_gids ..... 2
#   interfaces[1].proxy_gids ............... --------------------
#   interfaces[1].proxy_gids: shape ........ (2,)
#   interfaces[1].proxy_gids: dtype ........ int64
#   interfaces[1].proxy_gids: values ....... [[413, 414]]
#   synchronization_time ................... 3.6
#   synchronization_n_step ................. 36
#   gid .................................... UUID('0b8edcbf-4a21-404a-b770-a66d35338d0d')
#   number_of_interfaces ................... 2
#   number_of_populations .................. 2
#   populations_unique ..................... --------------------
#   populations_unique: shape .............. (2,)
#   populations_unique: dtype .............. <U1
#   populations_unique: values ............. ['E' 'I']
#   spiking_proxy_inds ..................... --------------------
#   spiking_proxy_inds: shape .............. (4,)
#   spiking_proxy_inds: dtype .............. int64
#   spiking_proxy_inds: =0 ................. {0, 2}
#   spiking_proxy_inds: =1 ................. {1, 3}
# )
# 2023-10-24 18:09:24,542 - INFO - tvb_multiscale.core.orchestrators.base -
# NESTOutputInterfaces (
#   title .................................. 'NESTOutputInterfaces gid: 0b8edcbf-4a21-404a-b770-a66d35338d0d'
#   Type ................................... 'NESTOutputInterfaces'
#   interfaces[0] .......................... '--------------------'
#   interfaces[0].title .................... 'NESTOutputInterface gid: f772693d-8b4b-41c2-8a5b-a781a6d7b271'
#   interfaces[0].Type ..................... 'NESTOutputInterface'
#   interfaces[0].proxy .................... NESTSpikeRecorderTotalSet gid: b6bd65ba-c9ce-4339-b2a8-2eb7a6d97a32
#   interfaces[0].spiking_network .......... NESTNetwork gid: bebeac52-45f0-4ec3-88ff-9e6192aa0860
#   interfaces[0].dt ....................... 0.1
#   interfaces[0].times .................... --------------------
#   interfaces[0].times: shape ............. (2,)
#   interfaces[0].times: dtype ............. int64
#   interfaces[0].times: values ............ [[0, 1]]
#   interfaces[0].spiking_proxy_inds ....... --------------------
#   interfaces[0].spiking_proxy_inds: shape  (2,)
#   interfaces[0].spiking_proxy_inds: dtype  int64
#   interfaces[0].spiking_proxy_inds: values  [[0, 1]]
#   interfaces[0].populations .............. --------------------
#   interfaces[0].populations: shape ....... (1,)
#   interfaces[0].populations: dtype ....... <U128
#   interfaces[0].populations: values ...... E
#   interfaces[0].model .................... ''
#   interfaces[0].gid ...................... UUID('f772693d-8b4b-41c2-8a5b-a781a6d7b271')
#   interfaces[0].number_of_proxy_nodes .... 2
#   interfaces[0].number_of_proxy_gids ..... 2
#   interfaces[0].proxy_gids ............... --------------------
#   interfaces[0].proxy_gids: shape ........ (2,)
#   interfaces[0].proxy_gids: dtype ........ int64
#   interfaces[0].proxy_gids: values ....... [[411, 412]]
#   interfaces[1] .......................... '--------------------'
#   interfaces[1].title .................... 'NESTOutputInterface gid: d123b74b-1c84-456d-82c6-fe947aae1a22'
#   interfaces[1].Type ..................... 'NESTOutputInterface'
#   interfaces[1].proxy .................... NESTSpikeRecorderTotalSet gid: 1ffe08db-b4ea-4502-a46c-b22d70302bc5
#   interfaces[1].spiking_network .......... NESTNetwork gid: bebeac52-45f0-4ec3-88ff-9e6192aa0860
#   interfaces[1].dt ....................... 0.1
#   interfaces[1].times .................... --------------------
#   interfaces[1].times: shape ............. (2,)
#   interfaces[1].times: dtype ............. int64
#   interfaces[1].times: values ............ [[0, 1]]
#   interfaces[1].spiking_proxy_inds ....... --------------------
#   interfaces[1].spiking_proxy_inds: shape  (2,)
#   interfaces[1].spiking_proxy_inds: dtype  int64
#   interfaces[1].spiking_proxy_inds: values  [[0, 1]]
#   interfaces[1].populations .............. --------------------
#   interfaces[1].populations: shape ....... (1,)
#   interfaces[1].populations: dtype ....... <U128
#   interfaces[1].populations: values ...... I
#   interfaces[1].model .................... ''
#   interfaces[1].gid ...................... UUID('d123b74b-1c84-456d-82c6-fe947aae1a22')
#   interfaces[1].number_of_proxy_nodes .... 2
#   interfaces[1].number_of_proxy_gids ..... 2
#   interfaces[1].proxy_gids ............... --------------------
#   interfaces[1].proxy_gids: shape ........ (2,)
#   interfaces[1].proxy_gids: dtype ........ int64
#   interfaces[1].proxy_gids: values ....... [[413, 414]]
#   synchronization_time ................... 3.6
#   synchronization_n_step ................. 36
#   gid .................................... UUID('0b8edcbf-4a21-404a-b770-a66d35338d0d')
#   number_of_interfaces ................... 2
#   number_of_populations .................. 2
#   populations_unique ..................... --------------------
#   populations_unique: shape .............. (2,)
#   populations_unique: dtype .............. <U1
#   populations_unique: values ............. ['E' 'I']
#   spiking_proxy_inds ..................... --------------------
#   spiking_proxy_inds: shape .............. (4,)
#   spiking_proxy_inds: dtype .............. int64
#   spiking_proxy_inds: =0 ................. {0, 2}
#   spiking_proxy_inds: =1 ................. {1, 3}
# )
#
# NESTOutputInterfaces (
#   title .................................. 'NESTOutputInterfaces gid: 0b8edcbf-4a21-404a-b770-a66d35338d0d'
#   Type ................................... 'NESTOutputInterfaces'
#   interfaces[0] .......................... '--------------------'
#   interfaces[0].title .................... 'NESTOutputInterface gid: f772693d-8b4b-41c2-8a5b-a781a6d7b271'
#   interfaces[0].Type ..................... 'NESTOutputInterface'
#   interfaces[0].proxy .................... NESTSpikeRecorderTotalSet gid: b6bd65ba-c9ce-4339-b2a8-2eb7a6d97a32
#   interfaces[0].spiking_network .......... NESTNetwork gid: bebeac52-45f0-4ec3-88ff-9e6192aa0860
#   interfaces[0].dt ....................... 0.1
#   interfaces[0].times .................... --------------------
#   interfaces[0].times: shape ............. (2,)
#   interfaces[0].times: dtype ............. int64
#   interfaces[0].times: values ............ [[0, 1]]
#   interfaces[0].spiking_proxy_inds ....... --------------------
#   interfaces[0].spiking_proxy_inds: shape  (2,)
#   interfaces[0].spiking_proxy_inds: dtype  int64
#   interfaces[0].spiking_proxy_inds: values  [[0, 1]]
#   interfaces[0].populations .............. --------------------
#   interfaces[0].populations: shape ....... (1,)
#   interfaces[0].populations: dtype ....... <U128
#   interfaces[0].populations: values ...... E
#   interfaces[0].model .................... ''
#   interfaces[0].gid ...................... UUID('f772693d-8b4b-41c2-8a5b-a781a6d7b271')
#   interfaces[0].number_of_proxy_nodes .... 2
#   interfaces[0].number_of_proxy_gids ..... 2
#   interfaces[0].proxy_gids ............... --------------------
#   interfaces[0].proxy_gids: shape ........ (2,)
#   interfaces[0].proxy_gids: dtype ........ int64
#   interfaces[0].proxy_gids: values ....... [[411, 412]]
#   interfaces[1] .......................... '--------------------'
#   interfaces[1].title .................... 'NESTOutputInterface gid: d123b74b-1c84-456d-82c6-fe947aae1a22'
#   interfaces[1].Type ..................... 'NESTOutputInterface'
#   interfaces[1].proxy .................... NESTSpikeRecorderTotalSet gid: 1ffe08db-b4ea-4502-a46c-b22d70302bc5
#   interfaces[1].spiking_network .......... NESTNetwork gid: bebeac52-45f0-4ec3-88ff-9e6192aa0860
#   interfaces[1].dt ....................... 0.1
#   interfaces[1].times .................... --------------------
#   interfaces[1].times: shape ............. (2,)
#   interfaces[1].times: dtype ............. int64
#   interfaces[1].times: values ............ [[0, 1]]
#   interfaces[1].spiking_proxy_inds ....... --------------------
#   interfaces[1].spiking_proxy_inds: shape  (2,)
#   interfaces[1].spiking_proxy_inds: dtype  int64
#   interfaces[1].spiking_proxy_inds: values  [[0, 1]]
#   interfaces[1].populations .............. --------------------
#   interfaces[1].populations: shape ....... (1,)
#   interfaces[1].populations: dtype ....... <U128
#   interfaces[1].populations: values ...... I
#   interfaces[1].model .................... ''
#   interfaces[1].gid ...................... UUID('d123b74b-1c84-456d-82c6-fe947aae1a22')
#   interfaces[1].number_of_proxy_nodes .... 2
#   interfaces[1].number_of_proxy_gids ..... 2
#   interfaces[1].proxy_gids ............... --------------------
#   interfaces[1].proxy_gids: shape ........ (2,)
#   interfaces[1].proxy_gids: dtype ........ int64
#   interfaces[1].proxy_gids: values ....... [[413, 414]]
#   synchronization_time ................... 3.6
#   synchronization_n_step ................. 36
#   gid .................................... UUID('0b8edcbf-4a21-404a-b770-a66d35338d0d')
#   number_of_interfaces ................... 2
#   number_of_populations .................. 2
#   populations_unique ..................... --------------------
#   populations_unique: shape .............. (2,)
#   populations_unique: dtype .............. <U1
#   populations_unique: values ............. ['E' 'I']
#   spiking_proxy_inds ..................... --------------------
#   spiking_proxy_inds: shape .............. (4,)
#   spiking_proxy_inds: dtype .............. int64
#   spiking_proxy_inds: =0 ................. {0, 2}
#   spiking_proxy_inds: =1 ................. {1, 3}
# )
# 2023-10-24 18:09:24,544 - INFO - tvb_multiscale.core.orchestrators.base -
# Configuring simulation with App NESTNRPApp...
# 2023-10-24 18:09:24,544 - INFO - tvb_multiscale.core.orchestrators.base -
# Configuring simulation with App NESTNRPApp...
# 2023-10-24 18:09:24,544 - INFO - tvb_multiscale.core.orchestrators.base -
# Configuring simulation with App NESTNRPApp...
#
# Configuring simulation with App NESTNRPApp...
# 2023-10-24 18:09:24,546 - INFO - tvb_multiscale.core.orchestrators.base -
# Setting NESTNRPApp synchronization_time from interfaces = 3.6
# 2023-10-24 18:09:24,546 - INFO - tvb_multiscale.core.orchestrators.base -
# Setting NESTNRPApp synchronization_time from interfaces = 3.6
# 2023-10-24 18:09:24,546 - INFO - tvb_multiscale.core.orchestrators.base -
# Setting NESTNRPApp synchronization_time from interfaces = 3.6
#
# Setting NESTNRPApp synchronization_time from interfaces = 3.6
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/spiking_models/node_set.py:77: FutureWarning:Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/spiking_models/node_set.py:77: FutureWarning:Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/spiking_models/node_set.py:77: FutureWarning:Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/spiking_models/node_set.py:77: FutureWarning:Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`

# %%
from tvb_multiscale.core.nrp.init.transformers import tvb_to_spikeNet_transformer_init, spikeNet_to_tvb_transformer_init


tvb_to_spikeNet_app = tvb_to_spikeNet_transformer_init(config)

spikeNet_to_tvb_app = spikeNet_to_tvb_transformer_init(config)
# Out:
# Starting App NRPTVBtoSpikeNetTransformerApp...
# 2023-10-24 18:09:24,561 - INFO - tvb_multiscale.core.orchestrators.base -
# Building with App NRPTVBtoSpikeNetTransformerApp...
# 2023-10-24 18:09:24,561 - INFO - tvb_multiscale.core.orchestrators.base -
# Building with App NRPTVBtoSpikeNetTransformerApp...
# 2023-10-24 18:09:24,561 - INFO - tvb_multiscale.core.orchestrators.base -
# Building with App NRPTVBtoSpikeNetTransformerApp...
# 2023-10-24 18:09:24,561 - INFO - tvb_multiscale.core.orchestrators.base -
# Building with App NRPTVBtoSpikeNetTransformerApp...
#
# Building with App NRPTVBtoSpikeNetTransformerApp...
# 2023-10-24 18:09:24,562 - INFO - tvb_multiscale.core.orchestrators.base -
# Building interfaces' with builder TVBtoSpikeNetTransformerInterfaceBuilder of App NRPTVBtoSpikeNetTransformerApp...
# 2023-10-24 18:09:24,562 - INFO - tvb_multiscale.core.orchestrators.base -
# Building interfaces' with builder TVBtoSpikeNetTransformerInterfaceBuilder of App NRPTVBtoSpikeNetTransformerApp...
# 2023-10-24 18:09:24,562 - INFO - tvb_multiscale.core.orchestrators.base -
# Building interfaces' with builder TVBtoSpikeNetTransformerInterfaceBuilder of App NRPTVBtoSpikeNetTransformerApp...
# 2023-10-24 18:09:24,562 - INFO - tvb_multiscale.core.orchestrators.base -
# Building interfaces' with builder TVBtoSpikeNetTransformerInterfaceBuilder of App NRPTVBtoSpikeNetTransformerApp...
#
# Building interfaces' with builder TVBtoSpikeNetTransformerInterfaceBuilder of App NRPTVBtoSpikeNetTransformerApp...
# 2023-10-24 18:09:24,565 - INFO - tvb_multiscale.core.orchestrators.base -
# Instantiating interfaces' builder TVBtoSpikeNetTransformerInterfaceBuilder of App NRPTVBtoSpikeNetTransformerApp...
# 2023-10-24 18:09:24,565 - INFO - tvb_multiscale.core.orchestrators.base -
# Instantiating interfaces' builder TVBtoSpikeNetTransformerInterfaceBuilder of App NRPTVBtoSpikeNetTransformerApp...
# 2023-10-24 18:09:24,565 - INFO - tvb_multiscale.core.orchestrators.base -
# Instantiating interfaces' builder TVBtoSpikeNetTransformerInterfaceBuilder of App NRPTVBtoSpikeNetTransformerApp...
# 2023-10-24 18:09:24,565 - INFO - tvb_multiscale.core.orchestrators.base -
# Instantiating interfaces' builder TVBtoSpikeNetTransformerInterfaceBuilder of App NRPTVBtoSpikeNetTransformerApp...
#
# Instantiating interfaces' builder TVBtoSpikeNetTransformerInterfaceBuilder of App NRPTVBtoSpikeNetTransformerApp...
# 2023-10-24 18:09:24,567 - INFO - tvb_multiscale.core.orchestrators.base -
# Configuring interfaces' builder TVBtoSpikeNetTransformerInterfaceBuilder of App NRPTVBtoSpikeNetTransformerApp...
# 2023-10-24 18:09:24,567 - INFO - tvb_multiscale.core.orchestrators.base -
# Configuring interfaces' builder TVBtoSpikeNetTransformerInterfaceBuilder of App NRPTVBtoSpikeNetTransformerApp...
# 2023-10-24 18:09:24,567 - INFO - tvb_multiscale.core.orchestrators.base -
# Configuring interfaces' builder TVBtoSpikeNetTransformerInterfaceBuilder of App NRPTVBtoSpikeNetTransformerApp...
# 2023-10-24 18:09:24,567 - INFO - tvb_multiscale.core.orchestrators.base -
# Configuring interfaces' builder TVBtoSpikeNetTransformerInterfaceBuilder of App NRPTVBtoSpikeNetTransformerApp...
#
# Configuring interfaces' builder TVBtoSpikeNetTransformerInterfaceBuilder of App NRPTVBtoSpikeNetTransformerApp...
# 2023-10-24 18:09:24,569 - INFO - tvb_multiscale.core.orchestrators.base -
# Reading interfaces' configurations from files...
# 2023-10-24 18:09:24,569 - INFO - tvb_multiscale.core.orchestrators.base -
# Reading interfaces' configurations from files...
# 2023-10-24 18:09:24,569 - INFO - tvb_multiscale.core.orchestrators.base -
# Reading interfaces' configurations from files...
# 2023-10-24 18:09:24,569 - INFO - tvb_multiscale.core.orchestrators.base -
# Reading interfaces' configurations from files...
#
# Reading interfaces' configurations from files...
# loading all interfaces
# 2023-10-24 18:09:24,574 - INFO - tvb_multiscale.core.orchestrators.base -
# TVBtoSpikeNetTransformerInterfaces (
#   title ................... 'TVBtoSpikeNetTransformerInterfaces gid: 5fc27211-618d-4915-ac0a-146756d0de97'
#   Type .................... 'TVBtoSpikeNetTransformerInterfaces'
#   interfaces[0] ........... '--------------------'
#   interfaces[0].title ..... 'TVBtoSpikeNetTransformerInterface gid: 5bef08cc-dc2d-4173-b8b7-8ee42aff21c1'
#   interfaces[0].Type ...... 'TVBtoSpikeNetTransformerInterface'
#   interfaces[0].transformer  LinearRate gid: e3a2db26-2b8d-48f3-b0d5-d6a8f8f643dc
#   interfaces[0].model ..... ''
#   interfaces[0].gid ....... UUID('5bef08cc-dc2d-4173-b8b7-8ee42aff21c1')
#   synchronization_time .... 3.6
#   synchronization_n_step .. 36
#   gid ..................... UUID('5fc27211-618d-4915-ac0a-146756d0de97')
#   number_of_interfaces .... 1
# )
# 2023-10-24 18:09:24,574 - INFO - tvb_multiscale.core.orchestrators.base -
# TVBtoSpikeNetTransformerInterfaces (
#   title ................... 'TVBtoSpikeNetTransformerInterfaces gid: 5fc27211-618d-4915-ac0a-146756d0de97'
#   Type .................... 'TVBtoSpikeNetTransformerInterfaces'
#   interfaces[0] ........... '--------------------'
#   interfaces[0].title ..... 'TVBtoSpikeNetTransformerInterface gid: 5bef08cc-dc2d-4173-b8b7-8ee42aff21c1'
#   interfaces[0].Type ...... 'TVBtoSpikeNetTransformerInterface'
#   interfaces[0].transformer  LinearRate gid: e3a2db26-2b8d-48f3-b0d5-d6a8f8f643dc
#   interfaces[0].model ..... ''
#   interfaces[0].gid ....... UUID('5bef08cc-dc2d-4173-b8b7-8ee42aff21c1')
#   synchronization_time .... 3.6
#   synchronization_n_step .. 36
#   gid ..................... UUID('5fc27211-618d-4915-ac0a-146756d0de97')
#   number_of_interfaces .... 1
# )
# 2023-10-24 18:09:24,574 - INFO - tvb_multiscale.core.orchestrators.base -
# TVBtoSpikeNetTransformerInterfaces (
#   title ................... 'TVBtoSpikeNetTransformerInterfaces gid: 5fc27211-618d-4915-ac0a-146756d0de97'
#   Type .................... 'TVBtoSpikeNetTransformerInterfaces'
#   interfaces[0] ........... '--------------------'
#   interfaces[0].title ..... 'TVBtoSpikeNetTransformerInterface gid: 5bef08cc-dc2d-4173-b8b7-8ee42aff21c1'
#   interfaces[0].Type ...... 'TVBtoSpikeNetTransformerInterface'
#   interfaces[0].transformer  LinearRate gid: e3a2db26-2b8d-48f3-b0d5-d6a8f8f643dc
#   interfaces[0].model ..... ''
#   interfaces[0].gid ....... UUID('5bef08cc-dc2d-4173-b8b7-8ee42aff21c1')
#   synchronization_time .... 3.6
#   synchronization_n_step .. 36
#   gid ..................... UUID('5fc27211-618d-4915-ac0a-146756d0de97')
#   number_of_interfaces .... 1
# )
# 2023-10-24 18:09:24,574 - INFO - tvb_multiscale.core.orchestrators.base -
# TVBtoSpikeNetTransformerInterfaces (
#   title ................... 'TVBtoSpikeNetTransformerInterfaces gid: 5fc27211-618d-4915-ac0a-146756d0de97'
#   Type .................... 'TVBtoSpikeNetTransformerInterfaces'
#   interfaces[0] ........... '--------------------'
#   interfaces[0].title ..... 'TVBtoSpikeNetTransformerInterface gid: 5bef08cc-dc2d-4173-b8b7-8ee42aff21c1'
#   interfaces[0].Type ...... 'TVBtoSpikeNetTransformerInterface'
#   interfaces[0].transformer  LinearRate gid: e3a2db26-2b8d-48f3-b0d5-d6a8f8f643dc
#   interfaces[0].model ..... ''
#   interfaces[0].gid ....... UUID('5bef08cc-dc2d-4173-b8b7-8ee42aff21c1')
#   synchronization_time .... 3.6
#   synchronization_n_step .. 36
#   gid ..................... UUID('5fc27211-618d-4915-ac0a-146756d0de97')
#   number_of_interfaces .... 1
# )
#
# TVBtoSpikeNetTransformerInterfaces (
#   title ................... 'TVBtoSpikeNetTransformerInterfaces gid: 5fc27211-618d-4915-ac0a-146756d0de97'
#   Type .................... 'TVBtoSpikeNetTransformerInterfaces'
#   interfaces[0] ........... '--------------------'
#   interfaces[0].title ..... 'TVBtoSpikeNetTransformerInterface gid: 5bef08cc-dc2d-4173-b8b7-8ee42aff21c1'
#   interfaces[0].Type ...... 'TVBtoSpikeNetTransformerInterface'
#   interfaces[0].transformer  LinearRate gid: e3a2db26-2b8d-48f3-b0d5-d6a8f8f643dc
#   interfaces[0].model ..... ''
#   interfaces[0].gid ....... UUID('5bef08cc-dc2d-4173-b8b7-8ee42aff21c1')
#   synchronization_time .... 3.6
#   synchronization_n_step .. 36
#   gid ..................... UUID('5fc27211-618d-4915-ac0a-146756d0de97')
#   number_of_interfaces .... 1
# )
# 2023-10-24 18:09:24,577 - INFO - tvb_multiscale.core.orchestrators.base -
# Configuring simulation with App NRPTVBtoSpikeNetTransformerApp...
# 2023-10-24 18:09:24,577 - INFO - tvb_multiscale.core.orchestrators.base -
# Configuring simulation with App NRPTVBtoSpikeNetTransformerApp...
# 2023-10-24 18:09:24,577 - INFO - tvb_multiscale.core.orchestrators.base -
# Configuring simulation with App NRPTVBtoSpikeNetTransformerApp...
# 2023-10-24 18:09:24,577 - INFO - tvb_multiscale.core.orchestrators.base -
# Configuring simulation with App NRPTVBtoSpikeNetTransformerApp...
#
# Configuring simulation with App NRPTVBtoSpikeNetTransformerApp...
#
# Starting App NRPSpikeNetToTVBTransformerApp...
# 2023-10-24 18:09:24,580 - INFO - tvb_multiscale.core.orchestrators.base -
# Building with App NRPSpikeNetToTVBTransformerApp...
# 2023-10-24 18:09:24,580 - INFO - tvb_multiscale.core.orchestrators.base -
# Building with App NRPSpikeNetToTVBTransformerApp...
# 2023-10-24 18:09:24,580 - INFO - tvb_multiscale.core.orchestrators.base -
# Building with App NRPSpikeNetToTVBTransformerApp...
# 2023-10-24 18:09:24,580 - INFO - tvb_multiscale.core.orchestrators.base -
# Building with App NRPSpikeNetToTVBTransformerApp...
# 2023-10-24 18:09:24,580 - INFO - tvb_multiscale.core.orchestrators.base -
# Building with App NRPSpikeNetToTVBTransformerApp...
#
# Building with App NRPSpikeNetToTVBTransformerApp...
# 2023-10-24 18:09:24,582 - INFO - tvb_multiscale.core.orchestrators.base -
# Building interfaces' with builder SpikeNetToTVBTransformerInterfaceBuilder of App NRPSpikeNetToTVBTransformerApp...
# 2023-10-24 18:09:24,582 - INFO - tvb_multiscale.core.orchestrators.base -
# Building interfaces' with builder SpikeNetToTVBTransformerInterfaceBuilder of App NRPSpikeNetToTVBTransformerApp...
# 2023-10-24 18:09:24,582 - INFO - tvb_multiscale.core.orchestrators.base -
# Building interfaces' with builder SpikeNetToTVBTransformerInterfaceBuilder of App NRPSpikeNetToTVBTransformerApp...
# 2023-10-24 18:09:24,582 - INFO - tvb_multiscale.core.orchestrators.base -
# Building interfaces' with builder SpikeNetToTVBTransformerInterfaceBuilder of App NRPSpikeNetToTVBTransformerApp...
# 2023-10-24 18:09:24,582 - INFO - tvb_multiscale.core.orchestrators.base -
# Building interfaces' with builder SpikeNetToTVBTransformerInterfaceBuilder of App NRPSpikeNetToTVBTransformerApp...
#
# Building interfaces' with builder SpikeNetToTVBTransformerInterfaceBuilder of App NRPSpikeNetToTVBTransformerApp...
# 2023-10-24 18:09:24,585 - INFO - tvb_multiscale.core.orchestrators.base -
# Instantiating interfaces' builder SpikeNetToTVBTransformerInterfaceBuilder of App NRPSpikeNetToTVBTransformerApp...
# 2023-10-24 18:09:24,585 - INFO - tvb_multiscale.core.orchestrators.base -
# Instantiating interfaces' builder SpikeNetToTVBTransformerInterfaceBuilder of App NRPSpikeNetToTVBTransformerApp...
# 2023-10-24 18:09:24,585 - INFO - tvb_multiscale.core.orchestrators.base -
# Instantiating interfaces' builder SpikeNetToTVBTransformerInterfaceBuilder of App NRPSpikeNetToTVBTransformerApp...
# 2023-10-24 18:09:24,585 - INFO - tvb_multiscale.core.orchestrators.base -
# Instantiating interfaces' builder SpikeNetToTVBTransformerInterfaceBuilder of App NRPSpikeNetToTVBTransformerApp...
# 2023-10-24 18:09:24,585 - INFO - tvb_multiscale.core.orchestrators.base -
# Instantiating interfaces' builder SpikeNetToTVBTransformerInterfaceBuilder of App NRPSpikeNetToTVBTransformerApp...
#
# Instantiating interfaces' builder SpikeNetToTVBTransformerInterfaceBuilder of App NRPSpikeNetToTVBTransformerApp...
# 2023-10-24 18:09:24,588 - INFO - tvb_multiscale.core.orchestrators.base -
# Configuring interfaces' builder SpikeNetToTVBTransformerInterfaceBuilder of App NRPSpikeNetToTVBTransformerApp...
# 2023-10-24 18:09:24,588 - INFO - tvb_multiscale.core.orchestrators.base -
# Configuring interfaces' builder SpikeNetToTVBTransformerInterfaceBuilder of App NRPSpikeNetToTVBTransformerApp...
# 2023-10-24 18:09:24,588 - INFO - tvb_multiscale.core.orchestrators.base -
# Configuring interfaces' builder SpikeNetToTVBTransformerInterfaceBuilder of App NRPSpikeNetToTVBTransformerApp...
# 2023-10-24 18:09:24,588 - INFO - tvb_multiscale.core.orchestrators.base -
# Configuring interfaces' builder SpikeNetToTVBTransformerInterfaceBuilder of App NRPSpikeNetToTVBTransformerApp...
# 2023-10-24 18:09:24,588 - INFO - tvb_multiscale.core.orchestrators.base -
# Configuring interfaces' builder SpikeNetToTVBTransformerInterfaceBuilder of App NRPSpikeNetToTVBTransformerApp...
#
# Configuring interfaces' builder SpikeNetToTVBTransformerInterfaceBuilder of App NRPSpikeNetToTVBTransformerApp...
# 2023-10-24 18:09:24,590 - INFO - tvb_multiscale.core.orchestrators.base -
# Reading interfaces' configurations from files...
# 2023-10-24 18:09:24,590 - INFO - tvb_multiscale.core.orchestrators.base -
# Reading interfaces' configurations from files...
# 2023-10-24 18:09:24,590 - INFO - tvb_multiscale.core.orchestrators.base -
# Reading interfaces' configurations from files...
# 2023-10-24 18:09:24,590 - INFO - tvb_multiscale.core.orchestrators.base -
# Reading interfaces' configurations from files...
# 2023-10-24 18:09:24,590 - INFO - tvb_multiscale.core.orchestrators.base -
# Reading interfaces' configurations from files...
#
# Reading interfaces' configurations from files...
# loading all interfaces
# 2023-10-24 18:09:24,596 - INFO - tvb_multiscale.core.orchestrators.base -
# SpikeNetToTVBTransformerInterfaces (
#   title ................... 'SpikeNetToTVBTransformerInterfaces gid: 206120b7-e8a6-4c90-a6fa-ae71356c0229'
#   Type .................... 'SpikeNetToTVBTransformerInterfaces'
#   interfaces[0] ........... '--------------------'
#   interfaces[0].title ..... 'SpikeNetToTVBTransformerInterface gid: b8e318ea-1326-4b8d-81f0-78530783eecf'
#   interfaces[0].Type ...... 'SpikeNetToTVBTransformerInterface'
#   interfaces[0].transformer  ElephantSpikesHistogramRate gid: d0da7928-df32-451c-95e6-67cd98112a63
#   interfaces[0].model ..... ''
#   interfaces[0].gid ....... UUID('b8e318ea-1326-4b8d-81f0-78530783eecf')
#   interfaces[1] ........... '--------------------'
#   interfaces[1].title ..... 'SpikeNetToTVBTransformerInterface gid: 5d3f956d-d968-4520-82b7-6c5ee43af5ec'
#   interfaces[1].Type ...... 'SpikeNetToTVBTransformerInterface'
#   interfaces[1].transformer  ElephantSpikesHistogramRate gid: eb84b0bf-af7a-42b1-aeb0-03bdf640a493
#   interfaces[1].model ..... ''
#   interfaces[1].gid ....... UUID('5d3f956d-d968-4520-82b7-6c5ee43af5ec')
#   synchronization_time .... 3.6
#   synchronization_n_step .. 36
#   gid ..................... UUID('206120b7-e8a6-4c90-a6fa-ae71356c0229')
#   number_of_interfaces .... 2
# )
# 2023-10-24 18:09:24,596 - INFO - tvb_multiscale.core.orchestrators.base -
# SpikeNetToTVBTransformerInterfaces (
#   title ................... 'SpikeNetToTVBTransformerInterfaces gid: 206120b7-e8a6-4c90-a6fa-ae71356c0229'
#   Type .................... 'SpikeNetToTVBTransformerInterfaces'
#   interfaces[0] ........... '--------------------'
#   interfaces[0].title ..... 'SpikeNetToTVBTransformerInterface gid: b8e318ea-1326-4b8d-81f0-78530783eecf'
#   interfaces[0].Type ...... 'SpikeNetToTVBTransformerInterface'
#   interfaces[0].transformer  ElephantSpikesHistogramRate gid: d0da7928-df32-451c-95e6-67cd98112a63
#   interfaces[0].model ..... ''
#   interfaces[0].gid ....... UUID('b8e318ea-1326-4b8d-81f0-78530783eecf')
#   interfaces[1] ........... '--------------------'
#   interfaces[1].title ..... 'SpikeNetToTVBTransformerInterface gid: 5d3f956d-d968-4520-82b7-6c5ee43af5ec'
#   interfaces[1].Type ...... 'SpikeNetToTVBTransformerInterface'
#   interfaces[1].transformer  ElephantSpikesHistogramRate gid: eb84b0bf-af7a-42b1-aeb0-03bdf640a493
#   interfaces[1].model ..... ''
#   interfaces[1].gid ....... UUID('5d3f956d-d968-4520-82b7-6c5ee43af5ec')
#   synchronization_time .... 3.6
#   synchronization_n_step .. 36
#   gid ..................... UUID('206120b7-e8a6-4c90-a6fa-ae71356c0229')
#   number_of_interfaces .... 2
# )
# 2023-10-24 18:09:24,596 - INFO - tvb_multiscale.core.orchestrators.base -
# SpikeNetToTVBTransformerInterfaces (
#   title ................... 'SpikeNetToTVBTransformerInterfaces gid: 206120b7-e8a6-4c90-a6fa-ae71356c0229'
#   Type .................... 'SpikeNetToTVBTransformerInterfaces'
#   interfaces[0] ........... '--------------------'
#   interfaces[0].title ..... 'SpikeNetToTVBTransformerInterface gid: b8e318ea-1326-4b8d-81f0-78530783eecf'
#   interfaces[0].Type ...... 'SpikeNetToTVBTransformerInterface'
#   interfaces[0].transformer  ElephantSpikesHistogramRate gid: d0da7928-df32-451c-95e6-67cd98112a63
#   interfaces[0].model ..... ''
#   interfaces[0].gid ....... UUID('b8e318ea-1326-4b8d-81f0-78530783eecf')
#   interfaces[1] ........... '--------------------'
#   interfaces[1].title ..... 'SpikeNetToTVBTransformerInterface gid: 5d3f956d-d968-4520-82b7-6c5ee43af5ec'
#   interfaces[1].Type ...... 'SpikeNetToTVBTransformerInterface'
#   interfaces[1].transformer  ElephantSpikesHistogramRate gid: eb84b0bf-af7a-42b1-aeb0-03bdf640a493
#   interfaces[1].model ..... ''
#   interfaces[1].gid ....... UUID('5d3f956d-d968-4520-82b7-6c5ee43af5ec')
#   synchronization_time .... 3.6
#   synchronization_n_step .. 36
#   gid ..................... UUID('206120b7-e8a6-4c90-a6fa-ae71356c0229')
#   number_of_interfaces .... 2
# )
# 2023-10-24 18:09:24,596 - INFO - tvb_multiscale.core.orchestrators.base -
# SpikeNetToTVBTransformerInterfaces (
#   title ................... 'SpikeNetToTVBTransformerInterfaces gid: 206120b7-e8a6-4c90-a6fa-ae71356c0229'
#   Type .................... 'SpikeNetToTVBTransformerInterfaces'
#   interfaces[0] ........... '--------------------'
#   interfaces[0].title ..... 'SpikeNetToTVBTransformerInterface gid: b8e318ea-1326-4b8d-81f0-78530783eecf'
#   interfaces[0].Type ...... 'SpikeNetToTVBTransformerInterface'
#   interfaces[0].transformer  ElephantSpikesHistogramRate gid: d0da7928-df32-451c-95e6-67cd98112a63
#   interfaces[0].model ..... ''
#   interfaces[0].gid ....... UUID('b8e318ea-1326-4b8d-81f0-78530783eecf')
#   interfaces[1] ........... '--------------------'
#   interfaces[1].title ..... 'SpikeNetToTVBTransformerInterface gid: 5d3f956d-d968-4520-82b7-6c5ee43af5ec'
#   interfaces[1].Type ...... 'SpikeNetToTVBTransformerInterface'
#   interfaces[1].transformer  ElephantSpikesHistogramRate gid: eb84b0bf-af7a-42b1-aeb0-03bdf640a493
#   interfaces[1].model ..... ''
#   interfaces[1].gid ....... UUID('5d3f956d-d968-4520-82b7-6c5ee43af5ec')
#   synchronization_time .... 3.6
#   synchronization_n_step .. 36
#   gid ..................... UUID('206120b7-e8a6-4c90-a6fa-ae71356c0229')
#   number_of_interfaces .... 2
# )
# 2023-10-24 18:09:24,596 - INFO - tvb_multiscale.core.orchestrators.base -
# SpikeNetToTVBTransformerInterfaces (
#   title ................... 'SpikeNetToTVBTransformerInterfaces gid: 206120b7-e8a6-4c90-a6fa-ae71356c0229'
#   Type .................... 'SpikeNetToTVBTransformerInterfaces'
#   interfaces[0] ........... '--------------------'
#   interfaces[0].title ..... 'SpikeNetToTVBTransformerInterface gid: b8e318ea-1326-4b8d-81f0-78530783eecf'
#   interfaces[0].Type ...... 'SpikeNetToTVBTransformerInterface'
#   interfaces[0].transformer  ElephantSpikesHistogramRate gid: d0da7928-df32-451c-95e6-67cd98112a63
#   interfaces[0].model ..... ''
#   interfaces[0].gid ....... UUID('b8e318ea-1326-4b8d-81f0-78530783eecf')
#   interfaces[1] ........... '--------------------'
#   interfaces[1].title ..... 'SpikeNetToTVBTransformerInterface gid: 5d3f956d-d968-4520-82b7-6c5ee43af5ec'
#   interfaces[1].Type ...... 'SpikeNetToTVBTransformerInterface'
#   interfaces[1].transformer  ElephantSpikesHistogramRate gid: eb84b0bf-af7a-42b1-aeb0-03bdf640a493
#   interfaces[1].model ..... ''
#   interfaces[1].gid ....... UUID('5d3f956d-d968-4520-82b7-6c5ee43af5ec')
#   synchronization_time .... 3.6
#   synchronization_n_step .. 36
#   gid ..................... UUID('206120b7-e8a6-4c90-a6fa-ae71356c0229')
#   number_of_interfaces .... 2
# )
#
# SpikeNetToTVBTransformerInterfaces (
#   title ................... 'SpikeNetToTVBTransformerInterfaces gid: 206120b7-e8a6-4c90-a6fa-ae71356c0229'
#   Type .................... 'SpikeNetToTVBTransformerInterfaces'
#   interfaces[0] ........... '--------------------'
#   interfaces[0].title ..... 'SpikeNetToTVBTransformerInterface gid: b8e318ea-1326-4b8d-81f0-78530783eecf'
#   interfaces[0].Type ...... 'SpikeNetToTVBTransformerInterface'
#   interfaces[0].transformer  ElephantSpikesHistogramRate gid: d0da7928-df32-451c-95e6-67cd98112a63
#   interfaces[0].model ..... ''
#   interfaces[0].gid ....... UUID('b8e318ea-1326-4b8d-81f0-78530783eecf')
#   interfaces[1] ........... '--------------------'
#   interfaces[1].title ..... 'SpikeNetToTVBTransformerInterface gid: 5d3f956d-d968-4520-82b7-6c5ee43af5ec'
#   interfaces[1].Type ...... 'SpikeNetToTVBTransformerInterface'
#   interfaces[1].transformer  ElephantSpikesHistogramRate gid: eb84b0bf-af7a-42b1-aeb0-03bdf640a493
#   interfaces[1].model ..... ''
#   interfaces[1].gid ....... UUID('5d3f956d-d968-4520-82b7-6c5ee43af5ec')
#   synchronization_time .... 3.6
#   synchronization_n_step .. 36
#   gid ..................... UUID('206120b7-e8a6-4c90-a6fa-ae71356c0229')
#   number_of_interfaces .... 2
# )
# 2023-10-24 18:09:24,599 - INFO - tvb_multiscale.core.orchestrators.base -
# Configuring simulation with App NRPSpikeNetToTVBTransformerApp...
# 2023-10-24 18:09:24,599 - INFO - tvb_multiscale.core.orchestrators.base -
# Configuring simulation with App NRPSpikeNetToTVBTransformerApp...
# 2023-10-24 18:09:24,599 - INFO - tvb_multiscale.core.orchestrators.base -
# Configuring simulation with App NRPSpikeNetToTVBTransformerApp...
# 2023-10-24 18:09:24,599 - INFO - tvb_multiscale.core.orchestrators.base -
# Configuring simulation with App NRPSpikeNetToTVBTransformerApp...
# 2023-10-24 18:09:24,599 - INFO - tvb_multiscale.core.orchestrators.base -
# Configuring simulation with App NRPSpikeNetToTVBTransformerApp...
#
# Configuring simulation with App NRPSpikeNetToTVBTransformerApp...

# %% [markdown]
# ## 4. Simulate, gather results

# %%
from tvb_multiscale.core.nrp.run import *


def run_for_synchronization_time_sync_min_delay(
    tvb_app, spikeNet_app, tvb_to_spikeNet_app, spikeNet_to_tvb_app,
    tvb_to_trans_cosim_updates=None, trans_to_spikeNet_cosim_updates=None,
    spikeNet_to_trans_cosim_updates=None,  trans_to_tvb_cosim_updates=None):
    """Function for cosimulating for one loop of synchronization time.
       It could be the highest level possible ENTRYPOINT for a parallel cosimulation.
       In that case, the cosimulation manager would be completely agnostic
       - of what the Apps of the different processed do,
       - including the transformation function they employ.
       The ENTRYPOINT here is just the cosimulation updates' data,
       which are "thrown over the wall" for the necessary data exchanges.
       Co-Simulator and bidirectional Transformers have to alternate between them, 
       and can be parallelized within (CoSimulator and Transformers respectively).
    """
    # Transform TVB -> spikeNet couplings of times [t, t + Tsync] = [t, t + min_tvb_delay]...
    # ...or TVB -> spikeNet state of times [t - Tsync, t]=[t - min_tvb_delay, t]
    if tvb_to_trans_cosim_updates is not None:
        # ...if any:
        trans_to_spikeNet_cosim_updates = run_transformer(tvb_to_spikeNet_app, tvb_to_trans_cosim_updates)
    else:
        trans_to_spikeNet_cosim_updates = None
    # Transform SpikeNet -> TVB updates of times [t - Tsync, t] = [t - min_tvb_delay, t]...
    if spikeNet_to_trans_cosim_updates is not None:
        # ...if any:
        trans_to_tvb_cosim_updates = run_transformer(spikeNet_to_tvb_app, spikeNet_to_trans_cosim_updates)
    else:
        trans_to_tvb_cosim_updates = None
    # TVB t -> t + Tsync
    # Simulate TVB for times [t, t + Tsync] = [t, t + min_tvb_delay]
    # with or without spikeNet update inputs of times [t - Tsync, t] = [t - min_tvb_delay, t]
    tvb_to_trans_cosim_updates = run_tvb(tvb_app, trans_to_tvb_cosim_updates)
    # SpikeNet t -> t + Tsync
    # Simulate spikeNet for times [t, t + Tsync] = [t, t + min_tvb_delay]
    # with or without TVB coupling inputs of times [t, t + min_tvb_delay]
    # or TVB state inputs of times [t - min_tvb_delay/2, t]
    spikeNet_to_trans_cosim_updates = run_spikeNet(spikeNet_app, trans_to_spikeNet_cosim_updates)
    return tvb_to_trans_cosim_updates, trans_to_spikeNet_cosim_updates, \
           spikeNet_to_trans_cosim_updates, trans_to_tvb_cosim_updates


def run_for_synchronization_time_sync_min_delay2(
    tvb_app, spikeNet_app, tvb_to_spikeNet_app, spikeNet_to_tvb_app,
    input_tvb_to_trans_cosim_updates=None, input_trans_to_spikeNet_cosim_updates=None,
    input_spikeNet_to_trans_cosim_updates=None,  input_trans_to_tvb_cosim_updates=None):
    """Function for cosimulating for one loop of synchronization time.
       It could be the highest level possible ENTRYPOINT for a parallel cosimulation.
       In that case, the cosimulation manager would be completely agnostic
       - of what the Apps of the different processed do,
       - including the transformation function they employ.
       The ENTRYPOINT here is just the cosimulation updates' data,
       which are "thrown over the wall" for the necessary data exchanges.
       All processes can work in parallel, 
       since the transformers work on time intervals than those simulated by the cosimulators.
    """
    # Transform TVB -> SpikeNet couplings of times [t + Tsync, t + 2*Tsync]=[t + min_tvb_delay/2, t + min_tvb_delay]...
    # ...or TVB -> spikeNet state of times [t - Tsync, t]=[t - min_tvb_delay/2, t]
    if input_tvb_to_trans_cosim_updates is not None:
        # ...if any:
        trans_to_spikeNet_cosim_updates = run_transformer(tvb_to_spikeNet_app, input_tvb_to_trans_cosim_updates)
    else:
        trans_to_spikeNet_cosim_updates = None
    # Transform SpikeNet -> TVB updates of times [t - Tsync, t]=[t - min_tvb_delay/2, t]...
    if input_spikeNet_to_trans_cosim_updates is not None:
        # ...if any:
        trans_to_tvb_cosim_updates = run_transformer(spikeNet_to_tvb_app, input_spikeNet_to_trans_cosim_updates)
    else:
        trans_to_tvb_cosim_updates = None
    # TVB t -> t + Tsync
    # Simulate TVB for times [t, t + Tsync] = [t, t + min_tvb_delay/2]
    # with or without SpikeNet update inputs of times [t - 2*Tsync, t - Tsync] = [t - min_tvb_delay/, t - min_tvb_delay/2]
    tvb_to_trans_cosim_updates = run_tvb(tvb_app, input_trans_to_tvb_cosim_updates)
    # SpikeNet t -> t + Tsync
    # Simulate SpikeNet for times [t, t + Tsync] = [t, t + min_tvb_delay/2]
    # with or without TVB coupling inputs of times [t, t + min_tvb_delay/2]
    # or TVB state inputs of times [t - min_tvb_delay, t - min_tvb_delay/2]
    spikeNet_to_trans_cosim_updates = run_spikeNet(spikeNet_app, input_trans_to_spikeNet_cosim_updates)
    return tvb_to_trans_cosim_updates, trans_to_spikeNet_cosim_updates, \
           spikeNet_to_trans_cosim_updates, trans_to_tvb_cosim_updates



def run_cosimulation(tvb_app, spikeNet_app, tvb_to_spikeNet_app, spikeNet_to_tvb_app,
                     advance_simulation_for_delayed_monitors_output=True):
    """Function for running the whole cosimulation, assuming all Apps are built and configured.
       This function shows the necessary initialization of the cosimulation.
    """

    import time
    import numpy as np

    # Keep the following cosimulation attributes safe and easy to access:
    simulation_length = tvb_app.cosimulator.simulation_length 
    synchronization_time = tvb_app.cosimulator.synchronization_time
    synchronization_n_step = tvb_app.cosimulator.synchronization_n_step  # store the configured value
    if advance_simulation_for_delayed_monitors_output:
        simulation_length += synchronization_time
    dt = tvb_app.cosimulator.integrator.dt
    
    # Initial conditions of co-simulation:
    
    tvb_app.cosimulator.relative_output_interfaces_time_steps = 0
    tvb_app.cosimulator.relative_output_time_steps = 0
    
    # TVB initial condition cosimulation data towards spikeNet 
    # - of TVB coupling for [0, Tsync] if INTERFACE_COUPLING_MODE == "TVB"
    # - of TVB state for [-Tsync, 0] if INTERFACE_COUPLING_MODE == "spikeNet"
    tvb_to_trans_cosim_updates = tvb_app.get_tvb_init_cosim_coupling(relative_output_interfaces_time_steps=0)
    # SpikeNet initial condition update towards TVB:
    spikeNet_to_trans_cosim_updates = None
    # Transformer to TVB initial condition:
    trans_to_tvb_cosim_updates = None
    # Transformer to SpikeNet initial condition:
    trans_to_spikeNet_cosim_updates = None
    if tvb_app.cosimulator.min_idelay_sync_n_step_ratio == 2:
        run_for_synchronization_time = run_for_synchronization_time_sync_min_delay2
        tvb_app.cosimulator.relative_output_time_steps = tvb_app.cosimulator.synchronization_n_step
        if advance_simulation_for_delayed_monitors_output:
            simulation_length += tvb_app.cosimulator.relative_output_time_steps * tvb_app.cosimulator.integrator.dt
        if tvb_app.config.INTERFACE_COUPLING_MODE == "TVB":
        # If this is a TVB coupling interface,
            # ...transform the initial condition for [0, Tsync] = [0 min_tvb_delay/2] from TVB to SpikeNet:
            if tvb_to_trans_cosim_updates is not None:
                # ...if any:
                trans_to_spikeNet_cosim_updates = tvb_to_spikeNet_app.run_for_synchronization_time(tvb_to_trans_cosim_updates)
            # ...and advance the data sent from TVB towards the transformer,
            # by Tsync = min_tvb_delay / 2
            # TVB initial condition cosimulation coupling towards SpikeNet 
            # for [Tsync, 2*Tsync] = [min_tvb_delay/2, min_tvb_delay]
            tvb_to_trans_cosim_updates = tvb_app.get_tvb_init_cosim_coupling(
                relative_output_interfaces_time_steps=tvb_app.cosimulator.synchronization_n_step) 
            # Keep this advancement in time for the simulation to follow:
            tvb_app.cosimulator.relative_output_interfaces_time_steps = tvb_app.cosimulator.synchronization_n_step
        else:
            # If this is a spikeNet coupling interface,
            # ...get the past state from TVB towards the transformer,
            # by Tsync = -min_tvb_delay / 2
            # TVB initial condition cosimulation state towards SpikeNet 
            # for [-2*Tsync, Tsync] = [-min_tvb_delay, -min_tvb_delay/2]
            tvb_to_trans_cosim_updates_past = tvb_app.get_tvb_init_cosim_coupling(
                relative_output_interfaces_time_steps=-tvb_app.cosimulator.synchronization_n_step)
            # ...and transform it:
            trans_to_spikeNet_cosim_updates = tvb_to_spikeNet_app.run_for_synchronization_time(tvb_to_trans_cosim_updates_past)
    else:
        run_for_synchronization_time = run_for_synchronization_time_sync_min_delay
    
    # Steps left to simulate:
    remaining_steps = int(np.round(simulation_length / dt))
    # Steps already simulated:
    simulated_steps = 0
    
    # Loop for steps_to_simulate in steps of synchronization_time:
    tvb_app.cosimulator._tic = time.time()
    while remaining_steps > 0:
        # Set the remaining steps as simulation time, 
        # if it is less than the original synchronization time:
        tvb_app.cosimulator.synchronization_n_step = np.minimum(remaining_steps, synchronization_n_step)
        time_to_simulate = dt * tvb_app.cosimulator.synchronization_n_step
        tvb_app.cosimulator.synchronization_time = time_to_simulate
        spikeNet_app.synchronization_time = time_to_simulate
        tvb_to_trans_cosim_updates, trans_to_spikeNet_cosim_updates, \
        spikeNet_to_trans_cosim_updates, trans_to_tvb_cosim_updates = \
            run_for_synchronization_time(tvb_app, spikeNet_app, tvb_to_spikeNet_app, spikeNet_to_tvb_app,
                                         tvb_to_trans_cosim_updates, trans_to_spikeNet_cosim_updates, 
                                         spikeNet_to_trans_cosim_updates, trans_to_tvb_cosim_updates)
        simulated_steps += tvb_app.cosimulator.n_tvb_steps_ran_since_last_synch
        tvb_app.cosimulator._log_print_progress_message(simulated_steps, simulation_length)
        remaining_steps -= tvb_app.cosimulator.n_tvb_steps_ran_since_last_synch

    # Update the simulation length of the TVB cosimulator:
    tvb_app.cosimulator.simulation_length = simulated_steps * dt  # update the configured value
    # Restore the original synchronization_time
    tvb_app.cosimulator.synchronization_n_step = synchronization_n_step
    tvb_app.cosimulator.synchronization_time = synchronization_time
    spikeNet_app.synchronization_time = synchronization_time
            
    return tvb_app, spikeNet_app, tvb_to_spikeNet_app, spikeNet_to_tvb_app, \
           tvb_to_trans_cosim_updates, trans_to_spikeNet_cosim_updates, \
           spikeNet_to_trans_cosim_updates, trans_to_tvb_cosim_updates

# %%
tvb_app, spikeNet_app, tvb_to_spikeNet_app, spikeNet_to_tvb_app, \
tvb_to_trans_cosim_updates, trans_to_spikeNet_cosim_updates, \
           spikeNet_to_trans_cosim_updates, trans_to_tvb_cosim_updates = \
    run_cosimulation(tvb_app, spikeNet_app, tvb_to_spikeNet_app, spikeNet_to_tvb_app, 
                     advance_simulation_for_delayed_monitors_output=True)

results = tvb_app.return_tvb_results()
# Out:
# ...0.326% completed in 0.0130486 sec!
# 2023-10-24 18:09:26,253	INFO worker.py:1642 -- Started a local Ray instance.
# ...6.189% completed in 4.09004 sec!
# (ray_compute_rates_ElephantSpikesHistogramRate pid=3090) /home/docker/.local/lib/python3.10/site-packages/elephant/conversion.py:1170: UserWarning: Binning discarded 4 last spike(s) of the input spiketrain
# (ray_compute_rates_ElephantSpikesHistogramRate pid=3090)   warnings.warn("Binning discarded {} last spike(s) of the "
# ...81.433% completed in 9.77109 sec!
# (ray_compute_rates_ElephantSpikesHistogramRate pid=3096) /home/docker/.local/lib/python3.10/site-packages/elephant/conversion.py:1170: UserWarning: Binning discarded 100 last spike(s) of the input spiketrain [repeated 10x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/ray-logging.html#log-deduplication for more options.)
# (ray_compute_rates_ElephantSpikesHistogramRate pid=3096)   warnings.warn("Binning discarded {} last spike(s) of the " [repeated 10x across cluster]
# ...100.000% completed in 11.1885 sec!

# %% [markdown]
# ## 5. Plot results and write them to HDF5 files

# %%
import os

import numpy as np
from scipy.io import savemat

from tvb_multiscale.core.plot.plotter import Plotter


# set to False for faster plotting of only mean field variables and dates, apart from spikes" rasters:
plot_per_neuron = False  
MAX_VARS_IN_COLS = 3
MAX_REGIONS_IN_ROWS = 10
MIN_REGIONS_FOR_RASTER_PLOT = 9

# Set the transient time to be optionally removed from results:
simulation_length = tvb_app.cosimulator.simulation_length
transient = getattr(config, "TRANSIENT", 0.1*simulation_length)

simulator = tvb_app.cosimulator
nest_network = spikeNet_app.spiking_network
nest_nodes_inds = tvb_app.cosimulator.proxy_inds

config.figures.SHOW_FLAG = True 
config.figures.SAVE_FLAG = True
config.figures.FIG_FORMAT = 'png'
config.figures.DEFAULT_SIZE= config.figures.NOTEBOOK_SIZE
FIGSIZE = config.figures.DEFAULT_SIZE

plotter = Plotter(config.figures)

try:
    # We need framework_tvb for writing and reading from HDF5 files
    from tvb_multiscale.core.tvb.io.h5_writer import H5Writer
    from examples.plot_write_results import write_RegionTimeSeriesXarray_to_h5
    writer = H5Writer()
    
except:
    writer = False
# Out:
# 2023-10-24 18:09:36,185 - INFO - tvb.storage.h5.encryption.data_encryption_handler - Cannot import syncrypto library.

# %% [markdown]
# ### TVB plots

# %%
# tvb_app.plot(transient=transient, plotter=plotter, writer=writer)

# If you want to see what the function above does, take the steps, one by one:

# %%
# Put the results in a Timeseries instance
from tvb.contrib.scripts.datatypes.time_series_xarray import TimeSeriesRegion as TimeSeriesXarray

source_ts = None
t = simulation_length * simulator.integrator.dt
if results is not None:
    # Substitute with TimeSeriesRegion fot TVB like functionality:
    # from tvb.contrib.scripts.datatypes.time_series import TimeSeriesRegion
    source_ts = TimeSeriesXarray(  
            data=results[0][1], time=results[0][0],
            connectivity=simulator.connectivity,
            labels_ordering=["Time", "State Variable", "Region", "Neurons"],
            labels_dimensions={"State Variable": list(simulator.model.variables_of_interest),
                               "Region": simulator.connectivity.region_labels.tolist()},
            sample_period=simulator.integrator.dt)
    source_ts.configure()

    t = source_ts.time

    # Write to file
    if writer:
        write_RegionTimeSeriesXarray_to_h5(source_ts, writer,
                                           os.path.join(config.out.FOLDER_RES, source_ts.title)+".h5")
    source_ts

# %%
# Plot TVB time series
if source_ts is not None:
    source_ts.plot_timeseries(plotter_config=plotter.config, 
                          hue="Region" if source_ts.shape[2] > MAX_REGIONS_IN_ROWS else None, 
                          per_variable=source_ts.shape[1] > MAX_VARS_IN_COLS, 
                          figsize=FIGSIZE);

# %%
# Focus on the nodes modelled in NEST: raster plot
if source_ts is not None and source_ts.number_of_labels > MIN_REGIONS_FOR_RASTER_PLOT:
    source_ts.plot_raster(plotter_config=plotter.config, 
                          per_variable=source_ts.shape[1] > MAX_VARS_IN_COLS,
                          figsize=FIGSIZE, figname="Spiking nodes TVB Time Series Raster");

# %%
# Focus on the nodes modelled in NEST: 
n_spiking_nodes = len(nest_nodes_inds)
if source_ts is not None and n_spiking_nodes:
    source_ts_nest = source_ts[:, :, nest_nodes_inds]
    source_ts_nest.plot_timeseries(plotter_config=plotter.config, 
                                   hue="Region" if source_ts_nest.shape[2] > MAX_REGIONS_IN_ROWS else None, 
                                   per_variable=source_ts_nest.shape[1] > MAX_VARS_IN_COLS, 
                                   figsize=FIGSIZE, figname="Spiking nodes TVB Time Series");

# %%
# Focus on the nodes modelled in NEST: raster plot
if source_ts is not None and n_spiking_nodes: # and source_ts_nest.number_of_labels > MIN_REGIONS_FOR_RASTER_PLOT:
    source_ts_nest.plot_raster(plotter_config=plotter.config, 
                               per_variable=source_ts_nest.shape[1] > MAX_VARS_IN_COLS,
                               figsize=FIGSIZE, figname="Spiking nodes TVB Time Series Raster");

# %% [markdown]
# ### Interactive time series plot

# %%
# # ...interactively as well
# # For interactive plotting:
# %matplotlib notebook 
# plotter.plot_timeseries_interactive(source_ts)

# %% [markdown]
# ### Spiking Network plots

# %%
# spikeNet_app.plot(time=t, transient=transient,
#                   plot_per_neuron=plot_per_neuron, plotter=plotter, writer=writer)

# If you want to see what the function above does, take the steps, one by one:

# %%
spikeNet_analyzer = None
if nest_network is not None:
    from tvb_multiscale.core.data_analysis.spiking_network_analyser import SpikingNetworkAnalyser
    # Create a SpikingNetworkAnalyzer:
    spikeNet_analyzer = \
        SpikingNetworkAnalyser(spikeNet=nest_network,
                               start_time=0.0, end_time=simulation_length, 
                               transient=transient, time_series_output_type="TVB", 
                               return_data=True, force_homogeneous_results=True, 
                               period=simulator.monitors[0].period, connectivity=simulator.connectivity
                              )

# %% [markdown]
# ### Plot spikes' raster and mean spike rates and correlations

# %%
spikes_res = None
if spikeNet_analyzer is not None:
    # Spikes rates and correlations per Population and Region
    spikes_res = \
        spikeNet_analyzer.\
            compute_spikeNet_spikes_rates_and_correlations(
                populations_devices=None, regions=None,
                rates_methods=[], rates_kwargs=[{}],rate_results_names=[],
                corrs_methods=[], corrs_kwargs=[{}], corrs_results_names=[], bin_kwargs={},
                data_method=spikeNet_analyzer.get_spikes_from_device, data_kwargs={},
                return_devices=False
            );
# Out:
# 2023-10-24 18:09:42,283 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model  for  created!
# 2023-10-24 18:09:42,283 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model  for  created!
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/data_analysis/spiking_network_analyser.py:227: FutureWarning:Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/data_analysis/spiking_network_analyser.py:227: FutureWarning:Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/data_analysis/spiking_network_analyser.py:374: FutureWarning:Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/data_analysis/spiking_network_analyser.py:377: FutureWarning:Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/data_analysis/spiking_network_analyser.py:380: FutureWarning:Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/data_analysis/spiking_network_analyser.py:381: FutureWarning:Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/data_analysis/spiking_network_analyser.py:374: FutureWarning:Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# /home/docker/.local/lib/python3.10/site-packages/elephant/conversion.py:1170: UserWarning:Binning discarded 100 last spike(s) of the input spiketrain

# %%
if spikes_res:
    print(spikes_res["mean_rate"])
    print(spikes_res["spikes_correlation_coefficient"])
    # Plot spikes' rasters together with mean population's spikes' rates' time series
    if plotter:
        plotter.plot_spike_events(spikes_res["spikes"], mean_results=spikes_res["mean_rate"], # time_series=spikes_res["mean_rate_time_series"], 
                                  figsize=(20, 22),  
                                  stimulus=None,
                                  stimulus_linewidth=5.0,
                                  spikes_markersize=0.5, spikes_alpha=0.5,
                                  n_y_ticks=3, n_time_ticks=5, show_time_axis=True, 
                                  time_axis_min=0.0, time_axis_max=simulation_length)
        from tvb_multiscale.core.plot.correlations_plot import plot_correlations
        plot_correlations(spikes_res["spikes_correlation_coefficient"], plotter)
# Out:
# <xarray.DataArray "Mean Populations' Spikes' Rates" (Population: 2, Region: 2)>
# array([[28.37246313, 30.16315155],
#        [30.83963384, 39.79307593]])
# Coordinates:
#   * Region      (Region) object 'bankssts_L' 'bankssts_R'
#   * Population  (Population) object 'E' 'I'
# <xarray.DataArray "Populations' Correlation Coefficient" (Population_i: 2,
#                                                           Population_j: 2,
#                                                           Region_i: 2,
#                                                           Region_j: 2)>
# array([[[[ 1.        ,  0.01998742],
#          [ 0.01998742,  1.        ]],
#
#         [[ 0.01943322,  0.02507046],
#          [ 0.02871871,  0.00443049]]],
#
#
#        [[[ 0.01943322,  0.02871871],
#          [ 0.02507046,  0.00443049]],
#
#         [[ 1.        , -0.00345187],
#          [-0.00345187,  1.        ]]]])
# Coordinates:
#   * Population_j  (Population_j) object 'E' 'I'
#   * Region_j      (Region_j) object 'bankssts_L' 'bankssts_R'
#   * Population_i  (Population_i) object 'E' 'I'
#   * Region_i      (Region_i) object 'bankssts_L' 'bankssts_R'

# %%
if spikes_res:
    print("Mean spike rates:")
    for pop in spikes_res["mean_rate"].coords["Population"]:
        for reg in spikes_res["mean_rate"].coords["Region"]:
            if not np.isnan(spikes_res["mean_rate"].loc[pop, reg]):
                print("%s - %s: %g" % (pop.values.item().split("_spikes")[0], reg.values.item(), 
                                       spikes_res["mean_rate"].loc[pop, reg].values.item()))

    # savemat(os.path.join(config.out.FOLDER_RES, "spikes_mean_rates.mat"), spikes_res["mean_rate"].to_dict())

    
#--------------- INTERFACE_COUPLING_MODE = "TVB" --------------

# Mean spike rates:
# def_min_delay = 0.1ms, w_TVB_to_NEST = 5000.0, synchronization_time = min_tvb_delay
# E - bankssts_L: 28.85
# E - bankssts_R: 27.8552
# I - bankssts_L: 28.85
# I - bankssts_R: 27.8552


# def_min_delay = 1.0 ms, w_TVB_to_NEST = 2500.0:

# Mean spike rates, with synchronization_time = min_tvb_delay:
# E - bankssts_L: 28.3725
# E - bankssts_R: 30.1632
# I - bankssts_L: 30.8396
# I - bankssts_R: 39.7931
# completed in 77.6139 sec!

# Mean spike rates, with synchronization_time = min_tvb_delay / 2:
# E - bankssts_L: 29.2579
# E - bankssts_R: 28.5515
# I - bankssts_L: 31.8345
# I - bankssts_R: 31.8345
# completed in 99.6736 sec!


#--------------- INTERFACE_COUPLING_MODE = "spikeNet" --------------
# with min_nest_delay = 1.0ms and wTVB_to_NEST = 2500.0:

# Mean spike rates, with synchronization_time = min_tvb_delay:
# E - bankssts_L: 25.9451
# E - bankssts_R: 23.0004
# I - bankssts_L: 27.8552
# I - bankssts_R: 24.8707
# ...100.000% completed in ?? sec!
# Out:
# Mean spike rates:
# E - bankssts_L: 28.3725
# E - bankssts_R: 30.1632
# I - bankssts_L: 30.8396
# I - bankssts_R: 39.7931

# %%
spikes_sync = None

if spikeNet_analyzer is not None:

    spikeNet_analyzer.resample = True
    spikes_sync = \
        spikeNet_analyzer.compute_spikeNet_synchronization(populations_devices=None, regions=None,
                                                           comp_methods=[spikeNet_analyzer.compute_spikes_sync, 
                                                                         spikeNet_analyzer.compute_spikes_sync_time_series, 
                                                                         spikeNet_analyzer.compute_spikes_distance, 
                                                                         spikeNet_analyzer.compute_spikes_distance_time_series,
                                                                         spikeNet_analyzer.compute_spikes_isi_distance, 
                                                                         spikeNet_analyzer.compute_spikes_isi_distance_time_series],
                                                           computations_kwargs=[{}], data_kwargs={},
                                                           return_spikes_trains=False, return_devices=False)
# print(spikes_sync)
# Out:
# 2023-10-24 18:09:43,178 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model  for  created!
# 2023-10-24 18:09:43,178 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model  for  created!
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/data_analysis/spiking_network_analyser.py:227: FutureWarning:Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/data_analysis/spiking_network_analyser.py:227: FutureWarning:Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/data_analysis/spiking_network_analyser.py:374: FutureWarning:Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/data_analysis/spiking_network_analyser.py:377: FutureWarning:Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/data_analysis/spiking_network_analyser.py:380: FutureWarning:Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/data_analysis/spiking_network_analyser.py:381: FutureWarning:Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/data_analysis/spiking_network_analyser.py:374: FutureWarning:Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/data_analysis/spiking_network_analyser.py:377: FutureWarning:Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/data_analysis/spiking_network_analyser.py:380: FutureWarning:Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/data_analysis/spiking_network_analyser.py:381: FutureWarning:Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/data_analysis/spiking_network_analyser.py:374: FutureWarning:Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/data_analysis/spiking_network_analyser.py:377: FutureWarning:Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/data_analysis/spiking_network_analyser.py:380: FutureWarning:Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/data_analysis/spiking_network_analyser.py:381: FutureWarning:Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/data_analysis/spiking_network_analyser.py:374: FutureWarning:Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`

# %%
if spikes_sync:
    plotter.config.FONTSIZE = 20 # plotter.config.LARGE_FONTSIZE  # LARGE = 12, default = 10
    plotter.plot_spike_events(spikes_res["spikes"], 
                              time_series=spikes_sync["spikes_sync_time_series"], 
                              mean_results=spikes_sync["spikes_sync"], 
                              stimulus_linewidth=5.0,
                              spikes_markersize=0.5, spikes_alpha=0.5,
                              n_y_ticks=3, n_time_ticks=5, show_time_axis=True, 
                              time_axis_min=0.0, time_axis_max=simulation_length, figsize=(20, 22)
                              )

# %%
if spikes_sync:
    plotter.config.FONTSIZE = 20 # plotter.config.LARGE_FONTSIZE  # LARGE = 12, default = 10
    plotter.plot_spike_events(spikes_res["spikes"], 
                              time_series=spikes_sync["spikes_distance_time_series"], 
                              mean_results=spikes_sync["spikes_distance"], 
                              stimulus_linewidth=5.0,
                              spikes_markersize=0.5, spikes_alpha=0.5,
                              n_y_ticks=3, n_time_ticks=5, show_time_axis=True, 
                              time_axis_min=0.0, time_axis_max=simulation_length, figsize=(20, 22)
                                     )

# %%
if spikes_sync:
    plotter.config.FONTSIZE = 20 # plotter.config.LARGE_FONTSIZE  # LARGE = 12, default = 10
    plotter.plot_spike_events(spikes_res["spikes"], 
                              time_series=spikes_sync["spikes_isi_distance_time_series"], 
                              mean_results=spikes_sync["spikes_isi_distance"], 
                              stimulus_linewidth=5.0,
                              spikes_markersize=0.5, spikes_alpha=0.5,
                              n_y_ticks=3, n_time_ticks=5, show_time_axis=True, 
                              time_axis_min=0.0, time_axis_max=simulation_length, figsize=(20, 22)
                                     )

# %%
if spikes_sync:
    print("Spike synchronization:")
    for pop in spikes_sync["spikes_sync"].coords["Population"]:
        for reg in spikes_sync["spikes_sync"].coords["Region"]:
            if not np.isnan(spikes_sync["spikes_sync"].loc[pop, reg]):
                print("%s - %s: %g" % (pop.values.item().split("_spikes")[0], reg.values.item(), 
                                       spikes_sync["spikes_sync"].loc[pop, reg].values.item()))

#     savemat(os.path.join(config.out.FOLDER_RES, "spikes_sync.mat"), spikes_sync["spikes_sync"].to_dict())
#     savemat(os.path.join(config.out.FOLDER_RES, "spikes_sync_time_series.mat"), spikes_sync["spikes_sync_time_series"].to_dict())
# Out:
# Spike synchronization:
# E - bankssts_L: 1
# E - bankssts_R: 1
# I - bankssts_L: 1
# I - bankssts_R: 1

# %%
if spikes_sync:
    print("Spike distance:")
    for pop in spikes_sync["spikes_distance"].coords["Population"]:
        for reg in spikes_sync["spikes_distance"].coords["Region"]:
            if not np.isnan(spikes_sync["spikes_distance"].loc[pop, reg]):
                print("%s - %s: %g" % (pop.values.item().split("_spikes")[0], reg.values.item(), 
                                       spikes_sync["spikes_distance"].loc[pop, reg].values.item()))

#     savemat(os.path.join(config.out.FOLDER_RES, "spikes_distance.mat"), spikes_sync["spikes_distance"].to_dict())
#     savemat(os.path.join(config.out.FOLDER_RES, "spikes_distance_time_series.mat"), spikes_sync["spikes_distance_time_series"].to_dict())
# Out:
# Spike distance:
# E - bankssts_L: 0
# E - bankssts_R: 0
# I - bankssts_L: 0
# I - bankssts_R: 0

# %%
if spikes_sync:
    print("Spike ISI distance:")
    for pop in spikes_sync["spikes_isi_distance"].coords["Population"]:
        for reg in spikes_sync["spikes_isi_distance"].coords["Region"]:
            if not np.isnan(spikes_sync["spikes_isi_distance"].loc[pop, reg]):
                print("%s - %s: %g" % (pop.values.item().split("_spikes")[0], reg.values.item(), 
                                       spikes_sync["spikes_isi_distance"].loc[pop, reg].values.item()))

#     savemat(os.path.join(config.out.FOLDER_RES, "spikes_isi_distance.mat"), spikes_sync["spikes_isi_distance"].to_dict())
#     savemat(os.path.join(config.out.FOLDER_RES, "spikes_isi_distance_time_series.mat"), spikes_sync["spikes_isi_distance_time_series"].to_dict())
# Out:
# Spike ISI distance:
# E - bankssts_L: 0
# E - bankssts_R: 0
# I - bankssts_L: 0
# I - bankssts_R: 0

# %%
if spikes_res and writer:
    writer.write_object(spikes_res["spikes"].to_dict(), 
                        path=os.path.join(config.out.FOLDER_RES,  "Spikes") + ".h5");
    writer.write_object(spikes_res["mean_rate"].to_dict(),
                        path=os.path.join(config.out.FOLDER_RES,
                                          spikes_res["mean_rate"].name) + ".h5");
    write_RegionTimeSeriesXarray_to_h5(spikes_res["mean_rate_time_series"], writer,
                                       os.path.join(config.out.FOLDER_RES,
                                                    spikes_res["mean_rate_time_series"].title + ".h5"),
                                       recursive=False);
    writer.write_object(spikes_res["spikes_correlation_coefficient"].to_dict(),
                        path=os.path.join(config.out.FOLDER_RES,
                                          spikes_res["spikes_correlation_coefficient"].name) + ".h5");
# Out:
# 2023-10-24 18:09:47,618 - WARNING - tvb_multiscale.core.tvb.io.h5_writer - Failed to decompose group object: {'E': bankssts_L    senders    [84, 72, 8, 20, 24, 28, 40, 44, 48,...
# bankssts_R    senders    [208, 256, 264, 272, 296, 204, 220,...
# Name: E, dtype: object, 'I': bankssts_L    senders    [104, 108, 112, 116, 120, 124, 128,...
# bankssts_R    senders    [304, 308, 312, 316, 320, 324, 328,...
# Name: I, dtype: object}!
# The error was
# module 'numpy' has no attribute 'complex'.
# `np.complex` was a deprecated alias for the builtin `complex`. To avoid this error in existing code, use `complex` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.complex128` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  It has no __dict__ attribute!
# 2023-10-24 18:09:47,621 - WARNING - tvb_multiscale.core.tvb.io.h5_writer -
# Writing <class 'tuple'> dims to h5 file as a numpy array dataset !
#
# 2023-10-24 18:09:47,621 - WARNING - tvb_multiscale.core.tvb.io.h5_writer - Failed to decompose group object: {'dims': ('Population', 'Region'), 'attrs': {}, 'data': [[28.372463134953314, 30.163151551605342], [30.839633842340554, 39.79307592560072]], 'coords': {'Region': {'dims': ('Region',), 'attrs': {}, 'data': ['bankssts_L', 'bankssts_R']}, 'Population': {'dims': ('Population',), 'attrs': {}, 'data': ['E', 'I']}}, 'name': "Mean Populations' Spikes' Rates"}!
# The error was
# module 'numpy' has no attribute 'complex'.
# `np.complex` was a deprecated alias for the builtin `complex`. To avoid this error in existing code, use `complex` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.complex128` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  It has no __dict__ attribute!
# 2023-10-24 18:09:47,622 - WARNING - tvb_multiscale.core.tvb.io.h5_writer - Failed to write to <HDF5 file "Mean Populations' Spikes' Rates.h5" (mode r+)> dataset <class 'numpy.ndarray'> dims:
# ['Population' 'Region'] !
# The error was:
# module 'numpy' has no attribute 'str'.
# `np.str` was a deprecated alias for the builtin `str`. To avoid this error in existing code, use `str` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.str_` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 2023-10-24 18:09:47,655 - WARNING - tvb_multiscale.core.tvb.io.h5_writer -
# Writing <class 'tuple'> dims to h5 file as a numpy array dataset !
#
# 2023-10-24 18:09:47,656 - WARNING - tvb_multiscale.core.tvb.io.h5_writer - Failed to decompose group object: {'dims': ('Population_i', 'Population_j', 'Region_i', 'Region_j'), 'attrs': {}, 'data': [[[[0.9999999999999999, 0.019987417709185298], [0.019987417709185298, 1.0]], [[0.019433222765724456, 0.025070463412504167], [0.0287187060475827, 0.004430486905557473]]], [[[0.019433222765724456, 0.0287187060475827], [0.025070463412504167, 0.004430486905557473]], [[0.9999999999999998, -0.003451872269800566], [-0.003451872269800566, 1.0]]]], 'coords': {'Population_j': {'dims': ('Population_j',), 'attrs': {}, 'data': ['E', 'I']}, 'Region_j': {'dims': ('Region_j',), 'attrs': {}, 'data': ['bankssts_L', 'bankssts_R']}, 'Population_i': {'dims': ('Population_i',), 'attrs': {}, 'data': ['E', 'I']}, 'Region_i': {'dims': ('Region_i',), 'attrs': {}, 'data': ['bankssts_L', 'bankssts_R']}}, 'name': "Populations' Correlation Coefficient"}!
# The error was
# module 'numpy' has no attribute 'complex'.
# `np.complex` was a deprecated alias for the builtin `complex`. To avoid this error in existing code, use `complex` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.complex128` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  It has no __dict__ attribute!
# 2023-10-24 18:09:47,657 - WARNING - tvb_multiscale.core.tvb.io.h5_writer - Failed to write to <HDF5 file "Populations' Correlation Coefficient.h5" (mode r+)> dataset <class 'numpy.ndarray'> dims:
# ['Population_i' 'Population_j' 'Region_i' 'Region_j'] !
# The error was:
# module 'numpy' has no attribute 'str'.
# `np.str` was a deprecated alias for the builtin `str`. To avoid this error in existing code, use `str` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.str_` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/tvb/io/h5_writer.py:125: FutureWarning:In the future `np.str` will be defined as the corresponding NumPy scalar.

# %% [markdown]
# ### Get  SpikingNetwork mean field variable time series and plot them

# %%
# Continuous time variables' data of spiking neurons
spikeNet_ts = None
mean_field_ts = None
if spikeNet_analyzer:
    if plot_per_neuron:
        spikeNet_analyzer.return_data = True
    else:
        spikeNet_analyzer.return_data = False
    spikeNet_ts = \
        spikeNet_analyzer. \
             compute_spikeNet_mean_field_time_series(populations_devices=None, regions=None, variables=None,
                                                     computations_kwargs={}, data_kwargs={}, return_devices=False)
    if spikeNet_ts:
        if plot_per_neuron:
            mean_field_ts = spikeNet_ts["mean_field_time_series"]  # mean field
            spikeNet_ts = spikeNet_ts["data_by_neuron"]  # per neuron data
        else:
            mean_field_ts = spikeNet_ts
            spikeNet_ts = None
        if mean_field_ts and mean_field_ts.size > 0:
            mean_field_ts.plot_timeseries(plotter_config=plotter.config, 
                                          per_variable=mean_field_ts.shape[1] > MAX_VARS_IN_COLS)
            if mean_field_ts.number_of_labels > MIN_REGIONS_FOR_RASTER_PLOT:
                mean_field_ts.plot_raster(plotter_config=plotter.config, 
                                          per_variable=mean_field_ts.shape[1] > MAX_VARS_IN_COLS,
                                          linestyle="--", alpha=0.5, linewidth=0.5)
# Out:
# 2023-10-24 18:09:47,662 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model  for  created!
# 2023-10-24 18:09:47,662 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model  for  created!
# 2023-10-24 18:09:47,665 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model  for  created!
# 2023-10-24 18:09:47,665 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model  for  created!
# 2023-10-24 18:09:47,667 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model  for  created!
# 2023-10-24 18:09:47,667 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model  for  created!
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/data_analysis/spiking_network_analyser.py:227: FutureWarning:Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/data_analysis/spiking_network_analyser.py:227: FutureWarning:Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/data_analysis/spiking_network_analyser.py:374: FutureWarning:Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/data_analysis/spiking_network_analyser.py:377: FutureWarning:Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/data_analysis/spiking_network_analyser.py:380: FutureWarning:Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/data_analysis/spiking_network_analyser.py:381: FutureWarning:Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`

# %%
# Write results to file:
if mean_field_ts and writer:
    write_RegionTimeSeriesXarray_to_h5(mean_field_ts, writer,
                                       os.path.join(config.out.FOLDER_RES, mean_field_ts.title + ".h5"), 
                                       recursive=False)

# %% [markdown]
# ### Compute per neuron spikes' rates times series and plot them

# %%
if spikes_res and plot_per_neuron:
    from tvb.simulator.plot.base_plotter import pyplot
    spikeNet_analyzer.return_data = False
    rates_ts_per_neuron = \
        spikeNet_analyzer. \
            compute_spikeNet_rates_time_series(populations_devices=None, regions=None,
                                               computations_kwargs={}, data_kwargs={},
                                               return_spikes_trains=False, return_devices=False);
    if rates_ts_per_neuron is not None and rates_ts_per_neuron.size:
        # Regions in rows
        row = rates_ts_per_neuron.dims[2] if rates_ts_per_neuron.shape[2] > 1 else None
        if row is None:
            # Populations in rows
            row = rates_ts_per_neuron.dims[1] if rates_ts_per_neuron.shape[1] > 1 else None
            col = None
        else:
            # Populations in columns
            col = rates_ts_per_neuron.dims[1] if rates_ts_per_neuron.shape[1] > 1 else None
        pyplot.figure()
        rates_ts_per_neuron.plot(y=rates_ts_per_neuron.dims[3], row=row, col=col, cmap="jet")
        plotter.base._save_figure(figure_name="Spike rates per neuron")
        # del rates_ts_per_neuron # to free memory

# %% [markdown]
# ### Plot per neuron SpikingNetwork time series

# %%
# Regions in rows
if spikeNet_ts is not None and spikeNet_ts.size:
    row = spikeNet_ts.dims[2] if spikeNet_ts.shape[2] > 1 else None
    if row is None:
        # Populations in rows
        row = spikeNet_ts.dims[3] if spikeNet_ts.shape[3] > 1 else None
        col = None
    else:
        # Populations in cols
         col = spikeNet_ts.dims[3] if spikeNet_ts.shape[3] > 1 else None
    for var in spikeNet_ts.coords[spikeNet_ts.dims[1]]:
        this_var_ts = spikeNet_ts.loc[:, var, :, :, :]
        this_var_ts.name = var.item()
        pyplot.figure()
        this_var_ts.plot(y=spikeNet_ts.dims[4], row=row, col=col, cmap="jet", figsize=FIGSIZE)
        plotter.base._save_figure(
            figure_name="Spiking Network variables' time series per neuron: %s" % this_var_ts.name)
    del spikeNet_ts # to free memory

# %%
from tvb_multiscale.core.nrp.final import *


spikeNet_app = final_spikeNet(spikeNet_app, plot=True)
tvb_to_spikeNet_app = final_transformer(tvb_to_spikeNet_app)
spikeNet_to_tvb_app = final_transformer(spikeNet_to_tvb_app)
tvb_app = final_tvb(tvb_app, plot=True)

del tvb_app, spikeNet_app, tvb_to_spikeNet_app, spikeNet_to_tvb_app
# Out:
# 2023-10-24 18:09:49,502 - INFO - tvb_multiscale.core.orchestrators.base -
# Plotting results with App NESTNRPApp...
# 2023-10-24 18:09:49,502 - INFO - tvb_multiscale.core.orchestrators.base -
# Plotting results with App NESTNRPApp...
# 2023-10-24 18:09:49,502 - INFO - tvb_multiscale.core.orchestrators.base -
# Plotting results with App NESTNRPApp...
# 2023-10-24 18:09:49,502 - INFO - tvb_multiscale.core.orchestrators.base -
# Plotting results with App NESTNRPApp...
# 2023-10-24 18:09:49,502 - INFO - tvb_multiscale.core.orchestrators.base -
# Plotting results with App NESTNRPApp...
#
# Plotting results with App NESTNRPApp...
# 2023-10-24 18:09:49,506 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model  for  created!
# 2023-10-24 18:09:49,506 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model  for  created!
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/data_analysis/spiking_network_analyser.py:227: FutureWarning:Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/data_analysis/spiking_network_analyser.py:227: FutureWarning:Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/data_analysis/spiking_network_analyser.py:374: FutureWarning:Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/data_analysis/spiking_network_analyser.py:377: FutureWarning:Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/data_analysis/spiking_network_analyser.py:380: FutureWarning:Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/data_analysis/spiking_network_analyser.py:381: FutureWarning:Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/data_analysis/spiking_network_analyser.py:374: FutureWarning:Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# /home/docker/.local/lib/python3.10/site-packages/elephant/conversion.py:1170: UserWarning:Binning discarded 100 last spike(s) of the input spiketrain
# Mean spike rates:
# E - bankssts_L: 29.3899
# E - bankssts_R: 31.0703
# I - bankssts_L: 31.9818
# I - bankssts_R: 40.9458
# <xarray.DataArray "Populations' Spikes' Correlation Coefficient" (
#                                                                   Population_i: 2,
#                                                                   Population_j: 2,
#                                                                   Region_i: 2,
#                                                                   Region_j: 2)>
# array([[[[ 1.        ,  0.01998742],
#          [ 0.01998742,  1.        ]],
#
#         [[ 0.01943322,  0.02507046],
#          [ 0.02871871,  0.00443049]]],
#
#
#        [[[ 0.01943322,  0.02871871],
#          [ 0.02507046,  0.00443049]],
#
#         [[ 1.        , -0.00345187],
#          [-0.00345187,  1.        ]]]])
# Coordinates:
#   * Population_j  (Population_j) object 'E' 'I'
#   * Region_j      (Region_j) object 'bankssts_L' 'bankssts_R'
#   * Population_i  (Population_i) object 'E' 'I'
#   * Region_i      (Region_i) object 'bankssts_L' 'bankssts_R'
# 2023-10-24 18:09:50,382 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model  for  created!
# 2023-10-24 18:09:50,382 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model  for  created!
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/data_analysis/spiking_network_analyser.py:227: FutureWarning:Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# Mean spike rates:
# E - bankssts_L: 1
# E - bankssts_R: 1
# I - bankssts_L: 1
# I - bankssts_R: 1
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/data_analysis/spiking_network_analyser.py:227: FutureWarning:Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/data_analysis/spiking_network_analyser.py:374: FutureWarning:Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/data_analysis/spiking_network_analyser.py:377: FutureWarning:Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/data_analysis/spiking_network_analyser.py:380: FutureWarning:Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/data_analysis/spiking_network_analyser.py:381: FutureWarning:Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/data_analysis/spiking_network_analyser.py:374: FutureWarning:Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# 2023-10-24 18:09:51,219 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model  for  created!
# 2023-10-24 18:09:51,219 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model  for  created!
# 2023-10-24 18:09:51,221 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model  for  created!
# 2023-10-24 18:09:51,221 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model  for  created!
# 2023-10-24 18:09:51,222 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model  for  created!
# 2023-10-24 18:09:51,222 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model  for  created!
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/data_analysis/spiking_network_analyser.py:227: FutureWarning:Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/data_analysis/spiking_network_analyser.py:227: FutureWarning:Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/data_analysis/spiking_network_analyser.py:374: FutureWarning:Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/data_analysis/spiking_network_analyser.py:377: FutureWarning:Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/data_analysis/spiking_network_analyser.py:380: FutureWarning:Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/data_analysis/spiking_network_analyser.py:381: FutureWarning:Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# 2023-10-24 18:09:52,946 - INFO - tvb_multiscale.core.orchestrators.base -
# Stopping App NESTNRPApp...
# 2023-10-24 18:09:52,946 - INFO - tvb_multiscale.core.orchestrators.base -
# Stopping App NESTNRPApp...
# 2023-10-24 18:09:52,946 - INFO - tvb_multiscale.core.orchestrators.base -
# Stopping App NESTNRPApp...
# 2023-10-24 18:09:52,946 - INFO - tvb_multiscale.core.orchestrators.base -
# Stopping App NESTNRPApp...
# 2023-10-24 18:09:52,946 - INFO - tvb_multiscale.core.orchestrators.base -
# Stopping App NESTNRPApp...
#
# Stopping App NESTNRPApp...
# 2023-10-24 18:09:52,950 - INFO - tvb_multiscale.core.orchestrators.base -
# Stopping App NRPTVBtoSpikeNetTransformerApp...
# 2023-10-24 18:09:52,950 - INFO - tvb_multiscale.core.orchestrators.base -
# Stopping App NRPTVBtoSpikeNetTransformerApp...
# 2023-10-24 18:09:52,950 - INFO - tvb_multiscale.core.orchestrators.base -
# Stopping App NRPTVBtoSpikeNetTransformerApp...
# 2023-10-24 18:09:52,950 - INFO - tvb_multiscale.core.orchestrators.base -
# Stopping App NRPTVBtoSpikeNetTransformerApp...
# 2023-10-24 18:09:52,950 - INFO - tvb_multiscale.core.orchestrators.base -
# Stopping App NRPTVBtoSpikeNetTransformerApp...
#
# Stopping App NRPTVBtoSpikeNetTransformerApp...
# 2023-10-24 18:09:52,953 - INFO - tvb_multiscale.core.orchestrators.base -
# Stopping App NRPSpikeNetToTVBTransformerApp...
# 2023-10-24 18:09:52,953 - INFO - tvb_multiscale.core.orchestrators.base -
# Stopping App NRPSpikeNetToTVBTransformerApp...
# 2023-10-24 18:09:52,953 - INFO - tvb_multiscale.core.orchestrators.base -
# Stopping App NRPSpikeNetToTVBTransformerApp...
# 2023-10-24 18:09:52,953 - INFO - tvb_multiscale.core.orchestrators.base -
# Stopping App NRPSpikeNetToTVBTransformerApp...
# 2023-10-24 18:09:52,953 - INFO - tvb_multiscale.core.orchestrators.base -
# Stopping App NRPSpikeNetToTVBTransformerApp...
#
# Stopping App NRPSpikeNetToTVBTransformerApp...
# 2023-10-24 18:09:52,956 - INFO - tvb_multiscale.core.orchestrators.base -
# Plotting results with App NRPTVBApp...
# 2023-10-24 18:09:52,956 - INFO - tvb_multiscale.core.orchestrators.base -
# Plotting results with App NRPTVBApp...
# 2023-10-24 18:09:52,956 - INFO - tvb_multiscale.core.orchestrators.base -
# Plotting results with App NRPTVBApp...
# 2023-10-24 18:09:52,956 - INFO - tvb_multiscale.core.orchestrators.base -
# Plotting results with App NRPTVBApp...
# 2023-10-24 18:09:52,956 - INFO - tvb_multiscale.core.orchestrators.base -
# Plotting results with App NRPTVBApp...
#
# Plotting results with App NRPTVBApp...
# 2023-10-24 18:10:03,954 - INFO - tvb_multiscale.core.orchestrators.base -
# Stopping App NRPTVBApp...
# 2023-10-24 18:10:03,954 - INFO - tvb_multiscale.core.orchestrators.base -
# Stopping App NRPTVBApp...
# 2023-10-24 18:10:03,954 - INFO - tvb_multiscale.core.orchestrators.base -
# Stopping App NRPTVBApp...
# 2023-10-24 18:10:03,954 - INFO - tvb_multiscale.core.orchestrators.base -
# Stopping App NRPTVBApp...
# 2023-10-24 18:10:03,954 - INFO - tvb_multiscale.core.orchestrators.base -
# Stopping App NRPTVBApp...
#
# Stopping App NRPTVBApp...

# %% [markdown]
# # References
#
# 1 Paula Sanz Leon, Stuart A. Knock, M. Marmaduke Woodman, Lia Domide, <br>
#   Jochen Mersmann, Anthony R. McIntosh, Viktor Jirsa (2013) <br>
#   The Virtual Brain: a simulator of primate brain network dynamics. <br>
#   Frontiers in Neuroinformatics (7:10. doi: 10.3389/fninf.2013.00010) <br>
#   https://www.thevirtualbrain.org/tvb/zwei <br>
#   https://github.com/the-virtual-brain <br>
#
# 2 Ritter P, Schirner M, McIntosh AR, Jirsa VK. 2013.  <br>
#   The Virtual Brain integrates computational modeling  <br>
#   and multimodal neuroimaging. Brain Connectivity 3:121–145. <br>
#
# 3 Jordan, Jakob; Mørk, Håkon; Vennemo, Stine Brekke;   Terhorst, Dennis; Peyser, <br>
#   Alexander; Ippen, Tammo; Deepu, Rajalekshmi;   Eppler, Jochen Martin; <br>
#   van Meegen, Alexander;   Kunkel, Susanne; Sinha, Ankur; Fardet, Tanguy; Diaz, <br>
#   Sandra; Morrison, Abigail; Schenck, Wolfram; Dahmen, David;   Pronold, Jari; <br>
#   Stapmanns, Jonas;   Trensch, Guido; Spreizer, Sebastian;   Mitchell, Jessica; <br>
#   Graber, Steffen; Senk, Johanna; Linssen, Charl; Hahne, Jan; Serenko, Alexey; <br>
#   Naoumenko, Daniel; Thomson, Eric;   Kitayama, Itaru; Berns, Sebastian;   <br>
#   Plesser, Hans Ekkehard <br>
#   NEST is a simulator for spiking neural network models that focuses <br>
#   on the dynamics, size and structure of neural systems rather than on <br>
#   the exact morphology of individual neurons. <br>
#   For further information, visit http://www.nest-simulator.org. <br>
#   The release notes for this release are available at  <br>
#   https://github.com/nest/nest-simulator/releases/tag/v2.18.0 <br>
